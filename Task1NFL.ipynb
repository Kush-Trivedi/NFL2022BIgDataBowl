# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Arc
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.animation as animation
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

# %%
gameData = pd.read_csv('games.csv', dayfirst=False, parse_dates=[3])
playsData = pd.read_csv('plays.csv')
playersData = pd.read_csv('players.csv')
pffData = pd.read_csv('PFFScoutingData.csv')
trackingData2018 = pd.read_csv("tracking2018.csv")
trackingData2019 = pd.read_csv("tracking2019.csv")
trackingData2020 = pd.read_csv("tracking2020.csv")

# %%
def memoryUsagePerDatatype(dataFrame):
    types = ['float','int','object']
    for type in types:
        columns = dataFrame.select_dtypes(include=[type])
        memoryUsageInBytes = columns.memory_usage(deep=True).sum()
        memoryUsageInMegaBytes=memoryUsageInBytes/1024**2
        print("Memory Usage for\033[1;31;43m {} \033[0;0mColumns:\033[1m {:03.2f} MB \033[0m".format(type,memoryUsageInMegaBytes))

        
def memoryUsage(dataFrame):
    return dataFrame.memory_usage(deep=True).sum()/1024**2


print('\n' + '\033[1;30;42m' + ' Game Data Columns Datatypes: ' + '\033[0m')
memoryUsagePerDatatype(gameData)
print('\033[1mTotal Memory Usage Before Optimization:\033[1;30;45m {:.2f} MB \033[0;0m'.format(memoryUsage(gameData)))
print('\n' + '\033[1;30;42m' + ' Plays Data Columns Datatypes: ' + '\033[0m')
memoryUsagePerDatatype(playsData)
print('\033[1mTotal Memory Usage Before Optimization:\033[1;30;45m {:.2f} MB \033[0;0m'.format(memoryUsage(playsData)))
print('\n' + '\033[1;30;42m' + ' Players Data Columns Datatypes: ' + '\033[0m')
memoryUsagePerDatatype(playersData)
print('\033[1mTotal Memory Usage Before Optimization:\033[1;30;45m {:.2f} MB \033[0;0m'.format(memoryUsage(playersData)))
print('\n' + '\033[1;30;42m' + ' PFF Data Columns Datatypes: ' + '\033[0m')
memoryUsagePerDatatype(pffData)
print('\033[1mTotal Memory Usage Before Optimization:\033[1;30;45m {:.2f} MB \033[0;0m'.format(memoryUsage(pffData)))
print('\n' + '\033[1;30;42m' + ' Tracking Data 2018 Columns Datatypes: ' + '\033[0m')
memoryUsagePerDatatype(trackingData2018)
print('\033[1mTotal Memory Usage Before Optimization:\033[1;30;45m {:.2f} MB \033[0;0m'.format(memoryUsage(trackingData2018)))
print('\n' + '\033[1;30;42m' + ' Tracking Data 2019 Columns Datatypes: ' + '\033[0m')
memoryUsagePerDatatype(trackingData2019)
print('\033[1mTotal Memory Usage Before Optimization:\033[1;30;45m {:.2f} MB \033[0;0m'.format(memoryUsage(trackingData2019)))
print('\n' + '\033[1;30;42m' + ' Tracking Data 2020 Datatypes: ' + '\033[0m')
memoryUsagePerDatatype(trackingData2020)
print('\033[1mTotal Memory Usage Before Optimization:\033[1;30;45m {:.2f} MB \033[0;0m'.format(memoryUsage(trackingData2020)))
# Out:
#  Game Data Columns Datatypes:
# Memory Usage for float Columns: 0.00 MB
# Memory Usage for int Columns: 0.02 MB
# Memory Usage for object Columns: 0.13 MB
# Total Memory Usage Before Optimization: 0.16 MB
#
#  Plays Data Columns Datatypes:
# Memory Usage for float Columns: 0.76 MB
# Memory Usage for int Columns: 1.52 MB
# Memory Usage for object Columns: 11.45 MB
# Total Memory Usage Before Optimization: 13.74 MB
#
#  Players Data Columns Datatypes:
# Memory Usage for float Columns: 0.00 MB
# Memory Usage for int Columns: 0.04 MB
# Memory Usage for object Columns: 0.84 MB
# Total Memory Usage Before Optimization: 0.88 MB
#
#  PFF Data Columns Datatypes:
# Memory Usage for float Columns: 0.46 MB
# Memory Usage for int Columns: 0.30 MB
# Memory Usage for object Columns: 12.29 MB
# Total Memory Usage Before Optimization: 13.06 MB
#
#  Tracking Data 2018 Columns Datatypes:
# Memory Usage for float Columns: 877.35 MB
# Memory Usage for int Columns: 292.45 MB
# ...

# %%
def downcast(dataFrame):
    startMemoryOptimization = dataFrame.memory_usage().sum() / 1024 ** 2
    print('Memory Usage\033[1;31;43m Before \033[0;0mOptimization of Dataframe is:\033[1m {:.2f} MB \033[0m'.format(startMemoryOptimization))
    floatColumns = [c for c in dataFrame if dataFrame[c].dtype in ['float64']]
    intColumns = [c for c in dataFrame if dataFrame[c].dtype in ['int64']]
    objectColumns = [c for c in dataFrame if dataFrame[c].dtype in ['object']]
    dataFrame[floatColumns] = dataFrame[floatColumns].astype(np.float32)
    dataFrame[intColumns] = dataFrame[intColumns].astype(np.int32)
    for column in dataFrame[objectColumns].columns:
        if column =='date':
                dataFrame['date'] = pd.to_datetime(dataFrame['date'],format='%Y-%m-%d')
                
    endMemoryOptimization = dataFrame.memory_usage().sum() / 1024 ** 2
    print('Memory Usage\033[1;31;43m After \033[0;0mOptimization is:\033[1m {:.2f} MB \033[0m'.format(endMemoryOptimization))
    print('\033[1m'+'Compressed by:\033[1;30;45m {:.2f} % \033[0;0m'.format(100*(startMemoryOptimization - endMemoryOptimization) / startMemoryOptimization))
    return dataFrame


print('\n' + '\033[1;30;42m' + ' Game Data Compression: ' + '\033[0m')
gameData = downcast(gameData)
print('\n' + '\033[1;30;42m' + ' Plays Data Compression: ' + '\033[0m')
playsData = downcast(playsData)
print('\n' + '\033[1;30;42m' + ' Playres Data Compression: ' + '\033[0m')
playersData = downcast(playersData)
print('\n' + '\033[1;30;42m' + ' Tracking Data 2018 Compression: ' + '\033[0m')
trackingData2018 = downcast(trackingData2018)
print('\n' + '\033[1;30;42m' + ' Tracking Data 2019 Compression: ' + '\033[0m')
trackingData2019 = downcast(trackingData2019)
print('\n' + '\033[1;30;42m' + ' Tracking Data 2020 Compression: ' + '\033[0m')
trackingData2020 = downcast(trackingData2020)
# Out:
#  Game Data Compression:
# Memory Usage Before Optimization of Dataframe is: 0.04 MB
# Memory Usage After Optimization is: 0.03 MB
# Compressed by: 21.36 %
#
#  Plays Data Compression:
# Memory Usage Before Optimization of Dataframe is: 3.81 MB
# Memory Usage After Optimization is: 2.67 MB
# Compressed by: 30.00 %
#
#  Playres Data Compression:
# Memory Usage Before Optimization of Dataframe is: 0.15 MB
# Memory Usage After Optimization is: 0.13 MB
# Compressed by: 14.27 %
#
#  Tracking Data 2018 Compression:
# Memory Usage Before Optimization of Dataframe is: 1754.70 MB
# Memory Usage After Optimization is: 1169.80 MB
# Compressed by: 33.33 %
#
#  Tracking Data 2019 Compression:
# Memory Usage Before Optimization of Dataframe is: 1671.42 MB
# Memory Usage After Optimization is: 1114.28 MB
# Compressed by: 33.33 %
#
#  Tracking Data 2020 Compression:
# Memory Usage Before Optimization of Dataframe is: 1623.46 MB
# Memory Usage After Optimization is: 1082.31 MB
# ...

# %%
trackingFull = pd.concat([trackingData2018, trackingData2019, trackingData2020], axis=0)
trackingFull.reset_index(drop=True, inplace=True)

# %%
mergedGameAndPlaysData = gameData.merge(playsData, how='inner', indicator=True)
mergedGamePlaysAndTrackingFullData = mergedGameAndPlaysData.merge(trackingFull, how='inner', indicator='exists')

# %%
task1DataFrame = mergedGameAndPlaysData[['season', 'possessionTeam', 'specialTeamsPlayType','specialTeamsResult']]
task1DataFrame["Result"] = task1DataFrame["specialTeamsPlayType"]+ " - " + task1DataFrame["specialTeamsResult"].map(str)
task1DataFrame.drop(['specialTeamsPlayType','specialTeamsResult'],axis=1, inplace=True)

# %%
mergedGamePlaysAndTrackingFullData["Result"] = mergedGamePlaysAndTrackingFullData["specialTeamsPlayType"]+ " - " + mergedGamePlaysAndTrackingFullData["specialTeamsResult"].map(str)
mergedGamePlaysAndTrackingFullData.drop(['specialTeamsPlayType','specialTeamsResult'],axis=1, inplace=True)

# %%
pd.options.display.max_rows = 99999999

# %%
task1DataFrame = mergedGamePlaysAndTrackingFullData[['gameId','season','week','homeTeamAbbr','visitorTeamAbbr','playId',
                                                     'quarter','down','yardsToGo','possessionTeam','Result',
                                                     'yardlineNumber','absoluteYardlineNumber','yardlineSide','gameClock','penaltyCodes','preSnapHomeScore',
                                                     'preSnapVisitorScore','kickReturnYardage','playResult','event'
                                                    ]]

# %%
task1DataFrame['penaltyCodes'] = task1DataFrame['penaltyCodes'].replace(np.nan, 0)

# %%
task1DataFrame['kickReturnYardage'] = task1DataFrame['kickReturnYardage'].replace(np.nan, 0)

# %%
# Special Play Classification

kickoffEvents = ['Kickoff - Touchback','Kickoff - Return','Kickoff - Muffed','Kickoff - Kickoff Team Recovery','Kickoff - Out of Bounds',
                 'Kickoff - Fair Catch','Kickoff - Downed']
puntEvents = ['Punt - Return','Punt - Touchback','Punt - Fair Catch','Punt - Downed','Punt - Muffed','Punt - Out of Bounds',
              'Punt - Non-Special Teams Result','Punt - Blocked Punt']
extrapointEvents = ['Extra Point - Kick Attempt Good','Extra Point - Kick Attempt No Good','Extra Point - Non-Special Teams Result',
                    'Extra Point - Blocked Kick Attempt']
fieldgoalEvents = ['Field Goal - Kick Attempt Good','Field Goal - Kick Attempt No Good','Field Goal - Blocked Kick Attempt',
                   'Field Goal - Non-Special Teams Result','Field Goal - Out of Bounds','Field Goal - Downed']

task1DataFrameKickoffs = task1DataFrame.loc[task1DataFrame['Result'].isin(kickoffEvents)] 
task1DataFramePunts = task1DataFrame.loc[task1DataFrame['Result'].isin(puntEvents)]
task1DataFrameExtrapoints = task1DataFrame.loc[task1DataFrame['Result'].isin(extrapointEvents)]  
task1DataFrameFieldgoals = task1DataFrame.loc[task1DataFrame['Result'].isin(fieldgoalEvents)]

# %%
task1DataFrameKickoffs.head().T

# %%
# ARI Special Plays Data Preparation

# Punts
puntsARI2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'ARI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsARI2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'ARI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsARI2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'ARI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsARI2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'ARI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsARI2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'ARI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsARI2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'ARI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsARI2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'ARI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsARI2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'ARI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsARI2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'ARI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsARI2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'ARI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsARI2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'ARI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsARI2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'ARI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# ATL Special Plays Data Preparation

# Punts
puntsATL2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'ATL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsATL2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'ATL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsATL2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'ATL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsATL2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'ATL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsATL2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'ATL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsATL2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'ATL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsATL2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'ATL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsATL2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'ATL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsATL2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'ATL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsATL2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'ATL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsATL2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'ATL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsATL2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'ATL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# BAL Special Plays Data Preparation

# Punts
puntsBAL2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'BAL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsBAL2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'BAL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsBAL2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'BAL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsBAL2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'BAL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsBAL2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'BAL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsBAL2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'BAL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsBAL2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'BAL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsBAL2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'BAL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsBAL2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'BAL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsBAL2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'BAL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsBAL2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'BAL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsBAL2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'BAL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# BUF Special Plays Data Preparation

# Punts
puntsBUF2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'BUF') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsBUF2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'BUF') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsBUF2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'BUF') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsBUF2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'BUF')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsBUF2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'BUF')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsBUF2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'BUF')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsBUF2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'BUF') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsBUF2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'BUF') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsBUF2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'BUF') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsBUF2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'BUF')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsBUF2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'BUF')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsBUF2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'BUF')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# CAR Special Plays Data Preparation

# Punts
puntsCAR2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'CAR') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCAR2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'CAR') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCAR2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'CAR') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsCAR2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'CAR')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCAR2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'CAR')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCAR2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'CAR')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsCAR2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'CAR') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCAR2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'CAR') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCAR2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'CAR') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsCAR2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'CAR')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCAR2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'CAR')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCAR2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'CAR')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# CHI Special Plays Data Preparation

# Punts
puntsCHI2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'CHI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCHI2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'CHI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCHI2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'CHI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsCHI2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'CHI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCHI2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'CHI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCHI2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'CHI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsCHI2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'CHI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCHI2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'CHI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCHI2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'CHI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsCHI2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'CHI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCHI2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'CHI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCHI2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'CHI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# CLE Special Plays Data Preparation

# Punts
puntsCLE2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'CLE') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCLE2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'CLE') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCLE2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'CLE') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsCLE2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'CLE')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCLE2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'CLE')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCLE2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'CLE')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsCLE2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'CLE') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCLE2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'CLE') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCLE2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'CLE') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsCLE2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'CLE')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCLE2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'CLE')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCLE2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'CLE')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# CIN Special Plays Data Preparation

# Punts
puntsCIN2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'CIN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCIN2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'CIN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsCIN2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'CIN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsCIN2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'CIN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCIN2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'CIN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsCIN2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'CIN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsCIN2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'CIN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCIN2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'CIN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsCIN2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'CIN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsCIN2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'CIN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCIN2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'CIN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsCIN2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'CIN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# DAL Special Plays Data Preparation

# Punts
puntsDAL2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'DAL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsDAL2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'DAL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsDAL2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'DAL') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsDAL2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'DAL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsDAL2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'DAL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsDAL2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'DAL')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsDAL2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'DAL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsDAL2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'DAL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsDAL2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'DAL') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsDAL2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'DAL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsDAL2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'DAL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsDAL2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'DAL')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
extraPointsDAL2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_ExtraPoint_2018.csv', index=False)
extraPointsDAL2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_ExtraPoint_2019.csv', index=False)
extraPointsDAL2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_ExtraPoint_2020.csv', index=False)

fieldGoalsDAL2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_FiledGoals_2018.csv', index=False)
fieldGoalsDAL2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_FiledGoals_2019.csv', index=False)
fieldGoalsDAL2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_FiledGoals_2020.csv', index=False)

kickoffsDAL2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_Kickoffs_2018.csv', index=False)
kickoffsDAL2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_Kickoffs_2019.csv', index=False)
kickoffsDAL2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_Kickoffs_2020.csv', index=False)

puntsDAL2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_Punts_2018.csv', index=False)
puntsDAL2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_Punts_2019.csv', index=False)
puntsDAL2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Dallas/DAL_Punts_2020.csv', index=False)

# %%
# DEN Special Plays Data Preparation

# Punts
puntsDEN2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'DEN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsDEN2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'DEN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsDEN2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'DEN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsDEN2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'DEN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsDEN2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'DEN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsDEN2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'DEN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsDEN2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'DEN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsDEN2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'DEN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsDEN2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'DEN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsDEN2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'DEN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsDEN2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'DEN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsDEN2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'DEN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# DET Special Plays Data Preparation

# Punts
puntsDET2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'DET') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsDET2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'DET') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsDET2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'DET') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsDET2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'DET')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsDET2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'DET')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsDET2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'DET')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsDET2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'DET') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsDET2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'DET') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsDET2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'DET') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsDET2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'DET')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsDET2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'DET')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsDET2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'DET')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# GB Special Plays Data Preparation

# Punts
puntsGB2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'GB') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsGB2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'GB') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsGB2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'GB') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsGB2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'GB')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsGB2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'GB')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsGB2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'GB')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsGB2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'GB') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsGB2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'GB') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsGB2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'GB') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsGB2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'GB')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsGB2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'GB')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsGB2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'GB')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
extraPointsGB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_ExtraPoint_2018.csv', index=False)
extraPointsGB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_ExtraPoint_2019.csv', index=False)
extraPointsGB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_ExtraPoint_2020.csv', index=False)

fieldGoalsGB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_FiledGoals_2018.csv', index=False)
fieldGoalsGB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_FiledGoals_2019.csv', index=False)
fieldGoalsGB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_FiledGoals_2020.csv', index=False)

kickoffsGB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_Kickoffs_2018.csv', index=False)
kickoffsGB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_Kickoffs_2019.csv', index=False)
kickoffsGB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_Kickoffs_2020.csv', index=False)

puntsGB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_Punts_2018.csv', index=False)
puntsGB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_Punts_2019.csv', index=False)
puntsGB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/GreenBay/GB_Punts_2020.csv', index=False)

# %%
# HOU Special Plays Data Preparation

# Punts
puntsHOU2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'HOU') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsHOU2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'HOU') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsHOU2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'HOU') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsHOU2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'HOU')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsHOU2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'HOU')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsHOU2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'HOU')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsHOU2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'HOU') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsHOU2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'HOU') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsHOU2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'HOU') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsHOU2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'HOU')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsHOU2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'HOU')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsHOU2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'HOU')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# IND Special Plays Data Preparation

# Punts
puntsIND2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'IND') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsIND2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'IND') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsIND2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'IND') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsIND2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'IND')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsIND2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'IND')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsIND2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'IND')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsIND2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'IND') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsIND2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'IND') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsIND2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'IND') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsIND2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'IND')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsIND2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'IND')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsIND2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'IND')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# JAX Special Plays Data Preparation

# Punts
puntsJAX2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'JAX') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsJAX2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'JAX') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsJAX2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'JAX') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsJAX2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'JAX')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsJAX2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'JAX')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsJAX2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'JAX')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsJAX2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'JAX') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsJAX2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'JAX') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsJAX2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'JAX') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsJAX2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'JAX')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsJAX2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'JAX')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsJAX2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'JAX')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# KC Special Plays Data Preparation

# Punts
puntsKC2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'KC') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsKC2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'KC') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsKC2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'KC') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsKC2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'KC')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsKC2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'KC')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsKC2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'KC')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsKC2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'KC') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsKC2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'KC') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsKC2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'KC') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsKC2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'KC')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsKC2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'KC')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsKC2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'KC')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
kickoffsKC2020.head(100).T

# %%
extraPointsKC2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_ExtraPoint_2018.csv', index=False)
extraPointsKC2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_ExtraPoint_2019.csv', index=False)
extraPointsKC2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_ExtraPoint_2020.csv', index=False)

fieldGoalsKC2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_FiledGoals_2018.csv', index=False)
fieldGoalsKC2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_FiledGoals_2019.csv', index=False)
fieldGoalsKC2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_FiledGoals_2020.csv', index=False)

kickoffsKC2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_Kickoffs_2018.csv', index=False)
kickoffsKC2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_Kickoffs_2019.csv', index=False)
kickoffsKC2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_Kickoffs_2020.csv', index=False)

puntsKC2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_Punts_2018.csv', index=False)
puntsKC2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_Punts_2019.csv', index=False)
puntsKC2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/KansasCity/KC_Punts_2020.csv', index=False)

# %%
# LA Special Plays Data Preparation

# Punts
puntsLA2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'LA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsLA2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'LA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsLA2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'LA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsLA2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'LA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsLA2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'LA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsLA2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'LA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsLA2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'LA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsLA2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'LA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsLA2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'LA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsLA2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'LA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsLA2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'LA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsLA2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'LA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
extraPointsLA2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_ExtraPoint_2018.csv', index=False)
extraPointsLA2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_ExtraPoint_2019.csv', index=False)
extraPointsLA2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_ExtraPoint_2020.csv', index=False)

fieldGoalsLA2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_FiledGoals_2018.csv', index=False)
fieldGoalsLA2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_FiledGoals_2019.csv', index=False)
fieldGoalsLA2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_FiledGoals_2020.csv', index=False)

kickoffsLA2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_Kickoffs_2018.csv', index=False)
kickoffsLA2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_Kickoffs_2019.csv', index=False)
kickoffsLA2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_Kickoffs_2020.csv', index=False)

puntsLA2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_Punts_2018.csv', index=False)
puntsLA2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_Punts_2019.csv', index=False)
puntsLA2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/LosAngeles/LA_Punts_2020.csv', index=False)

# %%
# LAC Special Plays Data Preparation

# Punts
puntsLAC2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'LAC') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsLAC2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'LAC') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsLAC2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'LAC') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsLAC2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'LAC')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsLAC2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'LAC')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsLAC2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'LAC')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsLAC2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'LAC') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsLAC2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'LAC') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsLAC2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'LAC') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsLAC2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'LAC')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsLAC2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'LAC')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsLAC2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'LAC')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# MIA Special Plays Data Preparation

# Punts
puntsMIA2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'MIA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsMIA2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'MIA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsMIA2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'MIA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsMIA2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'MIA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsMIA2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'MIA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsMIA2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'MIA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsMIA2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'MIA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsMIA2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'MIA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsMIA2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'MIA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsMIA2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'MIA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsMIA2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'MIA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsMIA2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'MIA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# MIN Special Plays Data Preparation

# Punts
puntsMIN2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'MIN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsMIN2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'MIN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsMIN2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'MIN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsMIN2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'MIN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsMIN2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'MIN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsMIN2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'MIN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsMIN2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'MIN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsMIN2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'MIN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsMIN2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'MIN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsMIN2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'MIN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsMIN2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'MIN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsMIN2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'MIN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# NE Special Plays Data Preparation

# Punts
puntsNE2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'NE') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNE2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'NE') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNE2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'NE') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsNE2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'NE')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNE2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'NE')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNE2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'NE')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsNE2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'NE') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNE2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'NE') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNE2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'NE') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsNE2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'NE')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNE2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'NE')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNE2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'NE')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# NO Special Plays Data Preparation

# Punts
puntsNO2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'NO') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNO2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'NO') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNO2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'NO') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsNO2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'NO')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNO2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'NO')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNO2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'NO')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsNO2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'NO') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNO2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'NO') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNO2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'NO') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsNO2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'NO')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNO2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'NO')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNO2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'NO')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# NYG Special Plays Data Preparation

# Punts
puntsNYG2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'NYG') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNYG2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'NYG') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNYG2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'NYG') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsNYG2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'NYG')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNYG2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'NYG')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNYG2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'NYG')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsNYG2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'NYG') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNYG2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'NYG') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNYG2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'NYG') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsNYG2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'NYG')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNYG2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'NYG')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNYG2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'NYG')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# NYJ Special Plays Data Preparation

# Punts
puntsNYJ2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'NYJ') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNYJ2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'NYJ') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsNYJ2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'NYJ') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsNYJ2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'NYJ')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNYJ2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'NYJ')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsNYJ2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'NYJ')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsNYJ2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'NYJ') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNYJ2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'NYJ') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsNYJ2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'NYJ') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsNYJ2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'NYJ')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNYJ2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'NYJ')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsNYJ2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'NYJ')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# OAK Special Plays Data Preparation

# Punts
puntsOAK2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'OAK') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsOAK2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'OAK') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsOAK2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'LV') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsOAK2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'OAK')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsOAK2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'OAK')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsOAK2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'LV')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsOAK2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'OAK') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsOAK2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'OAK') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsOAK2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'LV') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsOAK2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'OAK')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsOAK2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'OAK')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsOAK2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'LV')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# PHI Special Plays Data Preparation

# Punts
puntsPHI2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'PHI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsPHI2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'PHI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsPHI2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'PHI') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsPHI2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'PHI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsPHI2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'PHI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsPHI2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'PHI')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsPHI2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'PHI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsPHI2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'PHI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsPHI2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'PHI') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsPHI2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'PHI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsPHI2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'PHI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsPHI2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'PHI')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# PIT Special Plays Data Preparation

# Punts
puntsPIT2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'PIT') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsPIT2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'PIT') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsPIT2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'PIT') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsPIT2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'PIT')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsPIT2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'PIT')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsPIT2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'PIT')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsPIT2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'PIT') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsPIT2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'PIT') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsPIT2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'PIT') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsPIT2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'PIT')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsPIT2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'PIT')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsPIT2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'PIT')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# SEA Special Plays Data Preparation

# Punts
puntsSEA2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'SEA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsSEA2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'SEA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsSEA2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'SEA') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsSEA2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'SEA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsSEA2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'SEA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsSEA2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'SEA')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsSEA2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'SEA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsSEA2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'SEA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsSEA2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'SEA') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsSEA2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'SEA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsSEA2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'SEA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsSEA2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'SEA')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# SF Special Plays Data Preparation

# Punts
puntsSF2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'SF') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsSF2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'SF') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsSF2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'SF') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsSF2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'SF')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsSF2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'SF')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsSF2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'SF')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsSF2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'SF') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsSF2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'SF') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsSF2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'SF') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsSF2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'SF')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsSF2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'SF')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsSF2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'SF')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# TB Special Plays Data Preparation

# Punts
puntsTB2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'TB') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsTB2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'TB') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsTB2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'TB') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsTB2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'TB')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsTB2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'TB')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsTB2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'TB')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsTB2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'TB') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsTB2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'TB') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsTB2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'TB') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsTB2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'TB')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsTB2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'TB')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsTB2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'TB')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
extraPointsTB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_ExtraPoint_2018.csv', index=False)
extraPointsTB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_ExtraPoint_2019.csv', index=False)
extraPointsTB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_ExtraPoint_2020.csv', index=False)

fieldGoalsTB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_FiledGoals_2018.csv', index=False)
fieldGoalsTB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_FiledGoals_2019.csv', index=False)
fieldGoalsTB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_FiledGoals_2020.csv', index=False)

kickoffsTB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_Kickoffs_2018.csv', index=False)
kickoffsTB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_Kickoffs_2019.csv', index=False)
kickoffsTB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_Kickoffs_2020.csv', index=False)

puntsTB2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_Punts_2018.csv', index=False)
puntsTB2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_Punts_2019.csv', index=False)
puntsTB2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/TampaBay/TB_Punts_2020.csv', index=False)

# %%
# TEN Special Plays Data Preparation

# Punts
puntsTEN2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'TEN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsTEN2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'TEN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsTEN2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'TEN') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsTEN2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'TEN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsTEN2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'TEN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsTEN2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'TEN')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsTEN2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'TEN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsTEN2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'TEN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsTEN2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'TEN') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsTEN2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'TEN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsTEN2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'TEN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsTEN2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'TEN')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
extraPointsTEN2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_ExtraPoint_2018.csv', index=False)
extraPointsTEN2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_ExtraPoint_2019.csv', index=False)
extraPointsTEN2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_ExtraPoint_2020.csv', index=False)

fieldGoalsTEN2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_FiledGoals_2018.csv', index=False)
fieldGoalsTEN2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_FiledGoals_2019.csv', index=False)
fieldGoalsTEN2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_FiledGoals_2020.csv', index=False)

kickoffsTEN2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_Kickoffs_2018.csv', index=False)
kickoffsTEN2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_Kickoffs_2019.csv', index=False)
kickoffsTEN2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_Kickoffs_2020.csv', index=False)

puntsTEN2018.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_Punts_2018.csv', index=False)
puntsTEN2019.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_Punts_2019.csv', index=False)
puntsTEN2020.to_csv(r'/Users/kushtrivedi/Desktop/NFL/Tennessee/TEN_Punts_2020.csv', index=False)

# %%
# WAS Special Plays Data Preparation

# Punts
puntsWAS2018 = task1DataFramePunts[(task1DataFramePunts.season == 2018 ) & (task1DataFramePunts.possessionTeam == 'WAS') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsWAS2019 = task1DataFramePunts[(task1DataFramePunts.season == 2019 ) & (task1DataFramePunts.possessionTeam == 'WAS') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]
puntsWAS2020 = task1DataFramePunts[(task1DataFramePunts.season == 2020 ) & (task1DataFramePunts.possessionTeam == 'WAS') 
                                   & (task1DataFramePunts.penaltyCodes == 0) 
                                   & (task1DataFramePunts.event != 'None')]

# Kickoffs
kickoffsWAS2018 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2018 ) & (task1DataFrameKickoffs.possessionTeam == 'WAS')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsWAS2019 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2019 ) & (task1DataFrameKickoffs.possessionTeam == 'WAS')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]
kickoffsWAS2020 = task1DataFrameKickoffs[(task1DataFrameKickoffs.season == 2020 ) & (task1DataFrameKickoffs.possessionTeam == 'WAS')
                                         & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                         & (task1DataFrameKickoffs.event != 'None')]

# Extra Points
extraPointsWAS2018 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2018 ) & (task1DataFrameExtrapoints.possessionTeam == 'WAS') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsWAS2019 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2019 ) & (task1DataFrameExtrapoints.possessionTeam == 'WAS') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]
extraPointsWAS2020 = task1DataFrameExtrapoints[(task1DataFrameExtrapoints.season == 2020 ) & (task1DataFrameExtrapoints.possessionTeam == 'WAS') 
                                           & (task1DataFrameExtrapoints.penaltyCodes == 0) 
                                           & (task1DataFrameExtrapoints.event != 'None')]

# Field Goals
fieldGoalsWAS2018 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2018 ) & (task1DataFrameFieldgoals.possessionTeam == 'WAS')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsWAS2019 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2019 ) & (task1DataFrameFieldgoals.possessionTeam == 'WAS')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]
fieldGoalsWAS2020 = task1DataFrameFieldgoals[(task1DataFrameFieldgoals.season == 2020 ) & (task1DataFrameFieldgoals.possessionTeam == 'WAS')  
                                         & (task1DataFrameFieldgoals.penaltyCodes == 0) 
                                         & (task1DataFrameFieldgoals.event != 'None')]

# %%
# ARI Special Plays Data Frames

# Punt Frames
ARIPuntsSeries2018 = puntsARI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
ARIPuntsFrame2018 = pd.DataFrame(ARIPuntsSeries2018)

ARIPuntsSeries2019 = puntsARI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
ARIPuntsFrame2019 = pd.DataFrame(ARIPuntsSeries2019)

ARIPuntsSeries2020 = puntsARI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
ARIPuntsFrame2020 = pd.DataFrame(ARIPuntsSeries2020)


# Kickoff Frames
ARIKickoffsSeries2018 = kickoffsARI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
ARIKickoffsFrame2018 = pd.DataFrame(ARIKickoffsSeries2018)

ARIKickoffsSeries2019 = kickoffsARI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
ARIKickoffsFrame2019 = pd.DataFrame(ARIKickoffsSeries2019)

ARIKickoffsSeries2020 = kickoffsARI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
ARIKickoffsFrame2020 = pd.DataFrame(ARIKickoffsSeries2020)


# Extra Points
ARIExtraPointsSeries2018 = extraPointsARI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
ARIExtraPointsFrame2018 = pd.DataFrame(ARIExtraPointsSeries2018)
ARIExtraPointsSeries2019 = extraPointsARI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
ARIExtraPointsFrame2019 = pd.DataFrame(ARIExtraPointsSeries2019)
ARIExtraPointsSeries2020 = extraPointsARI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
ARIExtraPointsFrame2020 = pd.DataFrame(ARIExtraPointsSeries2020)


# Field Goals
ARIFiledGoalsSeries2018 = fieldGoalsARI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
ARIFiledGoalsFrame2018 = pd.DataFrame(ARIFiledGoalsSeries2018)
ARIFiledGoalsSeries2019 = fieldGoalsARI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
ARIFiledGoalsFrame2019 = pd.DataFrame(ARIFiledGoalsSeries2019)
ARIFiledGoalsSeries2020 = fieldGoalsARI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
ARIFiledGoalsFrame2020 = pd.DataFrame(ARIFiledGoalsSeries2020)

# %%
# ATL Special Plays Data Frames

# Punt Frames
ATLPuntsSeries2018 = puntsATL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
ATLPuntsFrame2018 = pd.DataFrame(ATLPuntsSeries2018)

ATLPuntsSeries2019 = puntsATL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
ATLPuntsFrame2019 = pd.DataFrame(ATLPuntsSeries2019)

ATLPuntsSeries2020 = puntsATL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
ATLPuntsFrame2020 = pd.DataFrame(ATLPuntsSeries2020)


# Kickoff Frames
ATLKickoffsSeries2018 = kickoffsATL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
ATLKickoffsFrame2018 = pd.DataFrame(ATLKickoffsSeries2018)

ATLKickoffsSeries2019 = kickoffsATL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
ATLKickoffsFrame2019 = pd.DataFrame(ATLKickoffsSeries2019)

ATLKickoffsSeries2020 = kickoffsATL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
ATLKickoffsFrame2020 = pd.DataFrame(ATLKickoffsSeries2020)


# Extra Points
ATLExtraPointsSeries2018 = extraPointsATL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
ATLExtraPointsFrame2018 = pd.DataFrame(ATLExtraPointsSeries2018)
ATLExtraPointsSeries2019 = extraPointsATL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
ATLExtraPointsFrame2019 = pd.DataFrame(ATLExtraPointsSeries2019)
ATLExtraPointsSeries2020 = extraPointsATL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
ATLExtraPointsFrame2020 = pd.DataFrame(ATLExtraPointsSeries2020)


# Field Goals
ATLFiledGoalsSeries2018 = fieldGoalsATL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
ATLFiledGoalsFrame2018 = pd.DataFrame(ATLFiledGoalsSeries2018)
ATLFiledGoalsSeries2019 = fieldGoalsATL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
ATLFiledGoalsFrame2019 = pd.DataFrame(ATLFiledGoalsSeries2019)
ATLFiledGoalsSeries2020 = fieldGoalsATL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
ATLFiledGoalsFrame2020 = pd.DataFrame(ATLFiledGoalsSeries2020)

# %%
# BAL Special Plays Data Frames

# Punt Frames
BALPuntsSeries2018 = puntsBAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
BALPuntsFrame2018 = pd.DataFrame(BALPuntsSeries2018)

BALPuntsSeries2019 = puntsBAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
BALPuntsFrame2019 = pd.DataFrame(BALPuntsSeries2019)

BALPuntsSeries2020 = puntsBAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
BALPuntsFrame2020 = pd.DataFrame(BALPuntsSeries2020)


# Kickoff Frames
BALKickoffsSeries2018 = kickoffsBAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
BALKickoffsFrame2018 = pd.DataFrame(BALKickoffsSeries2018)

BALKickoffsSeries2019 = kickoffsBAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
BALKickoffsFrame2019 = pd.DataFrame(BALKickoffsSeries2019)

BALKickoffsSeries2020 = kickoffsBAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
BALKickoffsFrame2020 = pd.DataFrame(BALKickoffsSeries2020)


# Extra Points
BALExtraPointsSeries2018 = extraPointsBAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
BALExtraPointsFrame2018 = pd.DataFrame(BALExtraPointsSeries2018)
BALExtraPointsSeries2019 = extraPointsBAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
BALExtraPointsFrame2019 = pd.DataFrame(BALExtraPointsSeries2019)
BALExtraPointsSeries2020 = extraPointsBAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
BALExtraPointsFrame2020 = pd.DataFrame(BALExtraPointsSeries2020)


# Field Goals
BALFiledGoalsSeries2018 = fieldGoalsBAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
BALFiledGoalsFrame2018 = pd.DataFrame(BALFiledGoalsSeries2018)
BALFiledGoalsSeries2019 = fieldGoalsBAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
BALFiledGoalsFrame2019 = pd.DataFrame(BALFiledGoalsSeries2019)
BALFiledGoalsSeries2020 = fieldGoalsBAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
BALFiledGoalsFrame2020 = pd.DataFrame(BALFiledGoalsSeries2020)

# %%
# BUF Special Plays Data Frames

# Punt Frames
BUFPuntsSeries2018 = puntsBUF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
BUFPuntsFrame2018 = pd.DataFrame(BUFPuntsSeries2018)

BUFPuntsSeries2019 = puntsBUF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
BUFPuntsFrame2019 = pd.DataFrame(BUFPuntsSeries2019)

BUFPuntsSeries2020 = puntsBUF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
BUFPuntsFrame2020 = pd.DataFrame(BUFPuntsSeries2020)


# Kickoff Frames
BUFKickoffsSeries2018 = kickoffsBUF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
BUFKickoffsFrame2018 = pd.DataFrame(BUFKickoffsSeries2018)

BUFKickoffsSeries2019 = kickoffsBUF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
BUFKickoffsFrame2019 = pd.DataFrame(BUFKickoffsSeries2019)

BUFKickoffsSeries2020 = kickoffsBUF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
BUFKickoffsFrame2020 = pd.DataFrame(BUFKickoffsSeries2020)


# Extra Points
BUFExtraPointsSeries2018 = extraPointsBUF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
BUFExtraPointsFrame2018 = pd.DataFrame(BUFExtraPointsSeries2018)
BUFExtraPointsSeries2019 = extraPointsBUF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
BUFExtraPointsFrame2019 = pd.DataFrame(BUFExtraPointsSeries2019)
BUFExtraPointsSeries2020 = extraPointsBUF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
BUFExtraPointsFrame2020 = pd.DataFrame(BUFExtraPointsSeries2020)


# Field Goals
BUFFiledGoalsSeries2018 = fieldGoalsBUF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
BUFFiledGoalsFrame2018 = pd.DataFrame(BUFFiledGoalsSeries2018)
BUFFiledGoalsSeries2019 = fieldGoalsBUF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
BUFFiledGoalsFrame2019 = pd.DataFrame(BUFFiledGoalsSeries2019)
BUFFiledGoalsSeries2020 = fieldGoalsBUF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
BUFFiledGoalsFrame2020 = pd.DataFrame(BUFFiledGoalsSeries2020)

# %%
# CAR Special Plays Data Frames

# Punt Frames
CARPuntsSeries2018 = puntsCAR2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
CARPuntsFrame2018 = pd.DataFrame(CARPuntsSeries2018)

CARPuntsSeries2019 = puntsCAR2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CARPuntsFrame2019 = pd.DataFrame(CARPuntsSeries2019)

CARPuntsSeries2020 = puntsCAR2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CARPuntsFrame2020 = pd.DataFrame(CARPuntsSeries2020)


# Kickoff Frames
CARKickoffsSeries2018 = kickoffsCAR2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CARKickoffsFrame2018 = pd.DataFrame(CARKickoffsSeries2018)

CARKickoffsSeries2019 = kickoffsCAR2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CARKickoffsFrame2019 = pd.DataFrame(CARKickoffsSeries2019)

CARKickoffsSeries2020 = kickoffsCAR2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CARKickoffsFrame2020 = pd.DataFrame(CARKickoffsSeries2020)


# Extra Points
CARExtraPointsSeries2018 = extraPointsCAR2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CARExtraPointsFrame2018 = pd.DataFrame(CARExtraPointsSeries2018)
CARExtraPointsSeries2019 = extraPointsCAR2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CARExtraPointsFrame2019 = pd.DataFrame(CARExtraPointsSeries2019)
CARExtraPointsSeries2020 = extraPointsCAR2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CARExtraPointsFrame2020 = pd.DataFrame(CARExtraPointsSeries2020)


# Field Goals
CARFiledGoalsSeries2018 = fieldGoalsCAR2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CARFiledGoalsFrame2018 = pd.DataFrame(CARFiledGoalsSeries2018)
CARFiledGoalsSeries2019 = fieldGoalsCAR2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CARFiledGoalsFrame2019 = pd.DataFrame(CARFiledGoalsSeries2019)
CARFiledGoalsSeries2020 = fieldGoalsCAR2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CARFiledGoalsFrame2020 = pd.DataFrame(CARFiledGoalsSeries2020)

# %%
# CHI Special Plays Data Frames

# Punt Frames
CHIPuntsSeries2018 = puntsCHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
CHIPuntsFrame2018 = pd.DataFrame(CHIPuntsSeries2018)

CHIPuntsSeries2019 = puntsCHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CHIPuntsFrame2019 = pd.DataFrame(CHIPuntsSeries2019)

CHIPuntsSeries2020 = puntsCHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CHIPuntsFrame2020 = pd.DataFrame(CHIPuntsSeries2020)


# Kickoff Frames
CHIKickoffsSeries2018 = kickoffsCHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CHIKickoffsFrame2018 = pd.DataFrame(CHIKickoffsSeries2018)

CHIKickoffsSeries2019 = kickoffsCHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CHIKickoffsFrame2019 = pd.DataFrame(CHIKickoffsSeries2019)

CHIKickoffsSeries2020 = kickoffsCHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CHIKickoffsFrame2020 = pd.DataFrame(CHIKickoffsSeries2020)


# Extra Points
CHIExtraPointsSeries2018 = extraPointsCHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CHIExtraPointsFrame2018 = pd.DataFrame(CHIExtraPointsSeries2018)
CHIExtraPointsSeries2019 = extraPointsCHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CHIExtraPointsFrame2019 = pd.DataFrame(CHIExtraPointsSeries2019)
CHIExtraPointsSeries2020 = extraPointsCHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CHIExtraPointsFrame2020 = pd.DataFrame(CHIExtraPointsSeries2020)


# Field Goals
CHIFiledGoalsSeries2018 = fieldGoalsCHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CHIFiledGoalsFrame2018 = pd.DataFrame(CHIFiledGoalsSeries2018)
CHIFiledGoalsSeries2019 = fieldGoalsCHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CHIFiledGoalsFrame2019 = pd.DataFrame(CHIFiledGoalsSeries2019)
CHIFiledGoalsSeries2020 = fieldGoalsCHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CHIFiledGoalsFrame2020 = pd.DataFrame(CHIFiledGoalsSeries2020)

# %%
# CIN Special Plays Data Frames

# Punt Frames
CINPuntsSeries2018 = puntsCIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
CINPuntsFrame2018 = pd.DataFrame(CINPuntsSeries2018)

CINPuntsSeries2019 = puntsCIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CINPuntsFrame2019 = pd.DataFrame(CINPuntsSeries2019)

CINPuntsSeries2020 = puntsCIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CINPuntsFrame2020 = pd.DataFrame(CINPuntsSeries2020)


# Kickoff Frames
CINKickoffsSeries2018 = kickoffsCIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CINKickoffsFrame2018 = pd.DataFrame(CINKickoffsSeries2018)

CINKickoffsSeries2019 = kickoffsCIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CINKickoffsFrame2019 = pd.DataFrame(CINKickoffsSeries2019)

CINKickoffsSeries2020 = kickoffsCIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CINKickoffsFrame2020 = pd.DataFrame(CINKickoffsSeries2020)


# Extra Points
CINExtraPointsSeries2018 = extraPointsCIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CINExtraPointsFrame2018 = pd.DataFrame(CINExtraPointsSeries2018)
CINExtraPointsSeries2019 = extraPointsCIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CINExtraPointsFrame2019 = pd.DataFrame(CINExtraPointsSeries2019)
CINExtraPointsSeries2020 = extraPointsCIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CINExtraPointsFrame2020 = pd.DataFrame(CINExtraPointsSeries2020)


# Field Goals
CINFiledGoalsSeries2018 = fieldGoalsCIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CINFiledGoalsFrame2018 = pd.DataFrame(CINFiledGoalsSeries2018)
CINFiledGoalsSeries2019 = fieldGoalsCIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CINFiledGoalsFrame2019 = pd.DataFrame(CINFiledGoalsSeries2019)
CINFiledGoalsSeries2020 = fieldGoalsCIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CINFiledGoalsFrame2020 = pd.DataFrame(CINFiledGoalsSeries2020)

# %%
# CLE Special Plays Data Frames

# Punt Frames
CLEPuntsSeries2018 = puntsCLE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
CLEPuntsFrame2018 = pd.DataFrame(CLEPuntsSeries2018)

CLEPuntsSeries2019 = puntsCLE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CLEPuntsFrame2019 = pd.DataFrame(CLEPuntsSeries2019)

CLEPuntsSeries2020 = puntsCLE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
CLEPuntsFrame2020 = pd.DataFrame(CLEPuntsSeries2020)


# Kickoff Frames
CLEKickoffsSeries2018 = kickoffsCLE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CLEKickoffsFrame2018 = pd.DataFrame(CLEKickoffsSeries2018)

CLEKickoffsSeries2019 = kickoffsCLE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CLEKickoffsFrame2019 = pd.DataFrame(CLEKickoffsSeries2019)

CLEKickoffsSeries2020 = kickoffsCLE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
CLEKickoffsFrame2020 = pd.DataFrame(CLEKickoffsSeries2020)


# Extra Points
CLEExtraPointsSeries2018 = extraPointsCLE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CLEExtraPointsFrame2018 = pd.DataFrame(CLEExtraPointsSeries2018)
CLEExtraPointsSeries2019 = extraPointsCLE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CLEExtraPointsFrame2019 = pd.DataFrame(CLEExtraPointsSeries2019)
CLEExtraPointsSeries2020 = extraPointsCLE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
CLEExtraPointsFrame2020 = pd.DataFrame(CLEExtraPointsSeries2020)


# Field Goals
CLEFiledGoalsSeries2018 = fieldGoalsCLE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CLEFiledGoalsFrame2018 = pd.DataFrame(CLEFiledGoalsSeries2018)
CLEFiledGoalsSeries2019 = fieldGoalsCLE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CLEFiledGoalsFrame2019 = pd.DataFrame(CLEFiledGoalsSeries2019)
CLEFiledGoalsSeries2020 = fieldGoalsCLE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
CLEFiledGoalsFrame2020 = pd.DataFrame(CLEFiledGoalsSeries2020)

# %%
# DAL Special Plays Data Frames

# Punt Frames
DALPuntsSeries2018 = puntsDAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
DALPuntsFrame2018 = pd.DataFrame(DALPuntsSeries2018)

DALPuntsSeries2019 = puntsDAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
DALPuntsFrame2019 = pd.DataFrame(DALPuntsSeries2019)

DALPuntsSeries2020 = puntsDAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
DALPuntsFrame2020 = pd.DataFrame(DALPuntsSeries2020)


# Kickoff Frames
DALKickoffsSeries2018 = kickoffsDAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DALKickoffsFrame2018 = pd.DataFrame(DALKickoffsSeries2018)

DALKickoffsSeries2019 = kickoffsDAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DALKickoffsFrame2019 = pd.DataFrame(DALKickoffsSeries2019)

DALKickoffsSeries2020 = kickoffsDAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DALKickoffsFrame2020 = pd.DataFrame(DALKickoffsSeries2020)


# Extra Points
DALExtraPointsSeries2018 = extraPointsDAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DALExtraPointsFrame2018 = pd.DataFrame(DALExtraPointsSeries2018)
DALExtraPointsSeries2019 = extraPointsDAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DALExtraPointsFrame2019 = pd.DataFrame(DALExtraPointsSeries2019)
DALExtraPointsSeries2020 = extraPointsDAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DALExtraPointsFrame2020 = pd.DataFrame(DALExtraPointsSeries2020)


# Field Goals
DALFiledGoalsSeries2018 = fieldGoalsDAL2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DALFiledGoalsFrame2018 = pd.DataFrame(DALFiledGoalsSeries2018)
DALFiledGoalsSeries2019 = fieldGoalsDAL2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DALFiledGoalsFrame2019 = pd.DataFrame(DALFiledGoalsSeries2019)
DALFiledGoalsSeries2020 = fieldGoalsDAL2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DALFiledGoalsFrame2020 = pd.DataFrame(DALFiledGoalsSeries2020)

# %%
# DEN Special Plays Data Frames

# Punt Frames
DENPuntsSeries2018 = puntsDEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
DENPuntsFrame2018 = pd.DataFrame(DENPuntsSeries2018)

DENPuntsSeries2019 = puntsDEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
DENPuntsFrame2019 = pd.DataFrame(DENPuntsSeries2019)

DENPuntsSeries2020 = puntsDEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
DENPuntsFrame2020 = pd.DataFrame(DENPuntsSeries2020)


# Kickoff Frames
DENKickoffsSeries2018 = kickoffsDEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DENKickoffsFrame2018 = pd.DataFrame(DENKickoffsSeries2018)

DENKickoffsSeries2019 = kickoffsDEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DENKickoffsFrame2019 = pd.DataFrame(DENKickoffsSeries2019)

DENKickoffsSeries2020 = kickoffsDEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DENKickoffsFrame2020 = pd.DataFrame(DENKickoffsSeries2020)


# Extra Points
DENExtraPointsSeries2018 = extraPointsDEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DENExtraPointsFrame2018 = pd.DataFrame(DENExtraPointsSeries2018)
DENExtraPointsSeries2019 = extraPointsDEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DENExtraPointsFrame2019 = pd.DataFrame(DENExtraPointsSeries2019)
DENExtraPointsSeries2020 = extraPointsDEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DENExtraPointsFrame2020 = pd.DataFrame(DENExtraPointsSeries2020)


# Field Goals
DENFiledGoalsSeries2018 = fieldGoalsDEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DENFiledGoalsFrame2018 = pd.DataFrame(DENFiledGoalsSeries2018)
DENFiledGoalsSeries2019 = fieldGoalsDEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DENFiledGoalsFrame2019 = pd.DataFrame(DENFiledGoalsSeries2019)
DENFiledGoalsSeries2020 = fieldGoalsDEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DENFiledGoalsFrame2020 = pd.DataFrame(DENFiledGoalsSeries2020)

# %%
# DET Special Plays Data Frames

# Punt Frames
DETPuntsSeries2018 = puntsDET2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
DETPuntsFrame2018 = pd.DataFrame(DETPuntsSeries2018)

DETPuntsSeries2019 = puntsDET2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
DETPuntsFrame2019 = pd.DataFrame(DETPuntsSeries2019)

DETPuntsSeries2020 = puntsDET2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
DETPuntsFrame2020 = pd.DataFrame(DETPuntsSeries2020)


# Kickoff Frames
DETKickoffsSeries2018 = kickoffsDET2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DETKickoffsFrame2018 = pd.DataFrame(DETKickoffsSeries2018)

DETKickoffsSeries2019 = kickoffsDET2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DETKickoffsFrame2019 = pd.DataFrame(DETKickoffsSeries2019)

DETKickoffsSeries2020 = kickoffsDET2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
DETKickoffsFrame2020 = pd.DataFrame(DETKickoffsSeries2020)


# Extra Points
DETExtraPointsSeries2018 = extraPointsDET2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DETExtraPointsFrame2018 = pd.DataFrame(DETExtraPointsSeries2018)
DETExtraPointsSeries2019 = extraPointsDET2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DETExtraPointsFrame2019 = pd.DataFrame(DETExtraPointsSeries2019)
DETExtraPointsSeries2020 = extraPointsDET2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
DETExtraPointsFrame2020 = pd.DataFrame(DETExtraPointsSeries2020)


# Field Goals
DETFiledGoalsSeries2018 = fieldGoalsDET2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DETFiledGoalsFrame2018 = pd.DataFrame(DETFiledGoalsSeries2018)
DETFiledGoalsSeries2019 = fieldGoalsDET2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DETFiledGoalsFrame2019 = pd.DataFrame(DETFiledGoalsSeries2019)
DETFiledGoalsSeries2020 = fieldGoalsDET2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
DETFiledGoalsFrame2020 = pd.DataFrame(DETFiledGoalsSeries2020)

# %%
# GB Special Plays Data Frames

# Punt Frames
GBPuntsSeries2018 = puntsGB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
GBPuntsFrame2018 = pd.DataFrame(GBPuntsSeries2018)

GBPuntsSeries2019 = puntsGB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
GBPuntsFrame2019 = pd.DataFrame(GBPuntsSeries2019)

GBPuntsSeries2020 = puntsGB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
GBPuntsFrame2020 = pd.DataFrame(GBPuntsSeries2020)


# Kickoff Frames
GBKickoffsSeries2018 = kickoffsGB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
GBKickoffsFrame2018 = pd.DataFrame(GBKickoffsSeries2018)

GBKickoffsSeries2019 = kickoffsGB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
GBKickoffsFrame2019 = pd.DataFrame(GBKickoffsSeries2019)

GBKickoffsSeries2020 = kickoffsGB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
GBKickoffsFrame2020 = pd.DataFrame(GBKickoffsSeries2020)


# Extra Points
GBExtraPointsSeries2018 = extraPointsGB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
GBExtraPointsFrame2018 = pd.DataFrame(GBExtraPointsSeries2018)
GBExtraPointsSeries2019 = extraPointsGB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
GBExtraPointsFrame2019 = pd.DataFrame(GBExtraPointsSeries2019)
GBExtraPointsSeries2020 = extraPointsGB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
GBExtraPointsFrame2020 = pd.DataFrame(GBExtraPointsSeries2020)


# Field Goals
GBFiledGoalsSeries2018 = fieldGoalsGB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
GBFiledGoalsFrame2018 = pd.DataFrame(GBFiledGoalsSeries2018)
GBFiledGoalsSeries2019 = fieldGoalsGB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
GBFiledGoalsFrame2019 = pd.DataFrame(GBFiledGoalsSeries2019)
GBFiledGoalsSeries2020 = fieldGoalsGB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
GBFiledGoalsFrame2020 = pd.DataFrame(GBFiledGoalsSeries2020)

# %%
# HOU Special Plays Data Frames

# Punt Frames
HOUPuntsSeries2018 = puntsHOU2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
HOUPuntsFrame2018 = pd.DataFrame(HOUPuntsSeries2018)

HOUPuntsSeries2019 = puntsHOU2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
HOUPuntsFrame2019 = pd.DataFrame(HOUPuntsSeries2019)

HOUPuntsSeries2020 = puntsHOU2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
HOUPuntsFrame2020 = pd.DataFrame(HOUPuntsSeries2020)


# Kickoff Frames
HOUKickoffsSeries2018 = kickoffsHOU2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
HOUKickoffsFrame2018 = pd.DataFrame(HOUKickoffsSeries2018)

HOUKickoffsSeries2019 = kickoffsHOU2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
HOUKickoffsFrame2019 = pd.DataFrame(HOUKickoffsSeries2019)

HOUKickoffsSeries2020 = kickoffsHOU2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
HOUKickoffsFrame2020 = pd.DataFrame(HOUKickoffsSeries2020)


# Extra Points
HOUExtraPointsSeries2018 = extraPointsHOU2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
HOUExtraPointsFrame2018 = pd.DataFrame(HOUExtraPointsSeries2018)
HOUExtraPointsSeries2019 = extraPointsHOU2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
HOUExtraPointsFrame2019 = pd.DataFrame(HOUExtraPointsSeries2019)
HOUExtraPointsSeries2020 = extraPointsHOU2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
HOUExtraPointsFrame2020 = pd.DataFrame(HOUExtraPointsSeries2020)


# Field Goals
HOUFiledGoalsSeries2018 = fieldGoalsHOU2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
HOUFiledGoalsFrame2018 = pd.DataFrame(HOUFiledGoalsSeries2018)
HOUFiledGoalsSeries2019 = fieldGoalsHOU2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
HOUFiledGoalsFrame2019 = pd.DataFrame(HOUFiledGoalsSeries2019)
HOUFiledGoalsSeries2020 = fieldGoalsHOU2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
HOUFiledGoalsFrame2020 = pd.DataFrame(HOUFiledGoalsSeries2020)

# %%
# IND Special Plays Data Frames

# Punt Frames
INDPuntsSeries2018 = puntsIND2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
INDPuntsFrame2018 = pd.DataFrame(INDPuntsSeries2018)

INDPuntsSeries2019 = puntsIND2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
INDPuntsFrame2019 = pd.DataFrame(INDPuntsSeries2019)

INDPuntsSeries2020 = puntsIND2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
INDPuntsFrame2020 = pd.DataFrame(INDPuntsSeries2020)


# Kickoff Frames
INDKickoffsSeries2018 = kickoffsIND2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
INDKickoffsFrame2018 = pd.DataFrame(INDKickoffsSeries2018)

INDKickoffsSeries2019 = kickoffsIND2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
INDKickoffsFrame2019 = pd.DataFrame(INDKickoffsSeries2019)

INDKickoffsSeries2020 = kickoffsIND2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
INDKickoffsFrame2020 = pd.DataFrame(INDKickoffsSeries2020)


# Extra Points
INDExtraPointsSeries2018 = extraPointsIND2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
INDExtraPointsFrame2018 = pd.DataFrame(INDExtraPointsSeries2018)
INDExtraPointsSeries2019 = extraPointsIND2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
INDExtraPointsFrame2019 = pd.DataFrame(INDExtraPointsSeries2019)
INDExtraPointsSeries2020 = extraPointsIND2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
INDExtraPointsFrame2020 = pd.DataFrame(INDExtraPointsSeries2020)


# Field Goals
INDFiledGoalsSeries2018 = fieldGoalsIND2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
INDFiledGoalsFrame2018 = pd.DataFrame(INDFiledGoalsSeries2018)
INDFiledGoalsSeries2019 = fieldGoalsIND2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
INDFiledGoalsFrame2019 = pd.DataFrame(INDFiledGoalsSeries2019)
INDFiledGoalsSeries2020 = fieldGoalsIND2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
INDFiledGoalsFrame2020 = pd.DataFrame(INDFiledGoalsSeries2020)

# %%
# JAX Special Plays Data Frames

# Punt Frames
JAXPuntsSeries2018 = puntsJAX2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
JAXPuntsFrame2018 = pd.DataFrame(JAXPuntsSeries2018)

JAXPuntsSeries2019 = puntsJAX2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
JAXPuntsFrame2019 = pd.DataFrame(JAXPuntsSeries2019)

JAXPuntsSeries2020 = puntsJAX2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
JAXPuntsFrame2020 = pd.DataFrame(JAXPuntsSeries2020)


# Kickoff Frames
JAXKickoffsSeries2018 = kickoffsJAX2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
JAXKickoffsFrame2018 = pd.DataFrame(JAXKickoffsSeries2018)

JAXKickoffsSeries2019 = kickoffsJAX2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
JAXKickoffsFrame2019 = pd.DataFrame(JAXKickoffsSeries2019)

JAXKickoffsSeries2020 = kickoffsJAX2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
JAXKickoffsFrame2020 = pd.DataFrame(JAXKickoffsSeries2020)


# Extra Points
JAXExtraPointsSeries2018 = extraPointsJAX2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
JAXExtraPointsFrame2018 = pd.DataFrame(JAXExtraPointsSeries2018)
JAXExtraPointsSeries2019 = extraPointsJAX2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
JAXExtraPointsFrame2019 = pd.DataFrame(JAXExtraPointsSeries2019)
JAXExtraPointsSeries2020 = extraPointsJAX2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
JAXExtraPointsFrame2020 = pd.DataFrame(JAXExtraPointsSeries2020)


# Field Goals
JAXFiledGoalsSeries2018 = fieldGoalsJAX2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
JAXFiledGoalsFrame2018 = pd.DataFrame(JAXFiledGoalsSeries2018)
JAXFiledGoalsSeries2019 = fieldGoalsJAX2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
JAXFiledGoalsFrame2019 = pd.DataFrame(JAXFiledGoalsSeries2019)
JAXFiledGoalsSeries2020 = fieldGoalsJAX2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
JAXFiledGoalsFrame2020 = pd.DataFrame(JAXFiledGoalsSeries2020)

# %%
# KC Special Plays Data Frames

# Punt Frames
KCPuntsSeries2018 = puntsKC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
KCPuntsFrame2018 = pd.DataFrame(KCPuntsSeries2018)

KCPuntsSeries2019 = puntsKC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
KCPuntsFrame2019 = pd.DataFrame(KCPuntsSeries2019)

KCPuntsSeries2020 = puntsKC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
KCPuntsFrame2020 = pd.DataFrame(KCPuntsSeries2020)


# Kickoff Frames
KCKickoffsSeries2018 = kickoffsKC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
KCKickoffsFrame2018 = pd.DataFrame(KCKickoffsSeries2018)

KCKickoffsSeries2019 = kickoffsKC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
KCKickoffsFrame2019 = pd.DataFrame(KCKickoffsSeries2019)

KCKickoffsSeries2020 = kickoffsKC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
KCKickoffsFrame2020 = pd.DataFrame(KCKickoffsSeries2020)


# Extra Points
KCExtraPointsSeries2018 = extraPointsKC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
KCExtraPointsFrame2018 = pd.DataFrame(KCExtraPointsSeries2018)
KCExtraPointsSeries2019 = extraPointsKC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
KCExtraPointsFrame2019 = pd.DataFrame(KCExtraPointsSeries2019)
KCExtraPointsSeries2020 = extraPointsKC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
KCExtraPointsFrame2020 = pd.DataFrame(KCExtraPointsSeries2020)


# Field Goals
KCFiledGoalsSeries2018 = fieldGoalsKC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
KCFiledGoalsFrame2018 = pd.DataFrame(KCFiledGoalsSeries2018)
KCFiledGoalsSeries2019 = fieldGoalsKC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
KCFiledGoalsFrame2019 = pd.DataFrame(KCFiledGoalsSeries2019)
KCFiledGoalsSeries2020 = fieldGoalsKC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
KCFiledGoalsFrame2020 = pd.DataFrame(KCFiledGoalsSeries2020)

# %%
# LA Special Plays Data Frames

# Punt Frames
LAPuntsSeries2018 = puntsLA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
LAPuntsFrame2018 = pd.DataFrame(LAPuntsSeries2018)

LAPuntsSeries2019 = puntsLA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
LAPuntsFrame2019 = pd.DataFrame(LAPuntsSeries2019)

LAPuntsSeries2020 = puntsLA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
LAPuntsFrame2020 = pd.DataFrame(LAPuntsSeries2020)


# Kickoff Frames
LAKickoffsSeries2018 = kickoffsLA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
LAKickoffsFrame2018 = pd.DataFrame(LAKickoffsSeries2018)

LAKickoffsSeries2019 = kickoffsLA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
LAKickoffsFrame2019 = pd.DataFrame(LAKickoffsSeries2019)

LAKickoffsSeries2020 = kickoffsLA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
LAKickoffsFrame2020 = pd.DataFrame(LAKickoffsSeries2020)


# Extra Points
LAExtraPointsSeries2018 = extraPointsLA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
LAExtraPointsFrame2018 = pd.DataFrame(LAExtraPointsSeries2018)
LAExtraPointsSeries2019 = extraPointsLA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
LAExtraPointsFrame2019 = pd.DataFrame(LAExtraPointsSeries2019)
LAExtraPointsSeries2020 = extraPointsLA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
LAExtraPointsFrame2020 = pd.DataFrame(LAExtraPointsSeries2020)


# Field Goals
LAFiledGoalsSeries2018 = fieldGoalsLA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
LAFiledGoalsFrame2018 = pd.DataFrame(LAFiledGoalsSeries2018)
LAFiledGoalsSeries2019 = fieldGoalsLA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
LAFiledGoalsFrame2019 = pd.DataFrame(LAFiledGoalsSeries2019)
LAFiledGoalsSeries2020 = fieldGoalsLA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
LAFiledGoalsFrame2020 = pd.DataFrame(LAFiledGoalsSeries2020)

# %%
# LAC Special Plays Data Frames

# Punt Frames
LACPuntsSeries2018 = puntsLAC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
LACPuntsFrame2018 = pd.DataFrame(LACPuntsSeries2018)

LACPuntsSeries2019 = puntsLAC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
LACPuntsFrame2019 = pd.DataFrame(LACPuntsSeries2019)

LACPuntsSeries2020 = puntsLAC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
LACPuntsFrame2020 = pd.DataFrame(LACPuntsSeries2020)


# Kickoff Frames
LACKickoffsSeries2018 = kickoffsLAC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
LACKickoffsFrame2018 = pd.DataFrame(LACKickoffsSeries2018)

LACKickoffsSeries2019 = kickoffsLAC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
LACKickoffsFrame2019 = pd.DataFrame(LACKickoffsSeries2019)

LACKickoffsSeries2020 = kickoffsLAC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
LACKickoffsFrame2020 = pd.DataFrame(LACKickoffsSeries2020)


# Extra Points
LACExtraPointsSeries2018 = extraPointsLAC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
LACExtraPointsFrame2018 = pd.DataFrame(LACExtraPointsSeries2018)
LACExtraPointsSeries2019 = extraPointsLAC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
LACExtraPointsFrame2019 = pd.DataFrame(LACExtraPointsSeries2019)
LACExtraPointsSeries2020 = extraPointsLAC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
LACExtraPointsFrame2020 = pd.DataFrame(LACExtraPointsSeries2020)


# Field Goals
LACFiledGoalsSeries2018 = fieldGoalsLAC2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
LACFiledGoalsFrame2018 = pd.DataFrame(LACFiledGoalsSeries2018)
LACFiledGoalsSeries2019 = fieldGoalsLAC2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
LACFiledGoalsFrame2019 = pd.DataFrame(LACFiledGoalsSeries2019)
LACFiledGoalsSeries2020 = fieldGoalsLAC2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
LACFiledGoalsFrame2020 = pd.DataFrame(LACFiledGoalsSeries2020)

# %%
# MIA Special Plays Data Frames

# Punt Frames
MIAPuntsSeries2018 = puntsMIA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
MIAPuntsFrame2018 = pd.DataFrame(MIAPuntsSeries2018)

MIAPuntsSeries2019 = puntsMIA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
MIAPuntsFrame2019 = pd.DataFrame(MIAPuntsSeries2019)

MIAPuntsSeries2020 = puntsMIA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
MIAPuntsFrame2020 = pd.DataFrame(MIAPuntsSeries2020)


# Kickoff Framesa
MIAKickoffsSeries2018 = kickoffsMIA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
MIAKickoffsFrame2018 = pd.DataFrame(MIAKickoffsSeries2018)

MIAKickoffsSeries2019 = kickoffsMIA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
MIAKickoffsFrame2019 = pd.DataFrame(MIAKickoffsSeries2019)

MIAKickoffsSeries2020 = kickoffsMIA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
MIAKickoffsFrame2020 = pd.DataFrame(MIAKickoffsSeries2020)


# Extra Points
MIAExtraPointsSeries2018 = extraPointsMIA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
MIAExtraPointsFrame2018 = pd.DataFrame(MIAExtraPointsSeries2018)
MIAExtraPointsSeries2019 = extraPointsMIA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
MIAExtraPointsFrame2019 = pd.DataFrame(MIAExtraPointsSeries2019)
MIAExtraPointsSeries2020 = extraPointsMIA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
MIAExtraPointsFrame2020 = pd.DataFrame(MIAExtraPointsSeries2020)


# Field Goals
MIAFiledGoalsSeries2018 = fieldGoalsMIA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
MIAFiledGoalsFrame2018 = pd.DataFrame(MIAFiledGoalsSeries2018)
MIAFiledGoalsSeries2019 = fieldGoalsMIA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
MIAFiledGoalsFrame2019 = pd.DataFrame(MIAFiledGoalsSeries2019)
MIAFiledGoalsSeries2020 = fieldGoalsMIA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
MIAFiledGoalsFrame2020 = pd.DataFrame(MIAFiledGoalsSeries2020)

# %%
# MIN Special Plays Data Frames

# Punt Frames
MINPuntsSeries2018 = puntsMIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
MINPuntsFrame2018 = pd.DataFrame(MINPuntsSeries2018)

MINPuntsSeries2019 = puntsMIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
MINPuntsFrame2019 = pd.DataFrame(MINPuntsSeries2019)

MINPuntsSeries2020 = puntsMIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
MINPuntsFrame2020 = pd.DataFrame(MINPuntsSeries2020)


# Kickoff Frames
MINKickoffsSeries2018 = kickoffsMIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
MINKickoffsFrame2018 = pd.DataFrame(MINKickoffsSeries2018)

MINKickoffsSeries2019 = kickoffsMIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
MINKickoffsFrame2019 = pd.DataFrame(MINKickoffsSeries2019)

MINKickoffsSeries2020 = kickoffsMIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
MINKickoffsFrame2020 = pd.DataFrame(MINKickoffsSeries2020)


# Extra Points
MINExtraPointsSeries2018 = extraPointsMIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
MINExtraPointsFrame2018 = pd.DataFrame(MINExtraPointsSeries2018)
MINExtraPointsSeries2019 = extraPointsMIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
MINExtraPointsFrame2019 = pd.DataFrame(MINExtraPointsSeries2019)
MINExtraPointsSeries2020 = extraPointsMIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
MINExtraPointsFrame2020 = pd.DataFrame(MINExtraPointsSeries2020)


# Field Goals
MINFiledGoalsSeries2018 = fieldGoalsMIN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
MINFiledGoalsFrame2018 = pd.DataFrame(MINFiledGoalsSeries2018)
MINFiledGoalsSeries2019 = fieldGoalsMIN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
MINFiledGoalsFrame2019 = pd.DataFrame(MINFiledGoalsSeries2019)
MINFiledGoalsSeries2020 = fieldGoalsMIN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
MINFiledGoalsFrame2020 = pd.DataFrame(MINFiledGoalsSeries2020)

# %%
# NE Special Plays Data Frames

# Punt Frames
NEPuntsSeries2018 = puntsNE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
NEPuntsFrame2018 = pd.DataFrame(NEPuntsSeries2018)

NEPuntsSeries2019 = puntsNE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NEPuntsFrame2019 = pd.DataFrame(NEPuntsSeries2019)

NEPuntsSeries2020 = puntsNE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NEPuntsFrame2020 = pd.DataFrame(NEPuntsSeries2020)


# Kickoff Frames
NEKickoffsSeries2018 = kickoffsNE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NEKickoffsFrame2018 = pd.DataFrame(NEKickoffsSeries2018)

NEKickoffsSeries2019 = kickoffsNE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NEKickoffsFrame2019 = pd.DataFrame(NEKickoffsSeries2019)

NEKickoffsSeries2020 = kickoffsNE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NEKickoffsFrame2020 = pd.DataFrame(NEKickoffsSeries2020)


# Extra Points
NEExtraPointsSeries2018 = extraPointsNE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NEExtraPointsFrame2018 = pd.DataFrame(NEExtraPointsSeries2018)
NEExtraPointsSeries2019 = extraPointsNE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NEExtraPointsFrame2019 = pd.DataFrame(NEExtraPointsSeries2019)
NEExtraPointsSeries2020 = extraPointsNE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NEExtraPointsFrame2020 = pd.DataFrame(NEExtraPointsSeries2020)


# Field Goals
NEFiledGoalsSeries2018 = fieldGoalsNE2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NEFiledGoalsFrame2018 = pd.DataFrame(NEFiledGoalsSeries2018)
NEFiledGoalsSeries2019 = fieldGoalsNE2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NEFiledGoalsFrame2019 = pd.DataFrame(NEFiledGoalsSeries2019)
NEFiledGoalsSeries2020 = fieldGoalsNE2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NEFiledGoalsFrame2020 = pd.DataFrame(NEFiledGoalsSeries2020)

# %%
# NO Special Plays Data Frames

# Punt Frames
NOPuntsSeries2018 = puntsNO2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
NOPuntsFrame2018 = pd.DataFrame(NOPuntsSeries2018)

NOPuntsSeries2019 = puntsNO2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NOPuntsFrame2019 = pd.DataFrame(NOPuntsSeries2019)

NOPuntsSeries2020 = puntsNO2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NOPuntsFrame2020 = pd.DataFrame(NOPuntsSeries2020)


# Kickoff Frames
NOKickoffsSeries2018 = kickoffsNO2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NOKickoffsFrame2018 = pd.DataFrame(NOKickoffsSeries2018)

NOKickoffsSeries2019 = kickoffsNO2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NOKickoffsFrame2019 = pd.DataFrame(NOKickoffsSeries2019)

NOKickoffsSeries2020 = kickoffsNO2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NOKickoffsFrame2020 = pd.DataFrame(NOKickoffsSeries2020)


# Extra Points
NOExtraPointsSeries2018 = extraPointsNO2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NOExtraPointsFrame2018 = pd.DataFrame(NOExtraPointsSeries2018)
NOExtraPointsSeries2019 = extraPointsNO2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NOExtraPointsFrame2019 = pd.DataFrame(NOExtraPointsSeries2019)
NOExtraPointsSeries2020 = extraPointsNO2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NOExtraPointsFrame2020 = pd.DataFrame(NOExtraPointsSeries2020)


# Field Goals
NOFiledGoalsSeries2018 = fieldGoalsNO2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NOFiledGoalsFrame2018 = pd.DataFrame(NOFiledGoalsSeries2018)
NOFiledGoalsSeries2019 = fieldGoalsNO2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NOFiledGoalsFrame2019 = pd.DataFrame(NOFiledGoalsSeries2019)
NOFiledGoalsSeries2020 = fieldGoalsNO2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NOFiledGoalsFrame2020 = pd.DataFrame(NOFiledGoalsSeries2020)

# %%
# NYG Special Plays Data Frames

# Punt Frames
NYGPuntsSeries2018 = puntsNYG2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
NYGPuntsFrame2018 = pd.DataFrame(NYGPuntsSeries2018)

NYGPuntsSeries2019 = puntsNYG2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NYGPuntsFrame2019 = pd.DataFrame(NYGPuntsSeries2019)

NYGPuntsSeries2020 = puntsNYG2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NYGPuntsFrame2020 = pd.DataFrame(NYGPuntsSeries2020)


# Kickoff Frames
NYGKickoffsSeries2018 = kickoffsNYG2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NYGKickoffsFrame2018 = pd.DataFrame(NYGKickoffsSeries2018)

NYGKickoffsSeries2019 = kickoffsNYG2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NYGKickoffsFrame2019 = pd.DataFrame(NYGKickoffsSeries2019)

NYGKickoffsSeries2020 = kickoffsNYG2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NYGKickoffsFrame2020 = pd.DataFrame(NYGKickoffsSeries2020)


# Extra Points
NYGExtraPointsSeries2018 = extraPointsNYG2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NYGExtraPointsFrame2018 = pd.DataFrame(NYGExtraPointsSeries2018)
NYGExtraPointsSeries2019 = extraPointsNYG2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NYGExtraPointsFrame2019 = pd.DataFrame(NYGExtraPointsSeries2019)
NYGExtraPointsSeries2020 = extraPointsNYG2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NYGExtraPointsFrame2020 = pd.DataFrame(NYGExtraPointsSeries2020)


# Field Goals
NYGFiledGoalsSeries2018 = fieldGoalsNYG2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NYGFiledGoalsFrame2018 = pd.DataFrame(NYGFiledGoalsSeries2018)
NYGFiledGoalsSeries2019 = fieldGoalsNYG2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NYGFiledGoalsFrame2019 = pd.DataFrame(NYGFiledGoalsSeries2019)
NYGFiledGoalsSeries2020 = fieldGoalsNYG2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NYGFiledGoalsFrame2020 = pd.DataFrame(NYGFiledGoalsSeries2020)

# %%
# NYJ Special Plays Data Frames

# Punt Frames
NYJPuntsSeries2018 = puntsNYJ2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
NYJPuntsFrame2018 = pd.DataFrame(NYJPuntsSeries2018)

NYJPuntsSeries2019 = puntsNYJ2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NYJPuntsFrame2019 = pd.DataFrame(NYJPuntsSeries2019)

NYJPuntsSeries2020 = puntsNYJ2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
NYJPuntsFrame2020 = pd.DataFrame(NYJPuntsSeries2020)


# Kickoff Frames
NYJKickoffsSeries2018 = kickoffsNYJ2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NYJKickoffsFrame2018 = pd.DataFrame(NYJKickoffsSeries2018)

NYJKickoffsSeries2019 = kickoffsNYJ2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NYJKickoffsFrame2019 = pd.DataFrame(NYJKickoffsSeries2019)

NYJKickoffsSeries2020 = kickoffsNYJ2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
NYJKickoffsFrame2020 = pd.DataFrame(NYJKickoffsSeries2020)


# Extra Points
NYJExtraPointsSeries2018 = extraPointsNYJ2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NYJExtraPointsFrame2018 = pd.DataFrame(NYJExtraPointsSeries2018)
NYJExtraPointsSeries2019 = extraPointsNYJ2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NYJExtraPointsFrame2019 = pd.DataFrame(NYJExtraPointsSeries2019)
NYJExtraPointsSeries2020 = extraPointsNYJ2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
NYJExtraPointsFrame2020 = pd.DataFrame(NYJExtraPointsSeries2020)


# Field Goals
NYJFiledGoalsSeries2018 = fieldGoalsNYJ2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NYJFiledGoalsFrame2018 = pd.DataFrame(NYJFiledGoalsSeries2018)
NYJFiledGoalsSeries2019 = fieldGoalsNYJ2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NYJFiledGoalsFrame2019 = pd.DataFrame(NYJFiledGoalsSeries2019)
NYJFiledGoalsSeries2020 = fieldGoalsNYJ2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
NYJFiledGoalsFrame2020 = pd.DataFrame(NYJFiledGoalsSeries2020)

# %%
# OAK Special Plays Data Frames

# Punt Frames
OAKPuntsSeries2018 = puntsOAK2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
OAKPuntsFrame2018 = pd.DataFrame(OAKPuntsSeries2018)

OAKPuntsSeries2019 = puntsOAK2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
OAKPuntsFrame2019 = pd.DataFrame(OAKPuntsSeries2019)

OAKPuntsSeries2020 = puntsOAK2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
OAKPuntsFrame2020 = pd.DataFrame(OAKPuntsSeries2020)


# Kickoff Frames
OAKKickoffsSeries2018 = kickoffsOAK2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
OAKKickoffsFrame2018 = pd.DataFrame(OAKKickoffsSeries2018)

OAKKickoffsSeries2019 = kickoffsOAK2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
OAKKickoffsFrame2019 = pd.DataFrame(OAKKickoffsSeries2019)

OAKKickoffsSeries2020 = kickoffsOAK2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
OAKKickoffsFrame2020 = pd.DataFrame(OAKKickoffsSeries2020)


# Extra Points
OAKExtraPointsSeries2018 = extraPointsOAK2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
OAKExtraPointsFrame2018 = pd.DataFrame(OAKExtraPointsSeries2018)
OAKExtraPointsSeries2019 = extraPointsOAK2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
OAKExtraPointsFrame2019 = pd.DataFrame(OAKExtraPointsSeries2019)
OAKExtraPointsSeries2020 = extraPointsOAK2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
OAKExtraPointsFrame2020 = pd.DataFrame(OAKExtraPointsSeries2020)


# Field Goals
OAKFiledGoalsSeries2018 = fieldGoalsOAK2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
OAKFiledGoalsFrame2018 = pd.DataFrame(OAKFiledGoalsSeries2018)
OAKFiledGoalsSeries2019 = fieldGoalsOAK2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
OAKFiledGoalsFrame2019 = pd.DataFrame(OAKFiledGoalsSeries2019)
OAKFiledGoalsSeries2020 = fieldGoalsOAK2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
OAKFiledGoalsFrame2020 = pd.DataFrame(OAKFiledGoalsSeries2020)

# %%
# PHI Special Plays Data Frames

# Punt Frames
PHIPuntsSeries2018 = puntsPHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
PHIPuntsFrame2018 = pd.DataFrame(PHIPuntsSeries2018)

PHIPuntsSeries2019 = puntsPHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
PHIPuntsFrame2019 = pd.DataFrame(PHIPuntsSeries2019)

PHIPuntsSeries2020 = puntsPHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
PHIPuntsFrame2020 = pd.DataFrame(PHIPuntsSeries2020)


# Kickoff Frames
PHIKickoffsSeries2018 = kickoffsPHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
PHIKickoffsFrame2018 = pd.DataFrame(PHIKickoffsSeries2018)

PHIKickoffsSeries2019 = kickoffsPHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
PHIKickoffsFrame2019 = pd.DataFrame(PHIKickoffsSeries2019)

PHIKickoffsSeries2020 = kickoffsPHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
PHIKickoffsFrame2020 = pd.DataFrame(PHIKickoffsSeries2020)


# Extra Points
PHIExtraPointsSeries2018 = extraPointsPHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
PHIExtraPointsFrame2018 = pd.DataFrame(PHIExtraPointsSeries2018)
PHIExtraPointsSeries2019 = extraPointsPHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
PHIExtraPointsFrame2019 = pd.DataFrame(PHIExtraPointsSeries2019)
PHIExtraPointsSeries2020 = extraPointsPHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
PHIExtraPointsFrame2020 = pd.DataFrame(PHIExtraPointsSeries2020)


# Field Goals
PHIFiledGoalsSeries2018 = fieldGoalsPHI2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
PHIFiledGoalsFrame2018 = pd.DataFrame(PHIFiledGoalsSeries2018)
PHIFiledGoalsSeries2019 = fieldGoalsPHI2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
PHIFiledGoalsFrame2019 = pd.DataFrame(PHIFiledGoalsSeries2019)
PHIFiledGoalsSeries2020 = fieldGoalsPHI2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
PHIFiledGoalsFrame2020 = pd.DataFrame(PHIFiledGoalsSeries2020)

# %%
# PIT Special Plays Data Frames

# Punt Frames
PITPuntsSeries2018 = puntsPIT2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
PITPuntsFrame2018 = pd.DataFrame(PITPuntsSeries2018)

PITPuntsSeries2019 = puntsPIT2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
PITPuntsFrame2019 = pd.DataFrame(PITPuntsSeries2019)

PITPuntsSeries2020 = puntsPIT2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
PITPuntsFrame2020 = pd.DataFrame(PITPuntsSeries2020)


# Kickoff Frames
PITKickoffsSeries2018 = kickoffsPIT2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
PITKickoffsFrame2018 = pd.DataFrame(PITKickoffsSeries2018)

PITKickoffsSeries2019 = kickoffsPIT2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
PITKickoffsFrame2019 = pd.DataFrame(PITKickoffsSeries2019)

PITKickoffsSeries2020 = kickoffsPIT2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
PITKickoffsFrame2020 = pd.DataFrame(PITKickoffsSeries2020)


# Extra Points
PITExtraPointsSeries2018 = extraPointsPIT2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
PITExtraPointsFrame2018 = pd.DataFrame(PITExtraPointsSeries2018)
PITExtraPointsSeries2019 = extraPointsPIT2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
PITExtraPointsFrame2019 = pd.DataFrame(PITExtraPointsSeries2019)
PITExtraPointsSeries2020 = extraPointsPIT2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
PITExtraPointsFrame2020 = pd.DataFrame(PITExtraPointsSeries2020)


# Field Goals
PITFiledGoalsSeries2018 = fieldGoalsPIT2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
PITFiledGoalsFrame2018 = pd.DataFrame(PITFiledGoalsSeries2018)
PITFiledGoalsSeries2019 = fieldGoalsPIT2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
PITFiledGoalsFrame2019 = pd.DataFrame(PITFiledGoalsSeries2019)
PITFiledGoalsSeries2020 = fieldGoalsPIT2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
PITFiledGoalsFrame2020 = pd.DataFrame(PITFiledGoalsSeries2020)

# %%
# SEA Special Plays Data Frames

# Punt Frames
SEAPuntsSeries2018 = puntsSEA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
SEAPuntsFrame2018 = pd.DataFrame(SEAPuntsSeries2018)

SEAPuntsSeries2019 = puntsSEA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
SEAPuntsFrame2019 = pd.DataFrame(SEAPuntsSeries2019)

SEAPuntsSeries2020 = puntsSEA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
SEAPuntsFrame2020 = pd.DataFrame(SEAPuntsSeries2020)


# Kickoff Frames
SEAKickoffsSeries2018 = kickoffsSEA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
SEAKickoffsFrame2018 = pd.DataFrame(SEAKickoffsSeries2018)

SEAKickoffsSeries2019 = kickoffsSEA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
SEAKickoffsFrame2019 = pd.DataFrame(SEAKickoffsSeries2019)

SEAKickoffsSeries2020 = kickoffsSEA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
SEAKickoffsFrame2020 = pd.DataFrame(SEAKickoffsSeries2020)


# Extra Points
SEAExtraPointsSeries2018 = extraPointsSEA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
SEAExtraPointsFrame2018 = pd.DataFrame(SEAExtraPointsSeries2018)
SEAExtraPointsSeries2019 = extraPointsSEA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
SEAExtraPointsFrame2019 = pd.DataFrame(SEAExtraPointsSeries2019)
SEAExtraPointsSeries2020 = extraPointsSEA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
SEAExtraPointsFrame2020 = pd.DataFrame(SEAExtraPointsSeries2020)


# Field Goals
SEAFiledGoalsSeries2018 = fieldGoalsSEA2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
SEAFiledGoalsFrame2018 = pd.DataFrame(SEAFiledGoalsSeries2018)
SEAFiledGoalsSeries2019 = fieldGoalsSEA2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
SEAFiledGoalsFrame2019 = pd.DataFrame(SEAFiledGoalsSeries2019)
SEAFiledGoalsSeries2020 = fieldGoalsSEA2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
SEAFiledGoalsFrame2020 = pd.DataFrame(SEAFiledGoalsSeries2020)

# %%
# SF Special Plays Data Frames

# Punt Frames
SFPuntsSeries2018 = puntsSF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
SFPuntsFrame2018 = pd.DataFrame(SFPuntsSeries2018)

SFPuntsSeries2019 = puntsSF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
SFPuntsFrame2019 = pd.DataFrame(SFPuntsSeries2019)

SFPuntsSeries2020 = puntsSF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
SFPuntsFrame2020 = pd.DataFrame(SFPuntsSeries2020)


# Kickoff Frames
SFKickoffsSeries2018 = kickoffsSF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
SFKickoffsFrame2018 = pd.DataFrame(SFKickoffsSeries2018)

SFKickoffsSeries2019 = kickoffsSF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
SFKickoffsFrame2019 = pd.DataFrame(SFKickoffsSeries2019)

SFKickoffsSeries2020 = kickoffsSF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
SFKickoffsFrame2020 = pd.DataFrame(SFKickoffsSeries2020)


# Extra Points
SFExtraPointsSeries2018 = extraPointsSF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
SFExtraPointsFrame2018 = pd.DataFrame(SFExtraPointsSeries2018)
SFExtraPointsSeries2019 = extraPointsSF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
SFExtraPointsFrame2019 = pd.DataFrame(SFExtraPointsSeries2019)
SFExtraPointsSeries2020 = extraPointsSF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
SFExtraPointsFrame2020 = pd.DataFrame(SFExtraPointsSeries2020)


# Field Goals
SFFiledGoalsSeries2018 = fieldGoalsSF2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
SFFiledGoalsFrame2018 = pd.DataFrame(SFFiledGoalsSeries2018)
SFFiledGoalsSeries2019 = fieldGoalsSF2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
SFFiledGoalsFrame2019 = pd.DataFrame(SFFiledGoalsSeries2019)
SFFiledGoalsSeries2020 = fieldGoalsSF2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
SFFiledGoalsFrame2020 = pd.DataFrame(SFFiledGoalsSeries2020)

# %%
# TB Special Plays Data Frames

# Punt Frames
TBPuntsSeries2018 = puntsTB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
TBPuntsFrame2018 = pd.DataFrame(TBPuntsSeries2018)

TBPuntsSeries2019 = puntsTB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
TBPuntsFrame2019 = pd.DataFrame(TBPuntsSeries2019)

TBPuntsSeries2020 = puntsTB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
TBPuntsFrame2020 = pd.DataFrame(TBPuntsSeries2020)


# Kickoff Frames
TBKickoffsSeries2018 = kickoffsTB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
TBKickoffsFrame2018 = pd.DataFrame(TBKickoffsSeries2018)

TBKickoffsSeries2019 = kickoffsTB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
TBKickoffsFrame2019 = pd.DataFrame(TBKickoffsSeries2019)

TBKickoffsSeries2020 = kickoffsTB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
TBKickoffsFrame2020 = pd.DataFrame(TBKickoffsSeries2020)


# Extra Points
TBExtraPointsSeries2018 = extraPointsTB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
TBExtraPointsFrame2018 = pd.DataFrame(TBExtraPointsSeries2018)
TBExtraPointsSeries2019 = extraPointsTB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
TBExtraPointsFrame2019 = pd.DataFrame(TBExtraPointsSeries2019)
TBExtraPointsSeries2020 = extraPointsTB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
TBExtraPointsFrame2020 = pd.DataFrame(TBExtraPointsSeries2020)


# Field Goals
TBFiledGoalsSeries2018 = fieldGoalsTB2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
TBFiledGoalsFrame2018 = pd.DataFrame(TBFiledGoalsSeries2018)
TBFiledGoalsSeries2019 = fieldGoalsTB2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
TBFiledGoalsFrame2019 = pd.DataFrame(TBFiledGoalsSeries2019)
TBFiledGoalsSeries2020 = fieldGoalsTB2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
TBFiledGoalsFrame2020 = pd.DataFrame(TBFiledGoalsSeries2020)

# %%
# TEN Special Plays Data Frames

# Punt Frames
TENPuntsSeries2018 = puntsTEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
TENPuntsFrame2018 = pd.DataFrame(TENPuntsSeries2018)

TENPuntsSeries2019 = puntsTEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
TENPuntsFrame2019 = pd.DataFrame(TENPuntsSeries2019)

TENPuntsSeries2020 = puntsTEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
TENPuntsFrame2020 = pd.DataFrame(TENPuntsSeries2020)


# Kickoff Frames
TENKickoffsSeries2018 = kickoffsTEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
TENKickoffsFrame2018 = pd.DataFrame(TENKickoffsSeries2018)

TENKickoffsSeries2019 = kickoffsTEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
TENKickoffsFrame2019 = pd.DataFrame(TENKickoffsSeries2019)

TENKickoffsSeries2020 = kickoffsTEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
TENKickoffsFrame2020 = pd.DataFrame(TENKickoffsSeries2020)


# Extra Points
TENExtraPointsSeries2018 = extraPointsTEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
TENExtraPointsFrame2018 = pd.DataFrame(TENExtraPointsSeries2018)
TENExtraPointsSeries2019 = extraPointsTEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
TENExtraPointsFrame2019 = pd.DataFrame(TENExtraPointsSeries2019)
TENExtraPointsSeries2020 = extraPointsTEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
TENExtraPointsFrame2020 = pd.DataFrame(TENExtraPointsSeries2020)


# Field Goals
TENFiledGoalsSeries2018 = fieldGoalsTEN2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
TENFiledGoalsFrame2018 = pd.DataFrame(TENFiledGoalsSeries2018)
TENFiledGoalsSeries2019 = fieldGoalsTEN2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
TENFiledGoalsFrame2019 = pd.DataFrame(TENFiledGoalsSeries2019)
TENFiledGoalsSeries2020 = fieldGoalsTEN2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
TENFiledGoalsFrame2020 = pd.DataFrame(TENFiledGoalsSeries2020)

# %%
# WAS Special Plays Data Frames

# Punt Frames
WASPuntsSeries2018 = puntsWAS2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
WASPuntsFrame2018 = pd.DataFrame(WASPuntsSeries2018)

WASPuntsSeries2019 = puntsWAS2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
WASPuntsFrame2019 = pd.DataFrame(WASPuntsSeries2019)

WASPuntsSeries2020 = puntsWAS2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                           'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                           'week'],as_index=True).size()
WASPuntsFrame2020 = pd.DataFrame(WASPuntsSeries2020)


# Kickoff Frames
WASKickoffsSeries2018 = kickoffsWAS2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
WASKickoffsFrame2018 = pd.DataFrame(WASKickoffsSeries2018)

WASKickoffsSeries2019 = kickoffsWAS2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
WASKickoffsFrame2019 = pd.DataFrame(WASKickoffsSeries2019)

WASKickoffsSeries2020 = kickoffsWAS2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                                 'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr',
                                                 'visitorTeamAbbr','week'],as_index=True).size()
WASKickoffsFrame2020 = pd.DataFrame(WASKickoffsSeries2020)


# Extra Points
WASExtraPointsSeries2018 = extraPointsWAS2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
WASExtraPointsFrame2018 = pd.DataFrame(WASExtraPointsSeries2018)
WASExtraPointsSeries2019 = extraPointsWAS2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
WASExtraPointsFrame2019 = pd.DataFrame(WASExtraPointsSeries2019)
WASExtraPointsSeries2020 = extraPointsWAS2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                               'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                               'week'],as_index=True).size()
WASExtraPointsFrame2020 = pd.DataFrame(WASExtraPointsSeries2020)


# Field Goals
WASFiledGoalsSeries2018 = fieldGoalsWAS2018.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
WASFiledGoalsFrame2018 = pd.DataFrame(WASFiledGoalsSeries2018)
WASFiledGoalsSeries2019 = fieldGoalsWAS2019.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
WASFiledGoalsFrame2019 = pd.DataFrame(WASFiledGoalsSeries2019)
WASFiledGoalsSeries2020 = fieldGoalsWAS2020.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
                                               'yardlineSide','Result','gameClock','yardlineNumber','playResult',
                                               'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
                                              ,as_index=True).size()
WASFiledGoalsFrame2020 = pd.DataFrame(WASFiledGoalsSeries2020)

# %%
# ARI Plot Data
ARIData = [['Punt - Return', 33, 24, 17],
            ['Punt - Fair Catch', 19, 12, 19],
            ['Punt - Downed', 11, 7, 7],
            ['Punt - Out of Bounds', 23, 21, 7],
            ['Punt - Touchback', 6, 5, 5],
            ['Punt - Muffed ', 3, 0, 1],
            ['Punt - Non-Special Teams Result', 1, 1, 1],
            ['Punt - Blocked Punt', 0, 1, 0],
            ['Kickoff - Return', 27, 30, 41],
            ['Kickoff - Touchback', 27, 45, 38],
            ['Kickoff - Out of Bounds', 1, 2, 1],
            ['Kickoff - Muffed', 0, 0, 1],
            ['Extra Point - Kick Attempt Good', 23, 31, 44],
            ['Extra Point - Kick Attempt No Good', 1, 1, 1],
            ['Field Goal - Kick Attempt Good ', 36, 28, 19],
            ['Field Goal - Kick Attempt No Good', 15, 2, 6],
            ['Field Goal - Blocked Kick Attempt', 0, 1, 1]]

allARIData = pd.DataFrame(ARIData, columns=['ARI Special Play', '2018', '2019', '2020'])

# ATL Plot Data
ATLData = [['Punt - Return', 20, 15, 20],
            ['Punt - Fair Catch', 21, 15, 14],
            ['Punt - Downed', 5, 5, 4],
            ['Punt - Out of Bounds', 1, 4, 4],
            ['Punt - Touchback', 2, 2, 2],
            ['Punt - Muffed ', 3, 1, 0],
            ['Punt - Non-Special Teams Result', 0, 0, 1],
            ['Punt - Blocked Punt', 2, 1, 0],
            ['Kickoff - Return', 35, 28, 36],
            ['Kickoff - Touchback', 49, 46, 44],
            ['Kickoff - Out of Bounds', 0, 4, 1],
            ['Kickoff - Kickoff Team Recovery', 0, 2, 1],
            ['Kickoff - Muffed', 0, 1, 1],
            ['Extra Point - Kick Attempt Good', 41, 28, 27],
            ['Extra Point - Kick Attempt No Good', 2, 2, 4],
            ['Field Goal - Kick Attempt Good ', 23, 28, 32],
            ['Field Goal - Kick Attempt No Good', 1, 8, 2]
           ]

allATLData = pd.DataFrame(ATLData, columns=['ATL Special Play', '2018', '2019', '2020'])

# BAL Plot Data
BALData = [['Punt - Return', 26, 11, 18],
           ['Punt - Fair Catch', 10, 9, 15],
           ['Punt - Out of Bounds', 6, 6, 8],
           ['Punt - Downed', 7, 5, 4],
           ['Punt - Touchback', 3, 4, 1],
           ['Punt - Non-Special Teams Result', 1, 2, 0],
           ['Punt - Muffed ', 1, 1, 0],
           ['Punt - Blocked Punt', 1, 1, 0],
           ['Kickoff - Return', 30, 44, 26],
           ['Kickoff - Touchback', 56, 54, 65],
           ['Kickoff - Muffed', 1, 0, 0],
           ['Kickoff - Out of Bounds', 1, 0, 0],
           ['Kickoff - Fair Catch', 0, 1, 0],
           ['Extra Point - Kick Attempt Good', 35, 52, 44],
           ['Extra Point - Kick Attempt No Good', 1, 2, 1],
           ['Field Goal - Kick Attempt Good', 34, 28, 24],
           ['Field Goal - Kick Attempt No Good', 1, 1, 3],
           ['Field Goal - Blocked Kick Attempt', 1, 0, 0],
           ['Field Goal - Non-Special Teams Result', 0, 1, 0]
           ]

allBALData = pd.DataFrame(BALData, columns=['BAL Special Play', '2018', '2019', '2020'])

# BUF Plot Data
BUFData = [['Punt - Return', 23, 25, 11],
           ['Punt - Fair Catch', 16, 15, 5],
           ['Punt - Downed', 12, 11, 4],
           ['Punt - Out of Bounds', 7, 13, 8],
           ['Punt - Touchback', 7, 7, 7],
           ['Punt - Muffed', 2, 2, 1],
           ['Punt - Non-Special Teams Result', 2, 0, 1],
           ['Punt - Blocked Punt', 1, 1, 0],
           ['Kickoff - Return', 28, 28, 27],
           ['Kickoff - Touchback', 29, 42, 70],
           ['Kickoff - Muffed', 1, 0, 0],
           ['Extra Point - Kick Attempt Good', 22, 28, 52],
           ['Extra Point - Non-Special Teams Result', 1, 0, 0],
           ['Extra Point - Kick Attempt No Good', 1, 1, 2],
           ['Extra Point - Blocked Kick Attempt', 0, 1, 0],
           ['Field Goal - Kick Attempt Good', 20, 22, 22],
           ['Field Goal - Kick Attempt No Good', 4, 5, 6],
           ['Field Goal - Blocked Kick Attempt', 1, 0, 0],
           ['Field Goal - Non-Special Teams Result', 1, 0, 0]
           ]

allBUFData = pd.DataFrame(BUFData, columns=['BUF Special Play', '2018', '2019', '2020'])

# CAR Plot Data
CARData = [['Punt - Return', 17, 28, 13],
           ['Punt - Fair Catch', 22, 12, 12],
           ['Punt - Downed', 6, 6, 5],
           ['Punt - Touchback', 4, 1, 3],
           ['Punt - Muffed', 2, 3, 3],
           ['Punt - Out of Bounds', 3, 6, 1],
           ['Punt - Non-Special Teams Result', 0, 2, 3],
           ['Kickoff - Touchback', 59, 66, 71],
           ['Kickoff - Return', 17, 4, 9],
           ['Kickoff - Muffed', 0, 1, 0],
           ['Kickoff - Kickoff Team Recovery', 0, 1, 0],
           ['Extra Point - Kick Attempt Good', 34, 28, 30],
           ['Extra Point - Kick Attempt No Good', 4, 3, 1],
           ['Extra Point - Non-Special Teams Result', 1, 0, 0],
           ['Extra Point - Blocked Kick Attempt', 0, 0, 1],
           ['Field Goal - Kick Attempt Good', 18, 22, 19],
           ['Field Goal - Kick Attempt No Good', 2, 5, 6],
           ['Field Goal - Blocked Kick Attempt', 0, 1, 1]
           ]

allCARData = pd.DataFrame(CARData, columns=['CAR Special Play', '2018', '2019', '2020'])

# CHI Plot Data
CHIData = [['Punt - Return', 15, 24, 21],
           ['Punt - Fair Catch', 18, 20, 21],
           ['Punt - Downed', 13, 11, 9],
           ['Punt - Touchback', 7, 1, 5],
           ['Punt - Muffed', 2, 1, 0],
           ['Punt - Out of Bounds', 2, 4, 1],
           ['Punt - Blocked Punt', 1, 0, 0],
           ['Punt - Non-Special Teams Result', 1, 0, 1],
           ['Kickoff - Touchback', 65, 31, 42],
           ['Kickoff - Return', 19, 25, 41],
           ['Kickoff - Out of Bounds', 1, 3, 0],
           ['Kickoff - Kickoff Team Recovery', 1, 1, 0],
           ['Extra Point - Kick Attempt Good', 41, 24, 30],
           ['Extra Point - Kick Attempt No Good', 3, 2, 1],
           ['Field Goal - Kick Attempt Good', 23, 20, 27],
           ['Field Goal - Kick Attempt No Good', 7, 4, 2]
           ]

allCHIData = pd.DataFrame(CHIData, columns=['CHI Special Play', '2018', '2019', '2020'])

# CIN Plot Data
CINData = [['Punt - Return', 20, 17, 22],
           ['Punt - Fair Catch', 21, 21, 16],
           ['Punt - Downed', 9, 5, 13],
           ['Punt - Non-Special Teams Result', 2, 0, 2],
           ['Punt - Touchback', 2, 4, 7],
           ['Punt - Out of Bounds', 2, 6, 3],
           ['Punt - Blocked Punt', 1, 0, 0],
           ['Kickoff - Return', 27, 17, 16],
           ['Kickoff - Touchback', 44, 46, 56],
           ['Kickoff - Out of Bounds', 1, 0, 1],
           ['Kickoff - Fair Catch', 1, 0, 0],
           ['Kickoff - Kickoff Team Recover', 0, 1, 0],
           ['Extra Point - Kick Attempt Good', 37, 21, 27],
           ['Extra Point - Kick Attempt No Good', 2, 1, 1],
           ['Field Goal - Kick Attempt Good', 17, 26, 26],
           ['Field Goal - Kick Attempt No Good', 2, 4, 7]
           ]

allCINData = pd.DataFrame(CINData, columns=['CIN Special Play', '2018', '2019', '2020'])

# CLE Plot Data
CLEData = [['Punt - Return', 28, 15, 18],
           ['Punt - Fair Catch', 20, 15, 13],
           ['Punt - Downed', 10, 10, 4],
           ['Punt - Touchback', 6, 3, 2],
           ['Punt - Out of Bounds', 6, 7, 3],
           ['Punt - Muffed', 2, 0, 0],
           ['Punt - Blocked Punt', 2, 1, 0],
           ['Punt - Non-Special Teams Result', 0, 0, 1],
           ['Kickoff - Touchback', 52, 30, 43],
           ['Kickoff - Return', 21, 41, 36],
           ['Kickoff - Kickoff Team Recovery', 1, 0, 0],
           ['Kickoff - Out of Bounds', 1, 2, 1],
           ['Extra Point - Kick Attempt Good', 27, 28, 38],
           ['Extra Point - Kick Attempt No Good', 6, 5, 5],
           ['Field Goal - Kick Attempt Good', 15, 22, 18],
           ['Field Goal - Kick Attempt No Good', 5, 4, 3],
           ['Field Goal - Blocked Kick Attempt', 1, 0, 1]
           ]

allCLEData = pd.DataFrame(CLEData, columns=['CLE Special Play', '2018', '2019', '2020'])

# DAL Plot Data
DALData = [['Punt - Return', 25, 12, 11],
           ['Punt - Fair Catch', 14, 15, 25],
           ['Punt - Downed', 9, 8, 0],
           ['Punt - Out of Bounds', 3, 3, 2],
           ['Punt - Non-Special Teams Result', 1, 0, 3],
           ['Punt - Muffed', 1, 3, 1],
           ['Punt - Touchback', 1, 2, 3],
           ['Punt - Blocked Punt', 0, 1, 0],
           ['Kickoff - Touchback', 50, 49, 53],
           ['Kickoff - Return', 23, 34, 30],
           ['Kickoff - Muffed', 1, 0, 0],
           ['Kickoff - Out of Bounds', 0, 3, 0],
           ['Kickoff - Kickoff Team Recovery', 0, 0, 1],
           ['Extra Point - Kick Attempt Good', 31, 42, 28],
           ['Extra Point - Kick Attempt No Good', 1, 0, 1],
           ['Extra Point - Blocked Kick Attempt', 0, 0, 1],
           ['Field Goal - Kick Attempt Good', 28, 27, 30],
           ['Field Goal - Kick Attempt No Good', 6, 7, 6],
           ['Field Goal - Blocked Kick Attempt', 1, 1, 0]
           ]

allDALData = pd.DataFrame(DALData, columns=['DAL Special Play', '2018', '2019', '2020'])

# DEN Plot Data
DENData = [['Punt - Return', 24, 17, 21],
           ['Punt - Fair Catch', 17, 13, 13],
           ['Punt - Out of Bounds', 11, 12, 11],
           ['Punt - Touchback', 8, 4, 4],
           ['Punt - Downed', 6, 7, 2],
           ['Punt - Muffed', 2, 5, 1],
           ['Punt - Non-Special Teams Result', 1, 1, 1],
           ['Kickoff - Return', 25, 13, 23],
           ['Kickoff - Touchback', 37, 54, 54],
           ['Kickoff - Out of Bounds', 1, 0, 0],
           ['Extra Point - Kick Attempt Good', 30, 23, 22],
           ['Extra Point - Kick Attempt No Good', 0, 1, 4],
           ['Field Goal - Kick Attempt Good', 17, 26, 27],
           ['Field Goal - Kick Attempt No Good', 3, 3, 5],
           ['Field Goal - Blocked Kick Attempt', 0, 0, 2]
           ]

allDENData = pd.DataFrame(DENData, columns=['DEN Special Play', '2018', '2019', '2020'])

# DET Plot Data
DETData = [['Punt - Return', 22, 17, 19],
           ['Punt - Fair Catch', 23, 14, 15],
           ['Punt - Downed', 12, 11, 10],
           ['Punt - Touchback', 4, 7, 5],
           ['Punt - Out of Bounds', 3, 4, 4],
           ['Punt - Muffed', 1, 1, 0],
           ['Punt - Non-Special Teams Result', 1, 0, 1],
           ['Kickoff - Return', 27, 46, 46],
           ['Kickoff - Touchback', 36, 2, 26],
           ['Kickoff - Muffed', 4, 1, 0],
           ['Kickoff - Kickoff Team Recovery', 1, 1, 0],
           ['Kickoff - Out of Bounds', 0, 1, 2],
           ['Extra Point - Kick Attempt Good', 29, 33, 33],
           ['Extra Point - Non-Special Teams Result', 1, 0, 0],
           ['Extra Point - Kick Attempt No Good', 0, 1, 3],
           ['Field Goal - Kick Attempt Good', 78, 21, 18],
           ['Field Goal - Kick Attempt No Good', 12, 4, 5],
           ['Field Goal - Non-Special Teams Result', 7, 0, 0]
           ]

allDETData = pd.DataFrame(DETData, columns=['DET Special Play', '2018', '2019', '2020'])

# GB Plot Data
GBData = [['Punt - Fair Catch', 27, 21, 10],
          ['Punt - Return', 14, 16, 12],
          ['Punt - Downed', 10, 10, 6],
          ['Punt - Touchback', 7, 3, 2],
          ['Punt - Out of Bounds', 3, 12, 9],
          ['Punt - Blocked Punt', 1, 0, 0],
          ['Punt - Non-Special Teams Result', 1, 0, 0],
          ['Punt - Muffed', 1, 1, 1],
          ['Kickoff - Return', 37, 24, 41],
          ['Kickoff - Touchback', 40, 48, 51],
          ['Kickoff - Muffed', 1, 1, 0],
          ['Kickoff - Out of Bounds', 0, 1, 1],
          ['Extra Point - Kick Attempt Good', 34, 34, 56],
          ['Extra Point - Kick Attempt No Good', 2, 1, 3],
          ['Field Goal - Kick Attempt Good', 28, 19, 15],
          ['Field Goal - Kick Attempt No Good', 6, 2, 0],
          ['Field Goal - Non-Special Teams Result', 1, 0, 0]
          ]

allGBData = pd.DataFrame(GBData, columns=['GB Special Play', '2018', '2019', '2020'])

# HOU Plot Data
HOUData = [['Punt - Return', 20, 18, 15],
           ['Punt - Fair Catch', 20, 18, 18],
           ['Punt - Muffed', 5, 0, 0],
           ['Punt - Downed', 6, 9, 4],
           ['Punt - Out of Bounds', 5, 1, 3],
           ['Punt - Touchback', 3, 0, 6],
           ['Punt - Non-Special Teams Result', 0, 1, 1],
           ['Kickoff - Touchback', 56, 41, 51],
           ['Kickoff - Return', 29, 31, 27],
           ['Kickoff - Muffed', 3, 2, 2],
           ['Kickoff - Kickoff Team Recovery', 0, 1, 1],
           ['Extra Point - Kick Attempt Good', 38, 34, 33],
           ['Extra Point - Kick Attempt No Good', 2, 3, 2],
           ['Extra Point - Blocked Kick Attempt', 0, 1, 0],
           ['Field Goal - Kick Attempt Good', 34, 19, 25],
           ['Field Goal - Kick Attempt No Good', 5, 5, 3],
           ['Field Goal - Out of Bounds', 0, 1, 0],
           ['Field Goal - Downed', 0, 0, 1]
           ]

allHOUData = pd.DataFrame(HOUData, columns=['HOU Special Play', '2018', '2019', '2020'])

# IND Plot Data
INDData = [['Punt - Return', 14, 18, 21],
           ['Punt - Fair Catch', 18, 12, 7],
           ['Punt - Downed', 8, 8, 5],
           ['Punt - Muffed', 3, 1, 0],
           ['Punt - Touchback', 4, 1, 5],
           ['Punt - Out of Bounds', 3, 5, 3],
           ['Punt - Blocked Punt', 0, 0, 1],
           ['Kickoff - Touchback', 51, 58, 46],
           ['Kickoff - Return', 23, 18, 45],
           ['Extra Point - Kick Attempt Good', 42, 32, 40],
           ['Extra Point - Kick Attempt No Good', 2, 5, 2],
           ['Extra Point - Blocked Kick Attempt', 0, 1, 0],
           ['Field Goal - Kick Attempt Good', 22, 21, 30],
           ['Field Goal - Kick Attempt No Good', 4, 6, 5],
           ['Field Goal - Blocked Kick Attempt', 0, 2, 0]
           ]

allINDData = pd.DataFrame(INDData, columns=['IND Special Play', '2018', '2019', '2020'])

# JAX Plot Data
JAXData = [['Punt - Return', 25, 15, 19],
           ['Punt - Fair Catch', 17, 23, 11],
           ['Punt - Downed', 10, 10, 12],
           ['Punt - Out of Bounds', 11, 9, 7],
           ['Punt - Muffed', 5, 4, 0],
           ['Punt - Touchback', 7, 2, 4],
           ['Punt - Non-Special Teams Result', 1, 2, 0],
           ['Kickoff - Touchback', 38, 39, 40],
           ['Kickoff - Return', 17, 33, 27],
           ['Kickoff - Kickoff Team Recovery', 1, 0, 0],
           ['Kickoff - Muffed', 0, 0, 2],
           ['Kickoff - Out of Bounds', 0, 0, 2],
           ['Extra Point - Kick Attempt Good', 20, 19, 21],
           ['Extra Point - Kick Attempt No Good', 0, 1, 3],
           ['Field Goal - Kick Attempt Good', 22, 30, 16],
           ['Field Goal - Kick Attempt No Good', 3, 1, 6],
           ['Field Goal - Non-Special Teams Result', 1, 1, 0]
           ]

allJAXData = pd.DataFrame(JAXData, columns=['JAX Special Play', '2018', '2019', '2020'])

# KC Plot Data
KCData = [['Punt - Return', 11, 13, 12],
          ['Punt - Fair Catch', 10, 9, 11],
          ['Punt - Downed', 7, 10, 5],
          ['Punt - Touchback', 3, 3, 4],
          ['Punt - Muffed', 1, 3, 1],
          ['Punt - Out of Bounds', 1, 0, 6],
          ['Punt - Blocked Punt', 0, 1, 0],
          ['Punt - Non-Special Teams Result', 0, 0, 1],
          ['Kickoff - Touchback', 67, 60, 70],
          ['Kickoff - Return', 25, 30, 19],
          ['Kickoff - Out of Bounds', 3, 0, 2],
          ['Extra Point - Kick Attempt Good', 58, 42, 43],
          ['Extra Point - Kick Attempt No Good', 3, 3, 4],
          ['Extra Point - Blocked Kick Attempt', 1, 0, 1],
          ['Extra Point - Non-Special Teams Result', 0, 1, 0],
          ['Field Goal - Kick Attempt Good', 23, 32, 22],
          ['Field Goal - Kick Attempt No Good', 3, 2, 2],
          ['Field Goal - Blocked Kick Attempt', 0, 1, 0]
          ]

allKCData = pd.DataFrame(KCData, columns=['KC Special Play', '2018', '2019', '2020'])


# LA Plot Data
LAData = [['Punt - Return', 11, 18, 21],
          ['Punt - Downed', 10, 8, 9],
          ['Punt - Out of Bounds', 9, 13, 11],
          ['Punt - Fair Catch', 7, 13, 20],
          ['Punt - Non-Special Teams Result', 4, 4, 0],
          ['Punt - Touchback', 2, 3, 5],
          ['Punt - Blocked Punt', 0, 1, 1],
          ['Punt - Muffed', 0, 1, 1],
          ['Kickoff - Touchback', 76, 63, 53],
          ['Kickoff - Return', 26, 15, 23],
          ['Kickoff - Out of Bounds', 0, 3, 1],
          ['Kickoff - Muffed', 0, 1, 1],
          ['Extra Point - Kick Attempt Good', 50, 41, 32],
          ['Extra Point - Kick Attempt No Good', 2, 0, 2],
          ['Extra Point - Blocked Kick Attempt', 0, 0, 2],
          ['Field Goal - Kick Attempt Good', 33, 20, 18],
          ['Field Goal - Kick Attempt No Good', 7, 6, 4],
          ['Field Goal - Non-Special Teams Result', 1, 0, 0],
          ['Field Goal - Blocked Kick Attempt', 0, 1, 1]
          ]

allLAData = pd.DataFrame(LAData, columns=['LA Special Play', '2018', '2019', '2020'])

# LAC Plot Data
LACData = [['Punt - Return', 17, 28, 30],
           ['Punt - Fair Catch', 11, 6, 7],
           ['Punt - Out of Bounds', 6, 1, 5],
           ['Punt - Downed', 5, 2, 3],
           ['Punt - Muffed', 3, 0, 1],
           ['Punt - Touchback', 3, 2, 3],
           ['Punt - Blocked Punt', 1, 0, 3],
           ['Punt - Non-Special Teams Result', 0, 0, 1],
           ['Kickoff - Return', 48, 33, 34],
           ['Kickoff - Touchback', 23, 35, 48],
           ['Extra Point - Kick Attempt Good', 36, 32, 35],
           ['Extra Point - Kick Attempt No Good', 7, 0, 3],
           ['Field Goal - Kick Attempt Good', 21, 24, 20],
           ['Field Goal - Kick Attempt No Good', 4, 6, 8],
           ['Field Goal - Blocked Kick Attempt', 0, 1, 1]
          ]

allLACData = pd.DataFrame(LACData, columns=['LAC Special Play', '2018', '2019', '2020'])

# MIA Plot Data
MIAData = [['Punt - Return', 23, 26, 17],
           ['Punt - Fair Catch', 23, 15, 17],
           ['Punt - Downed', 8, 12, 14],
           ['Punt - Out of Bounds', 6, 5, 5],
           ['Punt - Touchback', 5, 2, 1],
           ['Punt - Muffed', 2, 0, 2],
           ['Punt - Blocked Punt', 1, 0, 0],
           ['Punt - Non-Special Teams Result', 1, 3, 1],
           ['Kickoff - Touchback', 53, 46, 64],
           ['Kickoff - Return', 8, 20, 22],
           ['Kickoff - Out of Bounds', 1, 0, 1],
           ['Kickoff - Muffed', 0, 1, 1],
           ['Kickoff - Kickoff Team Recovery', 0, 1, 0],
           ['Kickoff - Fair Catch', 0, 1, 0],
           ['Extra Point - Kick Attempt Good', 29, 27, 29],
           ['Extra Point - Kick Attempt No Good', 1, 1, 0],
           ['Field Goal - Kick Attempt Good', 17, 21, 32],
           ['Field Goal - Kick Attempt No Good', 2, 7, 3],
           ['Field Goal - Non-Special Teams Result', 0, 2, 0]
          ]

allMIAData = pd.DataFrame(MIAData, columns=['MIA Special Play', '2018', '2019', '2020'])

# MIN Plot Data
MINData = [['Punt - Return', 17, 16, 19],
           ['Punt - Fair Catch', 16, 16, 10],
           ['Punt - Downed', 7, 5, 6],
           ['Punt - Out of Bounds', 7, 6, 1],
           ['Punt - Muffed', 4, 2, 1],
           ['Punt - Touchback', 2, 0, 3],
           ['Punt - Blocked Punt', 1, 0, 1],
           ['Kickoff - Return', 29, 20, 28],
           ['Kickoff - Touchback', 38, 64, 50],
           ['Kickoff - Out of Bounds', 1, 0, 0],
           ['Kickoff - Muffed', 0, 0, 1],
           ['Extra Point - Kick Attempt Good', 31, 37, 27],
           ['Extra Point - Kick Attempt No Good', 1, 3, 3],
           ['Extra Point - Blocked Kick Attempt', 0, 1, 0],
           ['Extra Point - Non-Special Teams Result', 0, 0, 1],
           ['Field Goal - Kick Attempt Good', 21, 0, 0],
           ['Field Goal - Kick Attempt No Good', 9, 25, 13],
           ['Field Goal - Blocked Kick Attempt', 1, 2, 4]
          ]

allMINData = pd.DataFrame(MINData, columns=['MIN Special Play', '2018', '2019', '2020'])

# NE Plot Data
NEData = [['Punt - Return', 22, 15, 9],
          ['Punt - Downed', 14, 10, 14],
          ['Punt - Out of Bounds', 8, 15, 3],
          ['Punt - Fair Catch', 6, 17, 15],
          ['Punt - Touchback', 5, 6, 5],
          ['Punt - Muffed', 0, 3, 1],
          ['Kickoff - Return', 36, 25, 30],
          ['Kickoff - Touchback', 45, 58, 42],
          ['Kickoff - Muffed', 1, 3, 1],
          ['Kickoff - Fair Catch', 1, 0, 0],
          ['Kickoff - Out of Bounds', 0, 3, 0],
          ['Extra Point - Kick Attempt Good', 43, 34, 28],
          ['Extra Point - Kick Attempt No Good', 1, 6, 3],
          ['Field Goal - Kick Attempt Good', 27, 26, 24],
          ['Field Goal - Kick Attempt No Good', 4, 5, 1],
          ['Field Goal - Blocked Kick Attempt', 0, 2, 0]
          ]

allNEData = pd.DataFrame(NEData, columns=['NE Special Play', '2018', '2019', '2020'])

# NO Plot Data
NOData = [['Punt - Return', 9, 19, 17],
          ['Punt - Fair Catch', 13, 17, 25],
          ['Punt - Out of Bounds', 7, 6, 6],
          ['Punt - Downed', 3, 6, 5],
          ['Punt - Non-Special Teams Result', 2, 2, 0],
          ['Punt - Touchback', 2, 1, 2],
          ['Punt - Muffed', 0, 1, 2],
          ['Kickoff - Touchback', 63, 73, 70],
          ['Kickoff - Return', 31, 16, 20],
          ['Kickoff - Muffed', 0, 0, 1],
          ['Kickoff - Out of Bounds', 0, 0, 1],
          ['Extra Point - Kick Attempt Good', 48, 44, 49],
          ['Extra Point - Kick Attempt No Good', 1, 0, 1],
          ['Field Goal - Kick Attempt Good', 25, 29, 22],
          ['Field Goal - Blocked Kick Attempt', 1, 3, 5]
          ]

allNOData = pd.DataFrame(NOData, columns=['NO Special Play', '2018', '2019', '2020'])

# NYG Plot Data
NYGData = [['Punt - Return', 19, 18, 19],
           ['Punt - Downed', 13, 13, 13],
           ['Punt - Fair Catch', 13, 13, 14],
           ['Punt - Out of Bounds', 9, 8, 2],
           ['Punt - Muffed', 3, 0, 2],
           ['Punt - Blocked Punt', 0, 2, 1],
           ['Punt - Touchback', 4, 2, 5],
           ['Punt - Non-Special Teams Result', 1, 0, 0],
           ['Kickoff - Touchback', 49, 50, 30],
           ['Kickoff - Return', 26, 14, 39],
           ['Kickoff - Muffed', 2, 3, 0],
           ['Kickoff - Out of Bounds', 3, 2, 0],
           ['Kickoff - Kickoff Team Recovery', 1, 0, 0],
           ['Extra Point - Kick Attempt Good', 28, 30, 18],
           ['Extra Point - Kick Attempt No Good', 1, 4, 2],
           ['Extra Point - Non-Special Teams Result', 0, 1, 0],
           ['Field Goal - Kick Attempt Good', 30, 8, 29],
           ['Field Goal - Kick Attempt No Good', 1, 4, 1],
           ['Field Goal - Non-Special Teams Result', 0, 0, 1]
           ]

allNYGData = pd.DataFrame(NYGData, columns=['NYG Special Play', '2018', '2019', '2020'])


# NYJ Plot Data
NYJData = [['Punt - Return', 32, 33, 29],
           ['Punt - Fair Catch', 13, 13, 16],
           ['Punt - Downed', 10, 16, 7],
           ['Punt - Out of Bounds', 8, 8, 7],
           ['Punt - Touchback', 5, 0, 3],
           ['Punt - Muffed', 2, 5, 0],
           ['Punt - Non-Special Teams Result', 1, 0, 0],
           ['Kickoff - Touchback', 58, 32, 33],
           ['Kickoff - Return', 19, 30, 22],
           ['Kickoff - Muffed', 0, 1, 0],
           ['Kickoff - Out of Bounds', 0, 0, 1],
           ['Extra Point - Kick Attempt Good', 28, 21, 15],
           ['Extra Point - Kick Attempt No Good', 3, 4, 3],
           ['Extra Point - Blocked Kick Attempt', 0, 0, 1],
           ['Field Goal - Kick Attempt Good', 32, 16, 21],
           ['Field Goal - Kick Attempt No Good', 3, 6, 5],
           ['Field Goal - Blocked Kick Attempt', 0, 0, 2]
           ]

allNYJData = pd.DataFrame(NYJData, columns=['NYJ Special Play', '2018', '2019', '2020'])


# OAK Plot Data
OAKData = [['Punt - Return', 19, 20, 9],
           ['Punt - Fair Catch', 16, 16, 14],
           ['Punt - Downed', 7, 8, 5],
           ['Punt - Out of Bounds', 5, 3, 5],
           ['Punt - Touchback', 4, 6, 2],
           ['Punt - Non-Special Teams Result', 1, 1, 1],
           ['Punt - Muffed', 0, 1, 2],
           ['Kickoff - Return', 32, 30, 26],
           ['Kickoff - Touchback', 28, 37, 61],
           ['Kickoff - Muffed', 1, 0, 0],
           ['Kickoff - Out of Bounds', 1, 0, 0],
           ['Extra Point - Kick Attempt Good', 26, 29, 28],
           ['Extra Point - Blocked Kick Attempt', 1, 1, 2],
           ['Extra Point - Kick Attempt No Good', 0, 1, 0],
           ['Field Goal - Kick Attempt Good', 25, 19, 31],
           ['Field Goal - Kick Attempt No Good', 4, 7, 2],
           ['Field Goal - Non-Special Teams Result', 0, 0, 1]
           ]

allOAKData = pd.DataFrame(OAKData, columns=['OAK Special Play', '2018', '2019', '2020'])

# PHI Plot Data
PHIData = [['Punt - Return', 22, 21, 34],
           ['Punt - Fair Catch', 15, 17, 9],
           ['Punt - Touchback', 6, 4, 5],
           ['Punt - Downed', 4, 7, 4],
           ['Punt - Muffed', 1, 0, 2],
           ['Punt - Out of Bounds', 2, 6, 6],
           ['Punt - Blocked Punt', 0, 0, 1],
           ['Kickoff - Touchback', 55, 49, 42],
           ['Kickoff - Return', 23, 28, 27],
           ['Kickoff - Muffed', 0, 1, 0],
           ['Extra Point - Kick Attempt Good', 28, 31, 21],
           ['Extra Point - Kick Attempt No Good', 2, 1, 2],
           ['Extra Point - Non-Special Teams Result', 0, 0, 1],
           ['Field Goal - Kick Attempt Good', 26, 19, 8],
           ['Field Goal - Kick Attempt No Good', 5, 4, 3],
           ['Field Goal - Non-Special Teams Result', 0, 1, 0]
           ]

allPHIData = pd.DataFrame(PHIData, columns=['PHI Special Play', '2018', '2019', '2020'])

# PIT Plot Data
PITData = [['Punt - Fair Catch', 18, 22, 24],
           ['Punt - Return', 11, 25, 21],
           ['Punt - Downed', 11, 10, 5],
           ['Punt - Out of Bounds', 6, 5, 5],
           ['Punt - Touchback', 4, 4, 5],
           ['Punt - Non-Special Teams Result', 1, 2, 0],
           ['Punt - Muffed', 0, 0, 1],
           ['Kickoff - Touchback', 48, 36, 43],
           ['Kickoff - Return', 25, 31, 38],
           ['Kickoff - Muffed', 0, 2, 1],
           ['Kickoff - Out of Bounds', 0, 0, 1],
           ['Extra Point - Kick Attempt Good', 42, 27, 37],
           ['Extra Point - Kick Attempt No Good', 4, 0, 3],
           ['Extra Point - Blocked Kick Attempt', 0, 0, 1],
           ['Field Goal - Kick Attempt Good', 15, 26, 21],
           ['Field Goal - Kick Attempt No Good', 5, 2, 0],
           ['Field Goal - Blocked Kick Attempt', 1, 0, 0]
           ]

allPITData = pd.DataFrame(PITData, columns=['PIT Special Play', '2018', '2019', '2020'])

# SEA Plot Data
SEAData = [['Punt - Return', 25, 25, 21],
           ['Punt - Downed', 10, 8, 7],
           ['Punt - Out of Bounds', 11, 8, 3],
           ['Punt - Fair Catch', 9, 15, 12],
           ['Punt - Touchback', 5, 2, 6],
           ['Punt - Muffed', 2, 0, 1],
           ['Punt - Non-Special Teams Result', 1, 1, 0],
           ['Punt - Blocked Punt', 1, 0, 0],
           ['Kickoff - Return', 32, 21, 37],
           ['Kickoff - Touchback', 36, 59, 50],
           ['Kickoff - Muffed', 1, 2, 1],
           ['Kickoff - Out of Bounds', 1, 0, 0],
           ['Kickoff - Fair Catch', 0, 1, 0],
           ['Extra Point - Kick Attempt Good', 43, 36, 40],
           ['Extra Point - Kick Attempt No Good', 3, 4, 4],
           ['Field Goal - Kick Attempt Good', 20, 20, 19],
           ['Field Goal - Kick Attempt No Good', 4, 4, 0]
           ]

allSEAData = pd.DataFrame(SEAData, columns=['SEA Special Play', '2018', '2019', '2020'])

# SF Plot Data
SFData = [['Punt - Fair Catch', 24, 10, 24],
          ['Punt - Return', 14, 16, 19],
          ['Punt - Out of Bounds', 7, 5, 4],
          ['Punt - Touchback', 4, 2, 5],
          ['Punt - Muffed', 1, 2, 2],
          ['Punt - Downed', 2, 7, 4],
          ['Punt - Blocked Punt', 1, 0, 0],
          ['Kickoff - Touchback', 45, 47, 43],
          ['Kickoff - Return', 23, 36, 34],
          ['Kickoff - Muffed', 1, 1, 0],
          ['Kickoff - Out of Bounds', 0, 1, 0],
          ['Extra Point - Kick Attempt Good', 24, 36, 33],
          ['Extra Point - Kick Attempt No Good', 2, 1, 1],
          ['Extra Point - Non-Special Teams Result', 1, 1, 1],
          ['Extra Point - Blocked Kick Attempt', 0, 0, 1],
          ['Field Goal - Kick Attempt Good', 30, 23, 18],
          ['Field Goal - Kick Attempt No Good', 1, 6, 4],
          ['Field Goal - Blocked Kick Attempt', 0, 2, 0]
          ]

allSFData = pd.DataFrame(SFData, columns=['SF Special Play', '2018', '2019', '2020'])

# TB Plot Data
TBData = [['Punt - Return', 19, 16, 20],
          ['Punt - Fair Catch', 15, 12, 13],
          ['Punt - Downed', 7, 8, 6],
          ['Punt - Touchback', 3, 3, 2],
          ['Punt - Out of Bounds', 3, 1, 7],
          ['Punt - Muffed', 2, 4, 1],
          ['Punt - Non-Special Teams Result', 1, 0, 0],
          ['Punt - Blocked Punt', 1, 0, 0],
          ['Kickoff - Return', 38, 4, 13],
          ['Kickoff - Touchback', 48, 85, 85],
          ['Kickoff - Muffed', 2, 1, 1],
          ['Kickoff - Out of Bounds', 0, 1, 1],
          ['Extra Point - Kick Attempt Good', 36, 41, 43],
          ['Extra Point - Kick Attempt No Good', 4, 3, 3],
          ['Extra Point - Non-Special Teams Result', 1, 0, 0],
          ['Extra Point - Blocked Kick Attempt', 0, 2, 2],
          ['Field Goal - Kick Attempt Good', 18, 25, 25],
          ['Field Goal - Kick Attempt No Good', 6, 6, 2],
          ['Field Goal - Blocked Kick Attempt', 0, 1, 1]
          ]

allTBData = pd.DataFrame(TBData, columns=['TB Special Play', '2018', '2019', '2020'])

# TEN Plot Data
TENData = [['Punt - Return', 24, 23, 16],
           ['Punt - Out of Bounds', 12, 16, 6],
           ['Punt - Fair Catch', 12, 18, 11],
           ['Punt - Downed', 6, 9, 5],
           ['Punt - Touchback', 2, 2, 4],
           ['Punt - Blocked Punt', 1, 0, 1],
           ['Punt - Non-Special Teams Result', 0, 2, 1],
           ['Punt - Muffed', 0, 1, 0],
           ['Kickoff - Touchback', 44, 38, 51],
           ['Kickoff - Return', 25, 32, 35],
           ['Kickoff - Muffed', 0, 1, 1],
           ['Kickoff - Out of Bounds', 0, 0, 2],
           ['Extra Point - Kick Attempt Good', 26, 46, 44],
           ['Extra Point - Blocked Kick Attempt', 1, 0, 0],
           ['Extra Point - Kick Attempt No Good', 2, 2, 0],
           ['Extra Point - Non-Special Teams Result', 0, 0, 1],
           ['Field Goal - Kick Attempt Good', 24, 5, 20],
           ['Field Goal - Kick Attempt No Good', 3, 7, 6],
           ['Field Goal - Blocked Kick Attempt', 0, 2, 2],
           ['Field Goal - Non-Special Teams Result', 0, 1, 0]
          ]

allTENData = pd.DataFrame(TENData, columns=['TEN Special Play', '2018', '2019', '2020'])

# WAS Plot Data
WASData = [['Punt - Return', 25, 31, 28],
           ['Punt - Downed', 16, 11, 7],
           ['Punt - Fair Catch', 19, 15, 23],
           ['Punt - Out of Bounds', 3, 5, 0],
           ['Punt - Non-Special Teams Result', 1, 0, 0],
           ['Punt - Touchback', 0, 4, 3],
           ['Punt - Muffed', 0, 2, 1],
           ['Kickoff - Touchback', 51, 46, 62],
           ['Kickoff - Return', 13, 17, 10],
           ['Kickoff - Muffed', 0, 0, 1],
           ['Extra Point - Kick Attempt Good', 22, 19, 22],
           ['Extra Point - Kick Attempt No Good', 1, 1, 1],
           ['Field Goal - Kick Attempt Good', 25, 24, 21],
           ['Field Goal - Kick Attempt No Good', 3, 3, 6],
           ['Field Goal - Blocked Kick Attempt', 0, 1, 0]
           ]

allWASData = pd.DataFrame(WASData, columns=['WAS Special Play', '2018', '2019', '2020'])

# %%
# For Bar Plot
sumARIData = allARIData["2018"] + allARIData["2019"] + allARIData['2020']
allARIData["Total"] = sumARIData
allARIData = allARIData.sort_values(by=['Total'],ascending=False)

sumATLData = allATLData["2018"] + allATLData["2019"] + allATLData['2020']
allATLData["Total"] = sumATLData
allATLData = allATLData.sort_values(by=['Total'],ascending=False)

sumBALData = allBALData["2018"] + allBALData["2019"] + allBALData['2020']
allBALData["Total"] = sumBALData
allBALData = allBALData.sort_values(by=['Total'],ascending=False)

sumBUFData = allBUFData["2018"] + allBUFData["2019"] + allBUFData['2020']
allBUFData["Total"] = sumBUFData
allBUFData = allBUFData.sort_values(by=['Total'],ascending=False)

sumCARData = allCARData["2018"] + allCARData["2019"] + allCARData['2020']
allCARData["Total"] = sumCARData
allCARData = allCARData.sort_values(by=['Total'],ascending=False)

sumCHIData = allCHIData["2018"] + allCHIData["2019"] + allCHIData['2020']
allCHIData["Total"] = sumCHIData
allCHIData = allCHIData.sort_values(by=['Total'],ascending=False)

sumCINData = allCINData["2018"] + allCINData["2019"] + allCINData['2020']
allCINData["Total"] = sumCINData
allCINData = allCINData.sort_values(by=['Total'],ascending=False)

sumCLEData = allCLEData["2018"] + allCLEData["2019"] + allCLEData['2020']
allCLEData["Total"] = sumCLEData
allCLEData = allCLEData.sort_values(by=['Total'],ascending=False)

sumDALData = allDALData["2018"] + allDALData["2019"] + allDALData['2020']
allDALData["Total"] = sumDALData
allDALData = allDALData.sort_values(by=['Total'],ascending=False)

sumDENData = allDENData["2018"] + allDENData["2019"] + allDENData['2020']
allDENData["Total"] = sumDENData
allDENData = allDENData.sort_values(by=['Total'],ascending=False)

sumDETData = allDETData["2018"] + allDETData["2019"] + allDETData['2020']
allDETData["Total"] = sumDETData
allDETData = allDETData.sort_values(by=['Total'],ascending=False)

sumGBData = allGBData["2018"] + allGBData["2019"] + allGBData['2020']
allGBData["Total"] = sumGBData
allGBData = allGBData.sort_values(by=['Total'],ascending=False)

sumHOUData = allHOUData["2018"] + allHOUData["2019"] + allHOUData['2020']
allHOUData["Total"] = sumHOUData
allHOUData = allHOUData.sort_values(by=['Total'],ascending=False)

sumINDData = allINDData["2018"] + allINDData["2019"] + allINDData['2020']
allINDData["Total"] = sumINDData
allINDData = allINDData.sort_values(by=['Total'],ascending=False)

sumJAXData = allJAXData["2018"] + allJAXData["2019"] + allJAXData['2020']
allJAXData["Total"] = sumJAXData
allJAXData = allJAXData.sort_values(by=['Total'],ascending=False)

sumKCData = allKCData["2018"] + allKCData["2019"] + allKCData['2020']
allKCData["Total"] = sumKCData
allKCData = allKCData.sort_values(by=['Total'],ascending=False)

sumLAData = allLAData["2018"] + allLAData["2019"] + allLAData['2020']
allLAData["Total"] = sumLAData
allLAData = allLAData.sort_values(by=['Total'],ascending=False)

sumLACData = allLACData["2018"] + allLACData["2019"] + allLACData['2020']
allLACData["Total"] = sumLACData
allLACData = allLACData.sort_values(by=['Total'],ascending=False)

sumMIAData = allMIAData["2018"] + allMIAData["2019"] + allMIAData['2020']
allMIAData["Total"] = sumMIAData
allMIAData = allMIAData.sort_values(by=['Total'],ascending=False)

sumMINData = allMINData["2018"] + allMINData["2019"] + allMINData['2020']
allMINData["Total"] = sumMINData
allMINData = allMINData.sort_values(by=['Total'],ascending=False)

sumNEData = allNEData["2018"] + allNEData["2019"] + allNEData['2020']
allNEData["Total"] = sumNEData
allNEData = allNEData.sort_values(by=['Total'],ascending=False)

sumNOData = allNOData["2018"] + allNOData["2019"] + allNOData['2020']
allNOData["Total"] = sumNOData
allNOData = allNOData.sort_values(by=['Total'],ascending=False)

sumNYGData = allNYGData["2018"] + allNYGData["2019"] + allNYGData['2020']
allNYGData["Total"] = sumNYGData
allNYGData = allNYGData.sort_values(by=['Total'],ascending=False)

sumNYJData = allNYJData["2018"] + allNYJData["2019"] + allNYJData['2020']
allNYJData["Total"] = sumNYJData
allNYJData = allNYJData.sort_values(by=['Total'],ascending=False)

sumOAKData = allOAKData["2018"] + allOAKData["2019"] + allOAKData['2020']
allOAKData["Total"] = sumOAKData
allOAKData = allOAKData.sort_values(by=['Total'],ascending=False)

sumPHIData = allPHIData["2018"] + allPHIData["2019"] + allPHIData['2020']
allPHIData["Total"] = sumPHIData
allPHIData = allPHIData.sort_values(by=['Total'],ascending=False)

sumPITData = allPITData["2018"] + allPITData["2019"] + allPITData['2020']
allPITData["Total"] = sumPITData
allPITData = allPITData.sort_values(by=['Total'],ascending=False)

sumSEAData = allSEAData["2018"] + allSEAData["2019"] + allSEAData['2020']
allSEAData["Total"] = sumSEAData
allSEAData = allSEAData.sort_values(by=['Total'],ascending=False)

sumSFData = allSFData["2018"] + allSFData["2019"] + allSFData['2020']
allSFData["Total"] = sumSFData
allSFData = allSFData.sort_values(by=['Total'],ascending=False)

sumTBData = allTBData["2018"] + allTBData["2019"] + allTBData['2020']
allTBData["Total"] = sumTBData
allTBData = allTBData.sort_values(by=['Total'],ascending=False)

sumTENData = allTENData["2018"] + allTENData["2019"] + allTENData['2020']
allTENData["Total"] = sumTENData
allTENData = allTENData.sort_values(by=['Total'],ascending=False)

sumWASData = allWASData["2018"] + allWASData["2019"] + allWASData['2020']
allWASData["Total"] = sumWASData
allWASData = allWASData.sort_values(by=['Total'],ascending=False)

# %%
ARI2018SpecialTeamPlayCountsSeries = allARIData.groupby('ARI Special Play')['2018'].sum().sort_values(ascending=False)
ARI2019SpecialTeamPlayCountsSeries = allARIData.groupby('ARI Special Play')['2019'].sum().sort_values(ascending=False)
ARI2020SpecialTeamPlayCountsSeries = allARIData.groupby('ARI Special Play')['2020'].sum().sort_values(ascending=False)


ATL2018SpecialTeamPlayCountsSeries = allATLData.groupby('ATL Special Play')['2018'].sum().sort_values(ascending=False)
ATL2019SpecialTeamPlayCountsSeries = allATLData.groupby('ATL Special Play')['2019'].sum().sort_values(ascending=False)
ATL2020SpecialTeamPlayCountsSeries = allATLData.groupby('ATL Special Play')['2020'].sum().sort_values(ascending=False)


BAL2018SpecialTeamPlayCountsSeries = allBALData.groupby('BAL Special Play')['2018'].sum().sort_values(ascending=False)
BAL2019SpecialTeamPlayCountsSeries = allBALData.groupby('BAL Special Play')['2019'].sum().sort_values(ascending=False)
BAL2020SpecialTeamPlayCountsSeries = allBALData.groupby('BAL Special Play')['2020'].sum().sort_values(ascending=False)


BUF2018SpecialTeamPlayCountsSeries = allBUFData.groupby('BUF Special Play')['2018'].sum().sort_values(ascending=False)
BUF2019SpecialTeamPlayCountsSeries = allBUFData.groupby('BUF Special Play')['2019'].sum().sort_values(ascending=False)
BUF2020SpecialTeamPlayCountsSeries = allBUFData.groupby('BUF Special Play')['2020'].sum().sort_values(ascending=False)


CAR2018SpecialTeamPlayCountsSeries = allCARData.groupby('CAR Special Play')['2018'].sum().sort_values(ascending=False)
CAR2019SpecialTeamPlayCountsSeries = allCARData.groupby('CAR Special Play')['2019'].sum().sort_values(ascending=False)
CAR2020SpecialTeamPlayCountsSeries = allCARData.groupby('CAR Special Play')['2020'].sum().sort_values(ascending=False)


CHI2018SpecialTeamPlayCountsSeries = allCHIData.groupby('CHI Special Play')['2018'].sum().sort_values(ascending=False)
CHI2019SpecialTeamPlayCountsSeries = allCHIData.groupby('CHI Special Play')['2019'].sum().sort_values(ascending=False)
CHI2020SpecialTeamPlayCountsSeries = allCHIData.groupby('CHI Special Play')['2020'].sum().sort_values(ascending=False)


CIN2018SpecialTeamPlayCountsSeries = allCINData.groupby('CIN Special Play')['2018'].sum().sort_values(ascending=False)
CIN2019SpecialTeamPlayCountsSeries = allCINData.groupby('CIN Special Play')['2019'].sum().sort_values(ascending=False)
CIN2020SpecialTeamPlayCountsSeries = allCINData.groupby('CIN Special Play')['2020'].sum().sort_values(ascending=False)


CLE2018SpecialTeamPlayCountsSeries = allCLEData.groupby('CLE Special Play')['2018'].sum().sort_values(ascending=False)
CLE2019SpecialTeamPlayCountsSeries = allCLEData.groupby('CLE Special Play')['2019'].sum().sort_values(ascending=False)
CLE2020SpecialTeamPlayCountsSeries = allCLEData.groupby('CLE Special Play')['2020'].sum().sort_values(ascending=False)


DAL2018SpecialTeamPlayCountsSeries = allDALData.groupby('DAL Special Play')['2018'].sum().sort_values(ascending=False)
DAL2019SpecialTeamPlayCountsSeries = allDALData.groupby('DAL Special Play')['2019'].sum().sort_values(ascending=False)
DAL2020SpecialTeamPlayCountsSeries = allDALData.groupby('DAL Special Play')['2020'].sum().sort_values(ascending=False)


DEN2018SpecialTeamPlayCountsSeries = allDENData.groupby('DEN Special Play')['2018'].sum().sort_values(ascending=False)
DEN2019SpecialTeamPlayCountsSeries = allDENData.groupby('DEN Special Play')['2019'].sum().sort_values(ascending=False)
DEN2020SpecialTeamPlayCountsSeries = allDENData.groupby('DEN Special Play')['2020'].sum().sort_values(ascending=False)


DET2018SpecialTeamPlayCountsSeries = allDETData.groupby('DET Special Play')['2018'].sum().sort_values(ascending=False)
DET2019SpecialTeamPlayCountsSeries = allDETData.groupby('DET Special Play')['2019'].sum().sort_values(ascending=False)
DET2020SpecialTeamPlayCountsSeries = allDETData.groupby('DET Special Play')['2020'].sum().sort_values(ascending=False)


GB2018SpecialTeamPlayCountsSeries = allGBData.groupby('GB Special Play')['2018'].sum().sort_values(ascending=False)
GB2019SpecialTeamPlayCountsSeries = allGBData.groupby('GB Special Play')['2019'].sum().sort_values(ascending=False)
GB2020SpecialTeamPlayCountsSeries = allGBData.groupby('GB Special Play')['2020'].sum().sort_values(ascending=False)


HOU2018SpecialTeamPlayCountsSeries = allHOUData.groupby('HOU Special Play')['2018'].sum().sort_values(ascending=False)
HOU2019SpecialTeamPlayCountsSeries = allHOUData.groupby('HOU Special Play')['2019'].sum().sort_values(ascending=False)
HOU2020SpecialTeamPlayCountsSeries = allHOUData.groupby('HOU Special Play')['2020'].sum().sort_values(ascending=False)


IND2018SpecialTeamPlayCountsSeries = allINDData.groupby('IND Special Play')['2018'].sum().sort_values(ascending=False)
IND2019SpecialTeamPlayCountsSeries = allINDData.groupby('IND Special Play')['2019'].sum().sort_values(ascending=False)
IND2020SpecialTeamPlayCountsSeries = allINDData.groupby('IND Special Play')['2020'].sum().sort_values(ascending=False)


JAX2018SpecialTeamPlayCountsSeries = allJAXData.groupby('JAX Special Play')['2018'].sum().sort_values(ascending=False)
JAX2019SpecialTeamPlayCountsSeries = allJAXData.groupby('JAX Special Play')['2019'].sum().sort_values(ascending=False)
JAX2020SpecialTeamPlayCountsSeries = allJAXData.groupby('JAX Special Play')['2020'].sum().sort_values(ascending=False)


KC2018SpecialTeamPlayCountsSeries = allKCData.groupby('KC Special Play')['2018'].sum().sort_values(ascending=False)
KC2019SpecialTeamPlayCountsSeries = allKCData.groupby('KC Special Play')['2019'].sum().sort_values(ascending=False)
KC2020SpecialTeamPlayCountsSeries = allKCData.groupby('KC Special Play')['2020'].sum().sort_values(ascending=False)


LA2018SpecialTeamPlayCountsSeries = allLAData.groupby('LA Special Play')['2018'].sum().sort_values(ascending=False)
LA2019SpecialTeamPlayCountsSeries = allLAData.groupby('LA Special Play')['2019'].sum().sort_values(ascending=False)
LA2020SpecialTeamPlayCountsSeries = allLAData.groupby('LA Special Play')['2020'].sum().sort_values(ascending=False)


LAC2018SpecialTeamPlayCountsSeries = allLACData.groupby('LAC Special Play')['2018'].sum().sort_values(ascending=False)
LAC2019SpecialTeamPlayCountsSeries = allLACData.groupby('LAC Special Play')['2019'].sum().sort_values(ascending=False)
LAC2020SpecialTeamPlayCountsSeries = allLACData.groupby('LAC Special Play')['2020'].sum().sort_values(ascending=False)


MIA2018SpecialTeamPlayCountsSeries = allMIAData.groupby('MIA Special Play')['2018'].sum().sort_values(ascending=False)
MIA2019SpecialTeamPlayCountsSeries = allMIAData.groupby('MIA Special Play')['2019'].sum().sort_values(ascending=False)
MIA2020SpecialTeamPlayCountsSeries = allMIAData.groupby('MIA Special Play')['2020'].sum().sort_values(ascending=False)


MIN2018SpecialTeamPlayCountsSeries = allMINData.groupby('MIN Special Play')['2018'].sum().sort_values(ascending=False)
MIN2019SpecialTeamPlayCountsSeries = allMINData.groupby('MIN Special Play')['2019'].sum().sort_values(ascending=False)
MIN2020SpecialTeamPlayCountsSeries = allMINData.groupby('MIN Special Play')['2020'].sum().sort_values(ascending=False)


NE2018SpecialTeamPlayCountsSeries = allNEData.groupby('NE Special Play')['2018'].sum().sort_values(ascending=False)
NE2019SpecialTeamPlayCountsSeries = allNEData.groupby('NE Special Play')['2019'].sum().sort_values(ascending=False)
NE2020SpecialTeamPlayCountsSeries = allNEData.groupby('NE Special Play')['2020'].sum().sort_values(ascending=False)


NO2018SpecialTeamPlayCountsSeries = allNOData.groupby('NO Special Play')['2018'].sum().sort_values(ascending=False)
NO2019SpecialTeamPlayCountsSeries = allNOData.groupby('NO Special Play')['2019'].sum().sort_values(ascending=False)
NO2020SpecialTeamPlayCountsSeries = allNOData.groupby('NO Special Play')['2020'].sum().sort_values(ascending=False)


NYG2018SpecialTeamPlayCountsSeries = allNYGData.groupby('NYG Special Play')['2018'].sum().sort_values(ascending=False)
NYG2019SpecialTeamPlayCountsSeries = allNYGData.groupby('NYG Special Play')['2019'].sum().sort_values(ascending=False)
NYG2020SpecialTeamPlayCountsSeries = allNYGData.groupby('NYG Special Play')['2020'].sum().sort_values(ascending=False)


NYJ2018SpecialTeamPlayCountsSeries = allNYJData.groupby('NYJ Special Play')['2018'].sum().sort_values(ascending=False)
NYJ2019SpecialTeamPlayCountsSeries = allNYJData.groupby('NYJ Special Play')['2019'].sum().sort_values(ascending=False)
NYJ2020SpecialTeamPlayCountsSeries = allNYJData.groupby('NYJ Special Play')['2020'].sum().sort_values(ascending=False)

OAK2018SpecialTeamPlayCountsSeries = allOAKData.groupby('OAK Special Play')['2018'].sum().sort_values(ascending=False)
OAK2019SpecialTeamPlayCountsSeries = allOAKData.groupby('OAK Special Play')['2019'].sum().sort_values(ascending=False)
OAK2020SpecialTeamPlayCountsSeries = allOAKData.groupby('OAK Special Play')['2020'].sum().sort_values(ascending=False)


PHI2018SpecialTeamPlayCountsSeries = allPHIData.groupby('PHI Special Play')['2018'].sum().sort_values(ascending=False)
PHI2019SpecialTeamPlayCountsSeries = allPHIData.groupby('PHI Special Play')['2019'].sum().sort_values(ascending=False)
PHI2020SpecialTeamPlayCountsSeries = allPHIData.groupby('PHI Special Play')['2020'].sum().sort_values(ascending=False)


PIT2018SpecialTeamPlayCountsSeries = allPITData.groupby('PIT Special Play')['2018'].sum().sort_values(ascending=False)
PIT2019SpecialTeamPlayCountsSeries = allPITData.groupby('PIT Special Play')['2019'].sum().sort_values(ascending=False)
PIT2020SpecialTeamPlayCountsSeries = allPITData.groupby('PIT Special Play')['2020'].sum().sort_values(ascending=False)


SEA2018SpecialTeamPlayCountsSeries = allSEAData.groupby('SEA Special Play')['2018'].sum().sort_values(ascending=False)
SEA2019SpecialTeamPlayCountsSeries = allSEAData.groupby('SEA Special Play')['2019'].sum().sort_values(ascending=False)
SEA2020SpecialTeamPlayCountsSeries = allSEAData.groupby('SEA Special Play')['2020'].sum().sort_values(ascending=False)


SF2018SpecialTeamPlayCountsSeries = allSFData.groupby('SF Special Play')['2018'].sum().sort_values(ascending=False)
SF2019SpecialTeamPlayCountsSeries = allSFData.groupby('SF Special Play')['2019'].sum().sort_values(ascending=False)
SF2020SpecialTeamPlayCountsSeries = allSFData.groupby('SF Special Play')['2020'].sum().sort_values(ascending=False)


TB2018SpecialTeamPlayCountsSeries = allTBData.groupby('TB Special Play')['2018'].sum().sort_values(ascending=False)
TB2019SpecialTeamPlayCountsSeries = allTBData.groupby('TB Special Play')['2019'].sum().sort_values(ascending=False)
TB2020SpecialTeamPlayCountsSeries = allTBData.groupby('TB Special Play')['2020'].sum().sort_values(ascending=False)


TEN2018SpecialTeamPlayCountsSeries = allTENData.groupby('TEN Special Play')['2018'].sum().sort_values(ascending=False)
TEN2019SpecialTeamPlayCountsSeries = allTENData.groupby('TEN Special Play')['2019'].sum().sort_values(ascending=False)
TEN2020SpecialTeamPlayCountsSeries = allTENData.groupby('TEN Special Play')['2020'].sum().sort_values(ascending=False)


WAS2018SpecialTeamPlayCountsSeries = allWASData.groupby('WAS Special Play')['2018'].sum().sort_values(ascending=False)
WAS2019SpecialTeamPlayCountsSeries = allWASData.groupby('WAS Special Play')['2019'].sum().sort_values(ascending=False)
WAS2020SpecialTeamPlayCountsSeries = allWASData.groupby('WAS Special Play')['2020'].sum().sort_values(ascending=False)

# %%
ARI2018Labels = []
ARI2018Values = []
ARI2018Counts = 6
otherARI2018Count = 0
for c in ARI2018SpecialTeamPlayCountsSeries.index:
    if ARI2018Counts > 0:
        ARI2018Labels.append(c)
        ARI2018Values.append(ARI2018SpecialTeamPlayCountsSeries[c])
        ARI2018Counts -= 1
    else:
        otherARI2018Count += ARI2018SpecialTeamPlayCountsSeries[c]
ARI2018Labels.append("Other")
ARI2018Values.append(otherARI2018Count)


ARI2019Labels = []
ARI2019Values = []
ARI2019Counts = 6
otherARI2019Count = 0
for c in ARI2019SpecialTeamPlayCountsSeries.index:
    if ARI2019Counts > 0:
        ARI2019Labels.append(c)
        ARI2019Values.append(ARI2019SpecialTeamPlayCountsSeries[c])
        ARI2019Counts -= 1
    else:
        otherARI2019Count += ARI2019SpecialTeamPlayCountsSeries[c]
ARI2019Labels.append("Other")
ARI2019Values.append(otherARI2019Count)


ARI2020Labels = []
ARI2020Values = []
ARI2020Counts = 6
otherARI2020Count = 0
for c in ARI2020SpecialTeamPlayCountsSeries.index:
    if ARI2020Counts > 0:
        ARI2020Labels.append(c)
        ARI2020Values.append(ARI2020SpecialTeamPlayCountsSeries[c])
        ARI2020Counts -= 1
    else:
        otherARI2020Count += ARI2020SpecialTeamPlayCountsSeries[c]
ARI2020Labels.append("Other")
ARI2020Values.append(otherARI2020Count)


ATL2018Labels = []
ATL2018Values = []
ATL2018Counts = 6
otherATL2018Count = 0
for c in ATL2018SpecialTeamPlayCountsSeries.index:
    if ATL2018Counts > 0:
        ATL2018Labels.append(c)
        ATL2018Values.append(ATL2018SpecialTeamPlayCountsSeries[c])
        ATL2018Counts -= 1
    else:
        otherATL2018Count += ATL2018SpecialTeamPlayCountsSeries[c]
ATL2018Labels.append("Other")
ATL2018Values.append(otherATL2018Count)


ATL2019Labels = []
ATL2019Values = []
ATL2019Counts = 6
otherATL2019Count = 0
for c in ATL2019SpecialTeamPlayCountsSeries.index:
    if ATL2019Counts > 0:
        ATL2019Labels.append(c)
        ATL2019Values.append(ATL2019SpecialTeamPlayCountsSeries[c])
        ATL2019Counts -= 1
    else:
        otherATL2019Count += ATL2019SpecialTeamPlayCountsSeries[c]
ATL2019Labels.append("Other")
ATL2019Values.append(otherATL2019Count)


ATL2020Labels = []
ATL2020Values = []
ATL2020Counts = 6
otherATL2020Count = 0
for c in ATL2020SpecialTeamPlayCountsSeries.index:
    if ATL2020Counts > 0:
        ATL2020Labels.append(c)
        ATL2020Values.append(ATL2020SpecialTeamPlayCountsSeries[c])
        ATL2020Counts -= 1
    else:
        otherATL2020Count += ATL2020SpecialTeamPlayCountsSeries[c]
ATL2020Labels.append("Other")
ATL2020Values.append(otherATL2020Count)


BAL2018Labels = []
BAL2018Values = []
BAL2018Counts = 6
otherBAL2018Count = 0
for c in BAL2018SpecialTeamPlayCountsSeries.index:
    if BAL2018Counts > 0:
        BAL2018Labels.append(c)
        BAL2018Values.append(BAL2018SpecialTeamPlayCountsSeries[c])
        BAL2018Counts -= 1
    else:
        otherBAL2018Count += BAL2018SpecialTeamPlayCountsSeries[c]
BAL2018Labels.append("Other")
BAL2018Values.append(otherBAL2018Count)


BAL2019Labels = []
BAL2019Values = []
BAL2019Counts = 6
otherBAL2019Count = 0
for c in BAL2019SpecialTeamPlayCountsSeries.index:
    if BAL2019Counts > 0:
        BAL2019Labels.append(c)
        BAL2019Values.append(BAL2019SpecialTeamPlayCountsSeries[c])
        BAL2019Counts -= 1
    else:
        otherBAL2019Count += BAL2019SpecialTeamPlayCountsSeries[c]
BAL2019Labels.append("Other")
BAL2019Values.append(otherBAL2019Count)


BAL2020Labels = []
BAL2020Values = []
BAL2020Counts = 6
otherBAL2020Count = 0
for c in BAL2020SpecialTeamPlayCountsSeries.index:
    if BAL2020Counts > 0:
        BAL2020Labels.append(c)
        BAL2020Values.append(BAL2020SpecialTeamPlayCountsSeries[c])
        BAL2020Counts -= 1
    else:
        otherBAL2020Count += BAL2020SpecialTeamPlayCountsSeries[c]
BAL2020Labels.append("Other")
BAL2020Values.append(otherBAL2020Count)


BUF2018Labels = []
BUF2018Values = []
BUF2018Counts = 6
otherBUF2018Count = 0
for c in BUF2018SpecialTeamPlayCountsSeries.index:
    if BUF2018Counts > 0:
        BUF2018Labels.append(c)
        BUF2018Values.append(BUF2018SpecialTeamPlayCountsSeries[c])
        BUF2018Counts -= 1
    else:
        otherBUF2018Count += BUF2018SpecialTeamPlayCountsSeries[c]
BUF2018Labels.append("Other")
BUF2018Values.append(otherBUF2018Count)


BUF2019Labels = []
BUF2019Values = []
BUF2019Counts = 6
otherBUF2019Count = 0
for c in BUF2019SpecialTeamPlayCountsSeries.index:
    if BUF2019Counts > 0:
        BUF2019Labels.append(c)
        BUF2019Values.append(BUF2019SpecialTeamPlayCountsSeries[c])
        BUF2019Counts -= 1
    else:
        otherBUF2019Count += BUF2019SpecialTeamPlayCountsSeries[c]
BUF2019Labels.append("Other")
BUF2019Values.append(otherBUF2019Count)


BUF2020Labels = []
BUF2020Values = []
BUF2020Counts = 6
otherBUF2020Count = 0
for c in BUF2020SpecialTeamPlayCountsSeries.index:
    if BUF2020Counts > 0:
        BUF2020Labels.append(c)
        BUF2020Values.append(BUF2020SpecialTeamPlayCountsSeries[c])
        BUF2020Counts -= 1
    else:
        otherBUF2020Count += BUF2020SpecialTeamPlayCountsSeries[c]
BUF2020Labels.append("Other")
BUF2020Values.append(otherBUF2020Count)


CAR2018Labels = []
CAR2018Values = []
CAR2018Counts = 6
otherCAR2018Count = 0
for c in CAR2018SpecialTeamPlayCountsSeries.index:
    if CAR2018Counts > 0:
        CAR2018Labels.append(c)
        CAR2018Values.append(CAR2018SpecialTeamPlayCountsSeries[c])
        CAR2018Counts -= 1
    else:
        otherCAR2018Count += CAR2018SpecialTeamPlayCountsSeries[c]
CAR2018Labels.append("Other")
CAR2018Values.append(otherCAR2018Count)


CAR2019Labels = []
CAR2019Values = []
CAR2019Counts = 6
otherCAR2019Count = 0
for c in CAR2019SpecialTeamPlayCountsSeries.index:
    if CAR2019Counts > 0:
        CAR2019Labels.append(c)
        CAR2019Values.append(CAR2019SpecialTeamPlayCountsSeries[c])
        CAR2019Counts -= 1
    else:
        otherCAR2019Count += CAR2019SpecialTeamPlayCountsSeries[c]
CAR2019Labels.append("Other")
CAR2019Values.append(otherCAR2019Count)


CAR2020Labels = []
CAR2020Values = []
CAR2020Counts = 6
otherCAR2020Count = 0
for c in CAR2020SpecialTeamPlayCountsSeries.index:
    if CAR2020Counts > 0:
        CAR2020Labels.append(c)
        CAR2020Values.append(CAR2020SpecialTeamPlayCountsSeries[c])
        CAR2020Counts -= 1
    else:
        otherCAR2020Count += CAR2020SpecialTeamPlayCountsSeries[c]
CAR2020Labels.append("Other")
CAR2020Values.append(otherCAR2020Count)


CHI2018Labels = []
CHI2018Values = []
CHI2018Counts = 6
otherCHI2018Count = 0
for c in CHI2018SpecialTeamPlayCountsSeries.index:
    if CHI2018Counts > 0:
        CHI2018Labels.append(c)
        CHI2018Values.append(CHI2018SpecialTeamPlayCountsSeries[c])
        CHI2018Counts -= 1
    else:
        otherCHI2018Count += CHI2018SpecialTeamPlayCountsSeries[c]
CHI2018Labels.append("Other")
CHI2018Values.append(otherCHI2018Count)


CHI2019Labels = []
CHI2019Values = []
CHI2019Counts = 6
otherCHI2019Count = 0
for c in CHI2019SpecialTeamPlayCountsSeries.index:
    if CHI2019Counts > 0:
        CHI2019Labels.append(c)
        CHI2019Values.append(CHI2019SpecialTeamPlayCountsSeries[c])
        CHI2019Counts -= 1
    else:
        otherCHI2019Count += CHI2019SpecialTeamPlayCountsSeries[c]
CHI2019Labels.append("Other")
CHI2019Values.append(otherCHI2019Count)


CHI2020Labels = []
CHI2020Values = []
CHI2020Counts = 6
otherCHI2020Count = 0
for c in CHI2020SpecialTeamPlayCountsSeries.index:
    if CHI2020Counts > 0:
        CHI2020Labels.append(c)
        CHI2020Values.append(CHI2020SpecialTeamPlayCountsSeries[c])
        CHI2020Counts -= 1
    else:
        otherCHI2020Count += CHI2020SpecialTeamPlayCountsSeries[c]
CHI2020Labels.append("Other")
CHI2020Values.append(otherCHI2020Count)


CIN2018Labels = []
CIN2018Values = []
CIN2018Counts = 6
otherCIN2018Count = 0
for c in CIN2018SpecialTeamPlayCountsSeries.index:
    if CIN2018Counts > 0:
        CIN2018Labels.append(c)
        CIN2018Values.append(CIN2018SpecialTeamPlayCountsSeries[c])
        CIN2018Counts -= 1
    else:
        otherCIN2018Count += CIN2018SpecialTeamPlayCountsSeries[c]
CIN2018Labels.append("Other")
CIN2018Values.append(otherCIN2018Count)


CIN2019Labels = []
CIN2019Values = []
CIN2019Counts = 6
otherCIN2019Count = 0
for c in CIN2019SpecialTeamPlayCountsSeries.index:
    if CIN2019Counts > 0:
        CIN2019Labels.append(c)
        CIN2019Values.append(CIN2019SpecialTeamPlayCountsSeries[c])
        CIN2019Counts -= 1
    else:
        otherCIN2019Count += CIN2019SpecialTeamPlayCountsSeries[c]
CIN2019Labels.append("Other")
CIN2019Values.append(otherCIN2019Count)


CIN2020Labels = []
CIN2020Values = []
CIN2020Counts = 6
otherCIN2020Count = 0
for c in CIN2020SpecialTeamPlayCountsSeries.index:
    if CIN2020Counts > 0:
        CIN2020Labels.append(c)
        CIN2020Values.append(CIN2020SpecialTeamPlayCountsSeries[c])
        CIN2020Counts -= 1
    else:
        otherCIN2020Count += CIN2020SpecialTeamPlayCountsSeries[c]
CIN2020Labels.append("Other")
CIN2020Values.append(otherCIN2020Count)


CLE2018Labels = []
CLE2018Values = []
CLE2018Counts = 6
otherCLE2018Count = 0
for c in CLE2018SpecialTeamPlayCountsSeries.index:
    if CLE2018Counts > 0:
        CLE2018Labels.append(c)
        CLE2018Values.append(CLE2018SpecialTeamPlayCountsSeries[c])
        CLE2018Counts -= 1
    else:
        otherCLE2018Count += CLE2018SpecialTeamPlayCountsSeries[c]
CLE2018Labels.append("Other")
CLE2018Values.append(otherCLE2018Count)


CLE2019Labels = []
CLE2019Values = []
CLE2019Counts = 6
otherCLE2019Count = 0
for c in CLE2019SpecialTeamPlayCountsSeries.index:
    if CLE2019Counts > 0:
        CLE2019Labels.append(c)
        CLE2019Values.append(CLE2019SpecialTeamPlayCountsSeries[c])
        CLE2019Counts -= 1
    else:
        otherCLE2019Count += CLE2019SpecialTeamPlayCountsSeries[c]
CLE2019Labels.append("Other")
CLE2019Values.append(otherCLE2019Count)


CLE2020Labels = []
CLE2020Values = []
CLE2020Counts = 6
otherCLE2020Count = 0
for c in CLE2020SpecialTeamPlayCountsSeries.index:
    if CLE2020Counts > 0:
        CLE2020Labels.append(c)
        CLE2020Values.append(CLE2020SpecialTeamPlayCountsSeries[c])
        CLE2020Counts -= 1
    else:
        otherCLE2020Count += CLE2020SpecialTeamPlayCountsSeries[c]
CLE2020Labels.append("Other")
CLE2020Values.append(otherCLE2020Count)


DAL2018Labels = []
DAL2018Values = []
DAL2018Counts = 6
otherDAL2018Count = 0
for c in DAL2018SpecialTeamPlayCountsSeries.index:
    if DAL2018Counts > 0:
        DAL2018Labels.append(c)
        DAL2018Values.append(DAL2018SpecialTeamPlayCountsSeries[c])
        DAL2018Counts -= 1
    else:
        otherDAL2018Count += DAL2018SpecialTeamPlayCountsSeries[c]
DAL2018Labels.append("Other")
DAL2018Values.append(otherDAL2018Count)


DAL2019Labels = []
DAL2019Values = []
DAL2019Counts = 6
otherDAL2019Count = 0
for c in DAL2019SpecialTeamPlayCountsSeries.index:
    if DAL2019Counts > 0:
        DAL2019Labels.append(c)
        DAL2019Values.append(DAL2019SpecialTeamPlayCountsSeries[c])
        DAL2019Counts -= 1
    else:
        otherDAL2019Count += DAL2019SpecialTeamPlayCountsSeries[c]
DAL2019Labels.append("Other")
DAL2019Values.append(otherDAL2019Count)


DAL2020Labels = []
DAL2020Values = []
DAL2020Counts = 6
otherDAL2020Count = 0
for c in DAL2020SpecialTeamPlayCountsSeries.index:
    if DAL2020Counts > 0:
        DAL2020Labels.append(c)
        DAL2020Values.append(DAL2020SpecialTeamPlayCountsSeries[c])
        DAL2020Counts -= 1
    else:
        otherATL2020Count += DAL2020SpecialTeamPlayCountsSeries[c]
DAL2020Labels.append("Other")
DAL2020Values.append(otherDAL2020Count)


DEN2018Labels = []
DEN2018Values = []
DEN2018Counts = 6
otherDEN2018Count = 0
for c in DEN2018SpecialTeamPlayCountsSeries.index:
    if DEN2018Counts > 0:
        DEN2018Labels.append(c)
        DEN2018Values.append(DEN2018SpecialTeamPlayCountsSeries[c])
        DEN2018Counts -= 1
    else:
        otherDEN2018Count += DEN2018SpecialTeamPlayCountsSeries[c]
DEN2018Labels.append("Other")
DEN2018Values.append(otherDEN2018Count)


DEN2019Labels = []
DEN2019Values = []
DEN2019Counts = 6
otherDEN2019Count = 0
for c in DEN2019SpecialTeamPlayCountsSeries.index:
    if DEN2019Counts > 0:
        DEN2019Labels.append(c)
        DEN2019Values.append(DEN2019SpecialTeamPlayCountsSeries[c])
        DEN2019Counts -= 1
    else:
        otherDEN2019Count += DEN2019SpecialTeamPlayCountsSeries[c]
DEN2019Labels.append("Other")
DEN2019Values.append(otherDEN2019Count)


DEN2020Labels = []
DEN2020Values = []
DEN2020Counts = 6
otherDEN2020Count = 0
for c in DEN2020SpecialTeamPlayCountsSeries.index:
    if DEN2020Counts > 0:
        DEN2020Labels.append(c)
        DEN2020Values.append(DEN2020SpecialTeamPlayCountsSeries[c])
        DEN2020Counts -= 1
    else:
        otherDEN2020Count += DEN2020SpecialTeamPlayCountsSeries[c]
DEN2020Labels.append("Other")
DEN2020Values.append(otherDEN2020Count)


DET2018Labels = []
DET2018Values = []
DET2018Counts = 6
otherDET2018Count = 0
for c in DET2018SpecialTeamPlayCountsSeries.index:
    if DET2018Counts > 0:
        DET2018Labels.append(c)
        DET2018Values.append(DET2018SpecialTeamPlayCountsSeries[c])
        DET2018Counts -= 1
    else:
        otherDET2018Count += DET2018SpecialTeamPlayCountsSeries[c]
DET2018Labels.append("Other")
DET2018Values.append(otherDET2018Count)


DET2019Labels = []
DET2019Values = []
DET2019Counts = 6
otherDET2019Count = 0
for c in DET2019SpecialTeamPlayCountsSeries.index:
    if DET2019Counts > 0:
        DET2019Labels.append(c)
        DET2019Values.append(DET2019SpecialTeamPlayCountsSeries[c])
        DET2019Counts -= 1
    else:
        otherDET2019Count += DET2019SpecialTeamPlayCountsSeries[c]
DET2019Labels.append("Other")
DET2019Values.append(otherDET2019Count)


DET2020Labels = []
DET2020Values = []
DET2020Counts = 6
otherDET2020Count = 0
for c in DET2020SpecialTeamPlayCountsSeries.index:
    if DET2020Counts > 0:
        DET2020Labels.append(c)
        DET2020Values.append(DET2020SpecialTeamPlayCountsSeries[c])
        DET2020Counts -= 1
    else:
        otherATL2020Count += DET2020SpecialTeamPlayCountsSeries[c]
DET2020Labels.append("Other")
DET2020Values.append(otherDET2020Count)


GB2018Labels = []
GB2018Values = []
GB2018Counts = 6
otherGB2018Count = 0
for c in GB2018SpecialTeamPlayCountsSeries.index:
    if GB2018Counts > 0:
        GB2018Labels.append(c)
        GB2018Values.append(GB2018SpecialTeamPlayCountsSeries[c])
        GB2018Counts -= 1
    else:
        otherGB2018Count += GB2018SpecialTeamPlayCountsSeries[c]
GB2018Labels.append("Other")
GB2018Values.append(otherGB2018Count)


GB2019Labels = []
GB2019Values = []
GB2019Counts = 6
otherGB2019Count = 0
for c in GB2019SpecialTeamPlayCountsSeries.index:
    if GB2019Counts > 0:
        GB2019Labels.append(c)
        GB2019Values.append(GB2019SpecialTeamPlayCountsSeries[c])
        GB2019Counts -= 1
    else:
        otherGB2019Count += GB2019SpecialTeamPlayCountsSeries[c]
GB2019Labels.append("Other")
GB2019Values.append(otherGB2019Count)


GB2020Labels = []
GB2020Values = []
GB2020Counts = 6
otherGB2020Count = 0
for c in GB2020SpecialTeamPlayCountsSeries.index:
    if GB2020Counts > 0:
        GB2020Labels.append(c)
        GB2020Values.append(GB2020SpecialTeamPlayCountsSeries[c])
        GB2020Counts -= 1
    else:
        otherGB2020Count += GB2020SpecialTeamPlayCountsSeries[c]
GB2020Labels.append("Other")
GB2020Values.append(otherGB2020Count)

HOU2018Labels = []
HOU2018Values = []
HOU2018Counts = 6
otherHOU2018Count = 0
for c in HOU2018SpecialTeamPlayCountsSeries.index:
    if HOU2018Counts > 0:
        HOU2018Labels.append(c)
        HOU2018Values.append(HOU2018SpecialTeamPlayCountsSeries[c])
        HOU2018Counts -= 1
    else:
        otherHOU2018Count += HOU2018SpecialTeamPlayCountsSeries[c]
HOU2018Labels.append("Other")
HOU2018Values.append(otherHOU2018Count)


HOU2019Labels = []
HOU2019Values = []
HOU2019Counts = 6
otherHOU2019Count = 0
for c in HOU2019SpecialTeamPlayCountsSeries.index:
    if HOU2019Counts > 0:
        HOU2019Labels.append(c)
        HOU2019Values.append(HOU2019SpecialTeamPlayCountsSeries[c])
        HOU2019Counts -= 1
    else:
        otherHOU2019Count += HOU2019SpecialTeamPlayCountsSeries[c]
HOU2019Labels.append("Other")
HOU2019Values.append(otherHOU2019Count)


HOU2020Labels = []
HOU2020Values = []
HOU2020Counts = 6
otherHOU2020Count = 0
for c in HOU2020SpecialTeamPlayCountsSeries.index:
    if HOU2020Counts > 0:
        HOU2020Labels.append(c)
        HOU2020Values.append(HOU2020SpecialTeamPlayCountsSeries[c])
        HOU2020Counts -= 1
    else:
        otherHOU2020Count += HOU2020SpecialTeamPlayCountsSeries[c]
HOU2020Labels.append("Other")
HOU2020Values.append(otherHOU2020Count)


IND2018Labels = []
IND2018Values = []
IND2018Counts = 6
otherIND2018Count = 0
for c in IND2018SpecialTeamPlayCountsSeries.index:
    if IND2018Counts > 0:
        IND2018Labels.append(c)
        IND2018Values.append(IND2018SpecialTeamPlayCountsSeries[c])
        IND2018Counts -= 1
    else:
        otherIND2018Count += IND2018SpecialTeamPlayCountsSeries[c]
IND2018Labels.append("Other")
IND2018Values.append(otherIND2018Count)


IND2019Labels = []
IND2019Values = []
IND2019Counts = 6
otherIND2019Count = 0
for c in IND2019SpecialTeamPlayCountsSeries.index:
    if IND2019Counts > 0:
        IND2019Labels.append(c)
        IND2019Values.append(IND2019SpecialTeamPlayCountsSeries[c])
        IND2019Counts -= 1
    else:
        otherIND2019Count += IND2019SpecialTeamPlayCountsSeries[c]
IND2019Labels.append("Other")
IND2019Values.append(otherIND2019Count)


IND2020Labels = []
IND2020Values = []
IND2020Counts = 6
otherIND2020Count = 0
for c in IND2020SpecialTeamPlayCountsSeries.index:
    if IND2020Counts > 0:
        IND2020Labels.append(c)
        IND2020Values.append(IND2020SpecialTeamPlayCountsSeries[c])
        IND2020Counts -= 1
    else:
        otherIND2020Count += IND2020SpecialTeamPlayCountsSeries[c]
IND2020Labels.append("Other")
IND2020Values.append(otherIND2020Count)


JAX2018Labels = []
JAX2018Values = []
JAX2018Counts = 6
otherJAX2018Count = 0
for c in JAX2018SpecialTeamPlayCountsSeries.index:
    if JAX2018Counts > 0:
        JAX2018Labels.append(c)
        JAX2018Values.append(JAX2018SpecialTeamPlayCountsSeries[c])
        JAX2018Counts -= 1
    else:
        otherJAX2018Count += JAX2018SpecialTeamPlayCountsSeries[c]
JAX2018Labels.append("Other")
JAX2018Values.append(otherJAX2018Count)


JAX2019Labels = []
JAX2019Values = []
JAX2019Counts = 6
otherJAX2019Count = 0
for c in JAX2019SpecialTeamPlayCountsSeries.index:
    if JAX2019Counts > 0:
        JAX2019Labels.append(c)
        JAX2019Values.append(JAX2019SpecialTeamPlayCountsSeries[c])
        JAX2019Counts -= 1
    else:
        otherJAX2019Count += JAX2019SpecialTeamPlayCountsSeries[c]
JAX2019Labels.append("Other")
JAX2019Values.append(otherJAX2019Count)


JAX2020Labels = []
JAX2020Values = []
JAX2020Counts = 6
otherJAX2020Count = 0
for c in JAX2020SpecialTeamPlayCountsSeries.index:
    if JAX2020Counts > 0:
        JAX2020Labels.append(c)
        JAX2020Values.append(JAX2020SpecialTeamPlayCountsSeries[c])
        JAX2020Counts -= 1
    else:
        otherJAX2020Count += JAX2020SpecialTeamPlayCountsSeries[c]
JAX2020Labels.append("Other")
JAX2020Values.append(otherJAX2020Count)


KC2018Labels = []
KC2018Values = []
KC2018Counts = 6
otherKC2018Count = 0
for c in KC2018SpecialTeamPlayCountsSeries.index:
    if KC2018Counts > 0:
        KC2018Labels.append(c)
        KC2018Values.append(KC2018SpecialTeamPlayCountsSeries[c])
        KC2018Counts -= 1
    else:
        otherKC2018Count += KC2018SpecialTeamPlayCountsSeries[c]
KC2018Labels.append("Other")
KC2018Values.append(otherKC2018Count)


KC2019Labels = []
KC2019Values = []
KC2019Counts = 6
otherKC2019Count = 0
for c in KC2019SpecialTeamPlayCountsSeries.index:
    if KC2019Counts > 0:
        KC2019Labels.append(c)
        KC2019Values.append(KC2019SpecialTeamPlayCountsSeries[c])
        KC2019Counts -= 1
    else:
        otherKC2019Count += KC2019SpecialTeamPlayCountsSeries[c]
KC2019Labels.append("Other")
KC2019Values.append(otherKC2019Count)


KC2020Labels = []
KC2020Values = []
KC2020Counts = 6
otherKC2020Count = 0
for c in KC2020SpecialTeamPlayCountsSeries.index:
    if KC2020Counts > 0:
        KC2020Labels.append(c)
        KC2020Values.append(KC2020SpecialTeamPlayCountsSeries[c])
        KC2020Counts -= 1
    else:
        otherKC2020Count += KC2020SpecialTeamPlayCountsSeries[c]
KC2020Labels.append("Other")
KC2020Values.append(otherKC2020Count)


LA2018Labels = []
LA2018Values = []
LA2018Counts = 6
otherLA2018Count = 0
for c in LA2018SpecialTeamPlayCountsSeries.index:
    if LA2018Counts > 0:
        LA2018Labels.append(c)
        LA2018Values.append(LA2018SpecialTeamPlayCountsSeries[c])
        LA2018Counts -= 1
    else:
        otherLA2018Count += LA2018SpecialTeamPlayCountsSeries[c]
LA2018Labels.append("Other")
LA2018Values.append(otherLA2018Count)


LA2019Labels = []
LA2019Values = []
LA2019Counts = 6
otherLA2019Count = 0
for c in LA2019SpecialTeamPlayCountsSeries.index:
    if LA2019Counts > 0:
        LA2019Labels.append(c)
        LA2019Values.append(LA2019SpecialTeamPlayCountsSeries[c])
        LA2019Counts -= 1
    else:
        otherLA2019Count += LA2019SpecialTeamPlayCountsSeries[c]
LA2019Labels.append("Other")
LA2019Values.append(otherLA2019Count)


LA2020Labels = []
LA2020Values = []
LA2020Counts = 6
otherLA2020Count = 0
for c in LA2020SpecialTeamPlayCountsSeries.index:
    if LA2020Counts > 0:
        LA2020Labels.append(c)
        LA2020Values.append(LA2020SpecialTeamPlayCountsSeries[c])
        LA2020Counts -= 1
    else:
        otherLA2020Count += LA2020SpecialTeamPlayCountsSeries[c]
LA2020Labels.append("Other")
LA2020Values.append(otherLA2020Count)


LAC2018Labels = []
LAC2018Values = []
LAC2018Counts = 6
otherLAC2018Count = 0
for c in LAC2018SpecialTeamPlayCountsSeries.index:
    if LAC2018Counts > 0:
        LAC2018Labels.append(c)
        LAC2018Values.append(LAC2018SpecialTeamPlayCountsSeries[c])
        LAC2018Counts -= 1
    else:
        otherLAC2018Count += LAC2018SpecialTeamPlayCountsSeries[c]
LAC2018Labels.append("Other")
LAC2018Values.append(otherLAC2018Count)


LAC2019Labels = []
LAC2019Values = []
LAC2019Counts = 6
otherLAC2019Count = 0
for c in LAC2019SpecialTeamPlayCountsSeries.index:
    if LAC2019Counts > 0:
        LAC2019Labels.append(c)
        LAC2019Values.append(LAC2019SpecialTeamPlayCountsSeries[c])
        LAC2019Counts -= 1
    else:
        otherLAC2019Count += LAC2019SpecialTeamPlayCountsSeries[c]
LAC2019Labels.append("Other")
LAC2019Values.append(otherLAC2019Count)


LAC2020Labels = []
LAC2020Values = []
LAC2020Counts = 6
otherLAC2020Count = 0
for c in LAC2020SpecialTeamPlayCountsSeries.index:
    if LAC2020Counts > 0:
        LAC2020Labels.append(c)
        LAC2020Values.append(LAC2020SpecialTeamPlayCountsSeries[c])
        LAC2020Counts -= 1
    else:
        otherLAC2020Count += LAC2020SpecialTeamPlayCountsSeries[c]
LAC2020Labels.append("Other")
LAC2020Values.append(otherLAC2020Count)


MIA2018Labels = []
MIA2018Values = []
MIA2018Counts = 6
otherMIA2018Count = 0
for c in MIA2018SpecialTeamPlayCountsSeries.index:
    if MIA2018Counts > 0:
        MIA2018Labels.append(c)
        MIA2018Values.append(MIA2018SpecialTeamPlayCountsSeries[c])
        MIA2018Counts -= 1
    else:
        otherMIA2018Count += MIA2018SpecialTeamPlayCountsSeries[c]
MIA2018Labels.append("Other")
MIA2018Values.append(otherMIA2018Count)


MIA2019Labels = []
MIA2019Values = []
MIA2019Counts = 6
otherMIA2019Count = 0
for c in MIA2019SpecialTeamPlayCountsSeries.index:
    if MIA2019Counts > 0:
        MIA2019Labels.append(c)
        MIA2019Values.append(MIA2019SpecialTeamPlayCountsSeries[c])
        MIA2019Counts -= 1
    else:
        otherMIA2019Count += MIA2019SpecialTeamPlayCountsSeries[c]
MIA2019Labels.append("Other")
MIA2019Values.append(otherMIA2019Count)


MIA2020Labels = []
MIA2020Values = []
MIA2020Counts = 6
otherMIA2020Count = 0
for c in MIA2020SpecialTeamPlayCountsSeries.index:
    if MIA2020Counts > 0:
        MIA2020Labels.append(c)
        MIA2020Values.append(MIA2020SpecialTeamPlayCountsSeries[c])
        MIA2020Counts -= 1
    else:
        otherMIA2020Count += MIA2020SpecialTeamPlayCountsSeries[c]
MIA2020Labels.append("Other")
MIA2020Values.append(otherMIA2020Count)


MIN2018Labels = []
MIN2018Values = []
MIN2018Counts = 6
otherMIN2018Count = 0
for c in MIN2018SpecialTeamPlayCountsSeries.index:
    if MIN2018Counts > 0:
        MIN2018Labels.append(c)
        MIN2018Values.append(MIN2018SpecialTeamPlayCountsSeries[c])
        MIN2018Counts -= 1
    else:
        otherMIN2018Count += MIN2018SpecialTeamPlayCountsSeries[c]
MIN2018Labels.append("Other")
MIN2018Values.append(otherMIN2018Count)


MIN2019Labels = []
MIN2019Values = []
MIN2019Counts = 6
otherMIN2019Count = 0
for c in MIN2019SpecialTeamPlayCountsSeries.index:
    if MIN2019Counts > 0:
        MIN2019Labels.append(c)
        MIN2019Values.append(MIN2019SpecialTeamPlayCountsSeries[c])
        MIN2019Counts -= 1
    else:
        otherMIN2019Count += MIN2019SpecialTeamPlayCountsSeries[c]
MIN2019Labels.append("Other")
MIN2019Values.append(otherMIN2019Count)


MIN2020Labels = []
MIN2020Values = []
MIN2020Counts = 6
otherMIN2020Count = 0
for c in MIN2020SpecialTeamPlayCountsSeries.index:
    if MIN2020Counts > 0:
        MIN2020Labels.append(c)
        MIN2020Values.append(MIN2020SpecialTeamPlayCountsSeries[c])
        MIN2020Counts -= 1
    else:
        otherMIN2020Count += MIN2020SpecialTeamPlayCountsSeries[c]
MIN2020Labels.append("Other")
MIN2020Values.append(otherMIN2020Count)


NE2018Labels = []
NE2018Values = []
NE2018Counts = 6
otherNE2018Count = 0
for c in NE2018SpecialTeamPlayCountsSeries.index:
    if NE2018Counts > 0:
        NE2018Labels.append(c)
        NE2018Values.append(NE2018SpecialTeamPlayCountsSeries[c])
        NE2018Counts -= 1
    else:
        otherNE2018Count += NE2018SpecialTeamPlayCountsSeries[c]
NE2018Labels.append("Other")
NE2018Values.append(otherNE2018Count)


NE2019Labels = []
NE2019Values = []
NE2019Counts = 6
otherNE2019Count = 0
for c in NE2019SpecialTeamPlayCountsSeries.index:
    if NE2019Counts > 0:
        NE2019Labels.append(c)
        NE2019Values.append(NE2019SpecialTeamPlayCountsSeries[c])
        NE2019Counts -= 1
    else:
        otherNE2019Count += NE2019SpecialTeamPlayCountsSeries[c]
NE2019Labels.append("Other")
NE2019Values.append(otherNE2019Count)


NE2020Labels = []
NE2020Values = []
NE2020Counts = 6
otherNE2020Count = 0
for c in NE2020SpecialTeamPlayCountsSeries.index:
    if NE2020Counts > 0:
        NE2020Labels.append(c)
        NE2020Values.append(NE2020SpecialTeamPlayCountsSeries[c])
        NE2020Counts -= 1
    else:
        otherNE2020Count += NE2020SpecialTeamPlayCountsSeries[c]
NE2020Labels.append("Other")
NE2020Values.append(otherNE2020Count)


NO2018Labels = []
NO2018Values = []
NO2018Counts = 6
otherNO2018Count = 0
for c in NO2018SpecialTeamPlayCountsSeries.index:
    if NO2018Counts > 0:
        NO2018Labels.append(c)
        NO2018Values.append(NO2018SpecialTeamPlayCountsSeries[c])
        NO2018Counts -= 1
    else:
        otherNO2018Count += NO2018SpecialTeamPlayCountsSeries[c]
NO2018Labels.append("Other")
NO2018Values.append(otherNO2018Count)


NO2019Labels = []
NO2019Values = []
NO2019Counts = 6
otherNO2019Count = 0
for c in NO2019SpecialTeamPlayCountsSeries.index:
    if NO2019Counts > 0:
        NO2019Labels.append(c)
        NO2019Values.append(NO2019SpecialTeamPlayCountsSeries[c])
        NO2019Counts -= 1
    else:
        otherNO2019Count += NO2019SpecialTeamPlayCountsSeries[c]
NO2019Labels.append("Other")
NO2019Values.append(otherNO2019Count)


NO2020Labels = []
NO2020Values = []
NO2020Counts = 6
otherNO2020Count = 0
for c in NO2020SpecialTeamPlayCountsSeries.index:
    if NO2020Counts > 0:
        NO2020Labels.append(c)
        NO2020Values.append(NO2020SpecialTeamPlayCountsSeries[c])
        NO2020Counts -= 1
    else:
        otherNO2020Count += NO2020SpecialTeamPlayCountsSeries[c]
NO2020Labels.append("Other")
NO2020Values.append(otherNO2020Count)


NYG2018Labels = []
NYG2018Values = []
NYG2018Counts = 6
otherNYG2018Count = 0
for c in NYG2018SpecialTeamPlayCountsSeries.index:
    if NYG2018Counts > 0:
        NYG2018Labels.append(c)
        NYG2018Values.append(NYG2018SpecialTeamPlayCountsSeries[c])
        NYG2018Counts -= 1
    else:
        otherNYG2018Count += NYG2018SpecialTeamPlayCountsSeries[c]
NYG2018Labels.append("Other")
NYG2018Values.append(otherNYG2018Count)


NYG2019Labels = []
NYG2019Values = []
NYG2019Counts = 6
otherNYG2019Count = 0
for c in NYG2019SpecialTeamPlayCountsSeries.index:
    if NYG2019Counts > 0:
        NYG2019Labels.append(c)
        NYG2019Values.append(NYG2019SpecialTeamPlayCountsSeries[c])
        NYG2019Counts -= 1
    else:
        otherNYG2019Count += NYG2019SpecialTeamPlayCountsSeries[c]
NYG2019Labels.append("Other")
NYG2019Values.append(otherNYG2019Count)


NYG2020Labels = []
NYG2020Values = []
NYG2020Counts = 6
otherNYG2020Count = 0
for c in NYG2020SpecialTeamPlayCountsSeries.index:
    if NYG2020Counts > 0:
        NYG2020Labels.append(c)
        NYG2020Values.append(NYG2020SpecialTeamPlayCountsSeries[c])
        NYG2020Counts -= 1
    else:
        otherNYG2020Count += NYG2020SpecialTeamPlayCountsSeries[c]
NYG2020Labels.append("Other")
NYG2020Values.append(otherNYG2020Count)


NYJ2018Labels = []
NYJ2018Values = []
NYJ2018Counts = 6
otherNYJ2018Count = 0
for c in NYJ2018SpecialTeamPlayCountsSeries.index:
    if NYJ2018Counts > 0:
        NYJ2018Labels.append(c)
        NYJ2018Values.append(NYJ2018SpecialTeamPlayCountsSeries[c])
        NYJ2018Counts -= 1
    else:
        otherNYJ2018Count += NYJ2018SpecialTeamPlayCountsSeries[c]
NYJ2018Labels.append("Other")
NYJ2018Values.append(otherNYJ2018Count)


NYJ2019Labels = []
NYJ2019Values = []
NYJ2019Counts = 6
otherNYJ2019Count = 0
for c in NYJ2019SpecialTeamPlayCountsSeries.index:
    if NYJ2019Counts > 0:
        NYJ2019Labels.append(c)
        NYJ2019Values.append(NYJ2019SpecialTeamPlayCountsSeries[c])
        NYJ2019Counts -= 1
    else:
        otherNYJ2019Count += NYJ2019SpecialTeamPlayCountsSeries[c]
NYJ2019Labels.append("Other")
NYJ2019Values.append(otherNYJ2019Count)


NYJ2020Labels = []
NYJ2020Values = []
NYJ2020Counts = 6
otherNYJ2020Count = 0
for c in NYJ2020SpecialTeamPlayCountsSeries.index:
    if NYJ2020Counts > 0:
        NYJ2020Labels.append(c)
        NYJ2020Values.append(NYJ2020SpecialTeamPlayCountsSeries[c])
        NYJ2020Counts -= 1
    else:
        otherNYJ2020Count += NYJ2020SpecialTeamPlayCountsSeries[c]
NYJ2020Labels.append("Other")
NYJ2020Values.append(otherNYJ2020Count)

OAK2018Labels = []
OAK2018Values = []
OAK2018Counts = 6
otherOAK2018Count = 0
for c in OAK2018SpecialTeamPlayCountsSeries.index:
    if OAK2018Counts > 0:
        OAK2018Labels.append(c)
        OAK2018Values.append(OAK2018SpecialTeamPlayCountsSeries[c])
        OAK2018Counts -= 1
    else:
        otherOAK2018Count += OAK2018SpecialTeamPlayCountsSeries[c]
OAK2018Labels.append("Other")
OAK2018Values.append(otherOAK2018Count)


OAK2019Labels = []
OAK2019Values = []
OAK2019Counts = 6
otherOAK2019Count = 0
for c in OAK2019SpecialTeamPlayCountsSeries.index:
    if OAK2019Counts > 0:
        OAK2019Labels.append(c)
        OAK2019Values.append(OAK2019SpecialTeamPlayCountsSeries[c])
        OAK2019Counts -= 1
    else:
        otherOAK2019Count += OAK2019SpecialTeamPlayCountsSeries[c]
OAK2019Labels.append("Other")
OAK2019Values.append(otherOAK2019Count)


OAK2020Labels = []
OAK2020Values = []
OAK2020Counts = 6
otherOAK2020Count = 0
for c in OAK2020SpecialTeamPlayCountsSeries.index:
    if OAK2020Counts > 0:
        OAK2020Labels.append(c)
        OAK2020Values.append(OAK2020SpecialTeamPlayCountsSeries[c])
        OAK2020Counts -= 1
    else:
        otherOAK2020Count += OAK2020SpecialTeamPlayCountsSeries[c]
OAK2020Labels.append("Other")
OAK2020Values.append(otherOAK2020Count)


PHI2018Labels = []
PHI2018Values = []
PHI2018Counts = 6
otherPHI2018Count = 0
for c in PHI2018SpecialTeamPlayCountsSeries.index:
    if PHI2018Counts > 0:
        PHI2018Labels.append(c)
        PHI2018Values.append(PHI2018SpecialTeamPlayCountsSeries[c])
        PHI2018Counts -= 1
    else:
        otherPHI2018Count += PHI2018SpecialTeamPlayCountsSeries[c]
PHI2018Labels.append("Other")
PHI2018Values.append(otherPHI2018Count)


PHI2019Labels = []
PHI2019Values = []
PHI2019Counts = 6
otherPHI2019Count = 0
for c in PHI2019SpecialTeamPlayCountsSeries.index:
    if PHI2019Counts > 0:
        PHI2019Labels.append(c)
        PHI2019Values.append(PHI2019SpecialTeamPlayCountsSeries[c])
        PHI2019Counts -= 1
    else:
        otherPHI2019Count += PHI2019SpecialTeamPlayCountsSeries[c]
PHI2019Labels.append("Other")
PHI2019Values.append(otherPHI2019Count)


PHI2020Labels = []
PHI2020Values = []
PHI2020Counts = 6
otherPHI2020Count = 0
for c in PHI2020SpecialTeamPlayCountsSeries.index:
    if PHI2020Counts > 0:
        PHI2020Labels.append(c)
        PHI2020Values.append(PHI2020SpecialTeamPlayCountsSeries[c])
        PHI2020Counts -= 1
    else:
        otherPHI2020Count += PHI2020SpecialTeamPlayCountsSeries[c]
PHI2020Labels.append("Other")
PHI2020Values.append(otherPHI2020Count)


PIT2018Labels = []
PIT2018Values = []
PIT2018Counts = 6
otherPIT2018Count = 0
for c in PIT2018SpecialTeamPlayCountsSeries.index:
    if PIT2018Counts > 0:
        PIT2018Labels.append(c)
        PIT2018Values.append(PIT2018SpecialTeamPlayCountsSeries[c])
        PIT2018Counts -= 1
    else:
        otherPIT2018Count += PIT2018SpecialTeamPlayCountsSeries[c]
PIT2018Labels.append("Other")
PIT2018Values.append(otherPIT2018Count)


PIT2019Labels = []
PIT2019Values = []
PIT2019Counts = 6
otherPIT2019Count = 0
for c in PIT2019SpecialTeamPlayCountsSeries.index:
    if PIT2019Counts > 0:
        PIT2019Labels.append(c)
        PIT2019Values.append(PIT2019SpecialTeamPlayCountsSeries[c])
        PIT2019Counts -= 1
    else:
        otherPIT2019Count += PIT2019SpecialTeamPlayCountsSeries[c]
PIT2019Labels.append("Other")
PIT2019Values.append(otherPIT2019Count)


PIT2020Labels = []
PIT2020Values = []
PIT2020Counts = 6
otherPIT2020Count = 0
for c in PIT2020SpecialTeamPlayCountsSeries.index:
    if PIT2020Counts > 0:
        PIT2020Labels.append(c)
        PIT2020Values.append(PIT2020SpecialTeamPlayCountsSeries[c])
        PIT2020Counts -= 1
    else:
        otherPIT2020Count += PIT2020SpecialTeamPlayCountsSeries[c]
PIT2020Labels.append("Other")
PIT2020Values.append(otherPIT2020Count)


SEA2018Labels = []
SEA2018Values = []
SEA2018Counts = 6
otherSEA2018Count = 0
for c in SEA2018SpecialTeamPlayCountsSeries.index:
    if SEA2018Counts > 0:
        SEA2018Labels.append(c)
        SEA2018Values.append(SEA2018SpecialTeamPlayCountsSeries[c])
        SEA2018Counts -= 1
    else:
        otherSEA2018Count += SEA2018SpecialTeamPlayCountsSeries[c]
SEA2018Labels.append("Other")
SEA2018Values.append(otherSEA2018Count)


SEA2019Labels = []
SEA2019Values = []
SEA2019Counts = 6
otherSEA2019Count = 0
for c in SEA2019SpecialTeamPlayCountsSeries.index:
    if SEA2019Counts > 0:
        SEA2019Labels.append(c)
        SEA2019Values.append(SEA2019SpecialTeamPlayCountsSeries[c])
        SEA2019Counts -= 1
    else:
        otherSEA2019Count += SEA2019SpecialTeamPlayCountsSeries[c]
SEA2019Labels.append("Other")
SEA2019Values.append(otherSEA2019Count)


SEA2020Labels = []
SEA2020Values = []
SEA2020Counts = 6
otherSEA2020Count = 0
for c in SEA2020SpecialTeamPlayCountsSeries.index:
    if SEA2020Counts > 0:
        SEA2020Labels.append(c)
        SEA2020Values.append(SEA2020SpecialTeamPlayCountsSeries[c])
        SEA2020Counts -= 1
    else:
        otherSEA2020Count += SEA2020SpecialTeamPlayCountsSeries[c]
SEA2020Labels.append("Other")
SEA2020Values.append(otherSEA2020Count)


SF2018Labels = []
SF2018Values = []
SF2018Counts = 6
otherSF2018Count = 0
for c in SF2018SpecialTeamPlayCountsSeries.index:
    if SF2018Counts > 0:
        SF2018Labels.append(c)
        SF2018Values.append(SF2018SpecialTeamPlayCountsSeries[c])
        SF2018Counts -= 1
    else:
        otherSF2018Count += SF2018SpecialTeamPlayCountsSeries[c]
SF2018Labels.append("Other")
SF2018Values.append(otherSF2018Count)


SF2019Labels = []
SF2019Values = []
SF2019Counts = 6
otherSF2019Count = 0
for c in SF2019SpecialTeamPlayCountsSeries.index:
    if SF2019Counts > 0:
        SF2019Labels.append(c)
        SF2019Values.append(SF2019SpecialTeamPlayCountsSeries[c])
        SF2019Counts -= 1
    else:
        otherSF2019Count += SF2019SpecialTeamPlayCountsSeries[c]
SF2019Labels.append("Other")
SF2019Values.append(otherSF2019Count)


SF2020Labels = []
SF2020Values = []
SF2020Counts = 6
otherSF2020Count = 0
for c in SF2020SpecialTeamPlayCountsSeries.index:
    if SF2020Counts > 0:
        SF2020Labels.append(c)
        SF2020Values.append(SF2020SpecialTeamPlayCountsSeries[c])
        SF2020Counts -= 1
    else:
        otherSF2020Count += SF2020SpecialTeamPlayCountsSeries[c]
SF2020Labels.append("Other")
SF2020Values.append(otherSF2020Count)


TB2018Labels = []
TB2018Values = []
TB2018Counts = 6
otherTB2018Count = 0
for c in TB2018SpecialTeamPlayCountsSeries.index:
    if TB2018Counts > 0:
        TB2018Labels.append(c)
        TB2018Values.append(TB2018SpecialTeamPlayCountsSeries[c])
        TB2018Counts -= 1
    else:
        otherTB2018Count += TB2018SpecialTeamPlayCountsSeries[c]
TB2018Labels.append("Other")
TB2018Values.append(otherTB2018Count)


TB2019Labels = []
TB2019Values = []
TB2019Counts = 6
otherTB2019Count = 0
for c in TB2019SpecialTeamPlayCountsSeries.index:
    if TB2019Counts > 0:
        TB2019Labels.append(c)
        TB2019Values.append(TB2019SpecialTeamPlayCountsSeries[c])
        TB2019Counts -= 1
    else:
        otherTB2019Count += TB2019SpecialTeamPlayCountsSeries[c]
TB2019Labels.append("Other")
TB2019Values.append(otherTB2019Count)


TB2020Labels = []
TB2020Values = []
TB2020Counts = 6
otherTB2020Count = 0
for c in TB2020SpecialTeamPlayCountsSeries.index:
    if TB2020Counts > 0:
        TB2020Labels.append(c)
        TB2020Values.append(TB2020SpecialTeamPlayCountsSeries[c])
        TB2020Counts -= 1
    else:
        otherTB2020Count += TB2020SpecialTeamPlayCountsSeries[c]
TB2020Labels.append("Other")
TB2020Values.append(otherTB2020Count)


TEN2018Labels = []
TEN2018Values = []
TEN2018Counts = 6
otherTEN2018Count = 0
for c in TEN2018SpecialTeamPlayCountsSeries.index:
    if TEN2018Counts > 0:
        TEN2018Labels.append(c)
        TEN2018Values.append(TEN2018SpecialTeamPlayCountsSeries[c])
        TEN2018Counts -= 1
    else:
        otherTEN2018Count += TEN2018SpecialTeamPlayCountsSeries[c]
TEN2018Labels.append("Other")
TEN2018Values.append(otherTEN2018Count)


TEN2019Labels = []
TEN2019Values = []
TEN2019Counts = 6
otherTEN2019Count = 0
for c in TEN2019SpecialTeamPlayCountsSeries.index:
    if TEN2019Counts > 0:
        TEN2019Labels.append(c)
        TEN2019Values.append(TEN2019SpecialTeamPlayCountsSeries[c])
        TEN2019Counts -= 1
    else:
        otherTEN2019Count += TEN2019SpecialTeamPlayCountsSeries[c]
TEN2019Labels.append("Other")
TEN2019Values.append(otherTEN2019Count)


TEN2020Labels = []
TEN2020Values = []
TEN2020Counts = 6
otherTEN2020Count = 0
for c in TEN2020SpecialTeamPlayCountsSeries.index:
    if TEN2020Counts > 0:
        TEN2020Labels.append(c)
        TEN2020Values.append(TEN2020SpecialTeamPlayCountsSeries[c])
        TEN2020Counts -= 1
    else:
        otherTEN2020Count += TEN2020SpecialTeamPlayCountsSeries[c]
TEN2020Labels.append("Other")
TEN2020Values.append(otherTEN2020Count)


WAS2018Labels = []
WAS2018Values = []
WAS2018Counts = 6
otherWAS2018Count = 0
for c in WAS2018SpecialTeamPlayCountsSeries.index:
    if WAS2018Counts > 0:
        WAS2018Labels.append(c)
        WAS2018Values.append(WAS2018SpecialTeamPlayCountsSeries[c])
        WAS2018Counts -= 1
    else:
        otherWAS2018Count += WAS2018SpecialTeamPlayCountsSeries[c]
WAS2018Labels.append("Other")
WAS2018Values.append(otherWAS2018Count)


WAS2019Labels = []
WAS2019Values = []
WAS2019Counts = 6
otherWAS2019Count = 0
for c in WAS2019SpecialTeamPlayCountsSeries.index:
    if WAS2019Counts > 0:
        WAS2019Labels.append(c)
        WAS2019Values.append(WAS2019SpecialTeamPlayCountsSeries[c])
        WAS2019Counts -= 1
    else:
        otherWAS2019Count += WAS2019SpecialTeamPlayCountsSeries[c]
WAS2019Labels.append("Other")
WAS2019Values.append(otherWAS2019Count)


WAS2020Labels = []
WAS2020Values = []
WAS2020Counts = 6
otherWAS2020Count = 0
for c in WAS2020SpecialTeamPlayCountsSeries.index:
    if WAS2020Counts > 0:
        WAS2020Labels.append(c)
        WAS2020Values.append(WAS2020SpecialTeamPlayCountsSeries[c])
        WAS2020Counts -= 1
    else:
        otherWAS2020Count += WAS2020SpecialTeamPlayCountsSeries[c]
WAS2020Labels.append("Other")
WAS2020Values.append(otherWAS2020Count)

# %%
x = 0
y = 0
sns.set_style('dark')
colors2018 = sns.color_palette('pastel')
colors2019 = sns.color_palette('Set2')
colors2020 = sns.color_palette('Set3')
fig, axes = plt.subplots(8, 3, figsize=(180, 380))
axes[0,0].pie(ARI2018Values, labels=ARI2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in ARI2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,0].set_title("ARI Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[0,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")
axes[0,1].pie(ARI2019Values, labels=ARI2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in ARI2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,1].set_title("ARI Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[0,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[0,2].pie(ARI2020Values, labels=ARI2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in ARI2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,2].set_title("ARI Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[0,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[1,0].pie(ATL2018Values, labels=ATL2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in ATL2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,0].set_title("ATL Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[1,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,1].pie(ATL2019Values, labels=ATL2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in ATL2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,1].set_title("ATL Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[1,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,2].pie(ATL2020Values, labels=ATL2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in ATL2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,2].set_title("ATL Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[1,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[2,0].pie(BAL2018Values, labels=BAL2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in BAL2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,0].set_title("BAL Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[2,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,1].pie(BAL2019Values, labels=BAL2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in BAL2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,1].set_title("BAL Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[2,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,2].pie(BAL2020Values, labels=BAL2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in BAL2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,2].set_title("BAL Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[2,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[3,0].pie(BUF2018Values, labels=BUF2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in BUF2018Labels], shadow=True, startangle=110,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,0].set_title("BUF Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[3,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,1].pie(BUF2019Values, labels=BUF2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in BUF2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,1].set_title("BUF Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[3,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,2].pie(BUF2020Values, labels=BUF2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in BUF2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,2].set_title("BUF Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[3,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[4,0].pie(CAR2018Values, labels=CAR2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in CAR2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,0].set_title("CAR Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[4,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,1].pie(CAR2019Values, labels=CAR2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in CAR2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,1].set_title("CAR Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[4,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,2].pie(CAR2020Values, labels=CAR2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in CAR2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,2].set_title("CAR Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[4,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")

axes[5,0].pie(CHI2018Values, labels=CHI2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in CHI2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,0].set_title("CHI Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[5,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,1].pie(CHI2019Values, labels=CHI2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in CHI2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,1].set_title("CHI Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[5,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,2].pie(CHI2020Values, labels=CHI2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in CHI2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,2].set_title("CHI Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[5,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[6,0].pie(CIN2018Values, labels=CIN2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in CIN2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,0].set_title("CIN Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[6,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,1].pie(CIN2019Values, labels=CIN2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in CIN2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,1].set_title("CIN Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[6,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,2].pie(CIN2020Values, labels=CIN2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in CIN2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,2].set_title("CIN Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[6,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[7,0].pie(CLE2018Values, labels=CLE2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in CLE2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,0].set_title("CLE Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[7,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[7,1].pie(CLE2019Values, labels=CLE2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in CLE2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,1].set_title("CLE Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[7,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[7,2].pie(CLE2020Values, labels=CLE2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in CLE2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,2].set_title("CLE Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[7,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110, va="center", ha="center")
fig.suptitle("NFL Special Teams Play Analysis (2018-20) Part-I", y=1, fontweight="bold", fontsize=200)
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
sns.set_style("dark")
plt.figure(figsize=(20, 12))
p1 = plt.bar(allARIData['ARI Special Play'],allARIData['2020'], color='#191970',edgecolor='black',linewidth=2)
p2 = plt.bar(allARIData['ARI Special Play'],allARIData['2019'], bottom = allARIData['2020'], color='#FFD700',edgecolor='black',linewidth=2)
p3 = plt.bar(allARIData['ARI Special Play'],allARIData['2018'], bottom = allARIData['2020'] + allARIData['2019'] , color='#97233f',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("ARI Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allATLData['ATL Special Play'],allATLData['2020'], color='#a5acaf',edgecolor='black',linewidth=2)
p2 = plt.bar(allATLData['ATL Special Play'],allATLData['2019'], bottom = allATLData['2020'], color='black',edgecolor='black',linewidth=2)
p3 = plt.bar(allATLData['ATL Special Play'],allATLData['2018'], bottom = allATLData['2020'] + allATLData['2019'] , color='#a71930',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("ATL Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allBALData['BAL Special Play'],allBALData['2020'], color='#241773',edgecolor='black',linewidth=2)
p2 = plt.bar(allBALData['BAL Special Play'],allBALData['2019'], bottom = allBALData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allBALData['BAL Special Play'],allBALData['2018'], bottom = allBALData['2020'] + allBALData['2019'] , color='#9e7c0c',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("BAL Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allBUFData['BUF Special Play'],allBUFData['2020'], color='#00338d',edgecolor='black',linewidth=2)
p2 = plt.bar(allBUFData['BUF Special Play'],allBUFData['2019'], bottom = allBUFData['2020'], color='#c60c30',edgecolor='black',linewidth=2)
p3 = plt.bar(allBUFData['BUF Special Play'],allBUFData['2018'], bottom = allBUFData['2020'] + allBUFData['2019'] , color='#00274d',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("BUF Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allCARData['CAR Special Play'],allCARData['2020'], color='#0085ca',edgecolor='black',linewidth=2)
p2 = plt.bar(allCARData['CAR Special Play'],allCARData['2019'], bottom = allCARData['2020'], color='black',edgecolor='black',linewidth=2)
p3 = plt.bar(allCARData['CAR Special Play'],allCARData['2018'], bottom = allCARData['2020'] + allCARData['2019'] , color='#bfc0bf',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("CAR Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allCHIData['CHI Special Play'],allCHIData['2020'], color='#c83803',edgecolor='black',linewidth=2)
p2 = plt.bar(allCHIData['CHI Special Play'],allCHIData['2019'], bottom = allCHIData['2020'], color='#191970',edgecolor='black',linewidth=2)
p3 = plt.bar(allCHIData['CHI Special Play'],allCHIData['2018'], bottom = allCHIData['2020'] + allCHIData['2019'] , color='#a71930',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("CHI Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allCINData['CIN Special Play'],allCINData['2020'], color='#fb4f14',edgecolor='black',linewidth=2)
p2 = plt.bar(allCINData['CIN Special Play'],allCINData['2019'], bottom = allCINData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allCINData['CIN Special Play'],allCINData['2018'], bottom = allCINData['2020'] + allCINData['2019'] , color='#97233f',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("CIN Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allCLEData['CLE Special Play'],allCLEData['2020'], color='#311d00',edgecolor='black',linewidth=2)
p2 = plt.bar(allCLEData['CLE Special Play'],allCLEData['2019'], bottom = allCLEData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allCLEData['CLE Special Play'],allCLEData['2018'], bottom = allCLEData['2020'] + allCLEData['2019'] , color='#ff3c00',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("CLE Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
x = 0
y = 0
sns.set_style('dark')
colors2018 = sns.color_palette('pastel')
colors2019 = sns.color_palette('Set2')
colors2020 = sns.color_palette('Set3')
fig, axes = plt.subplots(8, 3, figsize=(180, 380))
axes[0,0].pie(DAL2018Values, labels=DAL2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in DAL2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,0].set_title("DAL Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[0,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")
axes[0,1].pie(DAL2019Values, labels=DAL2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in DAL2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,1].set_title("DAL Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[0,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[0,2].pie(DAL2020Values, labels=DAL2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in DAL2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,2].set_title("DAL Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[0,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[1,0].pie(DEN2018Values, labels=DEN2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in DEN2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,0].set_title("DEN Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[1,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,1].pie(DEN2019Values, labels=DEN2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in DEN2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,1].set_title("DEN Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[1,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,2].pie(DEN2020Values, labels=DEN2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in DEN2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,2].set_title("DEN Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[1,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[2,0].pie(DET2018Values, labels=DET2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in DET2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,0].set_title("DET Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[2,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,1].pie(DET2019Values, labels=DET2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in DET2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,1].set_title("DET Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[2,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,2].pie(DET2020Values, labels=DET2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in DET2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,2].set_title("DET Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[2,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[3,0].pie(GB2018Values, labels=GB2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in GB2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,0].set_title("GB Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[3,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,1].pie(GB2019Values, labels=GB2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in GB2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,1].set_title("GB Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[3,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,2].pie(GB2020Values, labels=GB2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in GB2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,2].set_title("GB Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[3,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[4,0].pie(HOU2018Values, labels=HOU2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in HOU2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,0].set_title("HOU Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[4,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,1].pie(HOU2019Values, labels=HOU2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in HOU2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,1].set_title("HOU Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[4,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,2].pie(HOU2020Values, labels=HOU2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in HOU2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,2].set_title("HOU Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[4,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")

axes[5,0].pie(IND2018Values, labels=IND2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in IND2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,0].set_title("IND Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[5,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,1].pie(IND2019Values, labels=IND2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in IND2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,1].set_title("IND Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[5,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,2].pie(IND2020Values, labels=IND2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in IND2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,2].set_title("IND Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[5,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[6,0].pie(JAX2018Values, labels=JAX2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in JAX2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,0].set_title("JAX Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[6,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,1].pie(JAX2019Values, labels=JAX2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in JAX2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,1].set_title("JAX Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[6,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,2].pie(JAX2020Values, labels=JAX2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in JAX2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,2].set_title("JAX Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[6,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[7,0].pie(KC2018Values, labels=KC2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in KC2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,0].set_title("KC Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[7,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[7,1].pie(KC2019Values, labels=KC2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in KC2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,1].set_title("KC Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[7,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=120,va="center",  ha="center")
axes[7,2].pie(KC2020Values, labels=KC2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in KC2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,2].set_title("KC Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[7,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110, va="center", ha="center")
fig.suptitle("NFL Special Teams Play Analysis (2018-20) Part-II", y=1, fontweight="bold", fontsize=200)
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
sns.set_style("dark")
plt.figure(figsize=(20, 12))
p1 = plt.bar(allDALData['DAL Special Play'],allDALData['2020'], color='#869397',edgecolor='black',linewidth=2)
p2 = plt.bar(allDALData['DAL Special Play'],allDALData['2019'], bottom = allDALData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allDALData['DAL Special Play'],allDALData['2018'], bottom = allDALData['2020'] + allDALData['2019'] , color='#00338d',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("DAL Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allDENData['DEN Special Play'],allDENData['2020'], color='#fb4f14',edgecolor='black',linewidth=2)
p2 = plt.bar(allDENData['DEN Special Play'],allDENData['2019'], bottom = allDENData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allDENData['DEN Special Play'],allDENData['2018'], bottom = allDENData['2020'] + allDENData['2019'] , color='#002244',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("DEN Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allDETData['DET Special Play'],allDETData['2020'], color='#0076b6',edgecolor='black',linewidth=2)
p2 = plt.bar(allDETData['DET Special Play'],allDETData['2019'], bottom = allDETData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allDETData['DET Special Play'],allDETData['2018'], bottom = allDETData['2020'] + allDETData['2019'] , color='#b0b7bc',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("DET Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allGBData['GB Special Play'],allGBData['2020'], color='#203731',edgecolor='black',linewidth=2)
p2 = plt.bar(allGBData['GB Special Play'],allGBData['2019'], bottom = allGBData['2020'], color='#ffb612',edgecolor='black',linewidth=2)
p3 = plt.bar(allGBData['GB Special Play'],allGBData['2018'], bottom = allGBData['2020'] + allGBData['2019'] , color='white',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("GB Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allHOUData['HOU Special Play'],allHOUData['2020'], color='#03202f',edgecolor='black',linewidth=2)
p2 = plt.bar(allHOUData['HOU Special Play'],allHOUData['2019'], bottom = allHOUData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allHOUData['HOU Special Play'],allHOUData['2018'], bottom = allHOUData['2020'] + allHOUData['2019'] , color='#a71930',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("HOU Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allINDData['IND Special Play'],allINDData['2020'], color='white',edgecolor='black',linewidth=2)
p2 = plt.bar(allINDData['IND Special Play'],allINDData['2019'], bottom = allINDData['2020'], color='#002c5f',edgecolor='black',linewidth=2)
p3 = plt.bar(allINDData['IND Special Play'],allINDData['2018'], bottom = allINDData['2020'] + allINDData['2019'] , color='#a5acaf',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("IND Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allJAXData['JAX Special Play'],allJAXData['2020'], color='#006778',edgecolor='black',linewidth=2)
p2 = plt.bar(allJAXData['JAX Special Play'],allJAXData['2019'], bottom = allJAXData['2020'], color='#9f792c',edgecolor='black',linewidth=2)
p3 = plt.bar(allJAXData['JAX Special Play'],allJAXData['2018'], bottom = allJAXData['2020'] + allJAXData['2019'] , color='white',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("JAX Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allKCData['KC Special Play'],allKCData['2020'], color='#e31837',edgecolor='black',linewidth=2)
p2 = plt.bar(allKCData['KC Special Play'],allKCData['2019'], bottom = allKCData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allKCData['KC Special Play'],allKCData['2018'], bottom = allKCData['2020'] + allKCData['2019'] , color='#ffb612',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("KC Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold", rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
x = 0
y = 0
sns.set_style('dark')
colors2018 = sns.color_palette('pastel')
colors2019 = sns.color_palette('Set2')
colors2020 = sns.color_palette('Set3')
fig, axes = plt.subplots(8, 3, figsize=(180, 380))
axes[0,0].pie(LA2018Values, labels=LA2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in LA2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,0].set_title("LA Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[0,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")
axes[0,1].pie(LA2019Values, labels=LA2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in LA2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,1].set_title("LA Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[0,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[0,2].pie(LA2020Values, labels=LA2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in LA2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,2].set_title("LA Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[0,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[1,0].pie(LAC2018Values, labels=LAC2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in LAC2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,0].set_title("LAC Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[1,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,1].pie(LAC2019Values, labels=LAC2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in LAC2019Labels], shadow=True, startangle=110,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,1].set_title("LAC Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[1,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,2].pie(LAC2020Values, labels=LAC2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in LAC2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,2].set_title("LAC Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[1,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[2,0].pie(MIA2018Values, labels=MIA2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in MIA2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,0].set_title("MIA Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[2,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,1].pie(MIA2019Values, labels=MIA2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in MIA2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,1].set_title("MIA Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[2,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,2].pie(MIA2020Values, labels=MIA2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in MIA2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,2].set_title("MIA Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[2,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[3,0].pie(MIN2018Values, labels=MIN2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in MIN2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,0].set_title("MIN Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[3,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,1].pie(MIN2019Values, labels=MIN2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in MIN2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,1].set_title("MIN Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[3,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,2].pie(MIN2020Values, labels=MIN2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in MIN2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,2].set_title("MIN Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[3,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[4,0].pie(NE2018Values, labels=NE2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in NE2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,0].set_title("NE Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[4,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,1].pie(NE2019Values, labels=NE2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in NE2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,1].set_title("NE Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[4,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,2].pie(NE2020Values, labels=NE2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in NE2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,2].set_title("NE Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[4,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")

axes[5,0].pie(NO2018Values, labels=NO2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in NO2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,0].set_title("NO Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[5,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,1].pie(NO2019Values, labels=NO2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in NO2019Labels], shadow=True, startangle=110,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,1].set_title("NO Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[5,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,2].pie(NO2020Values, labels=NO2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in NO2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,2].set_title("NO Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[5,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[6,0].pie(NYG2018Values, labels=NYG2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in NYG2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,0].set_title("NYG Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[6,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,1].pie(NYG2019Values, labels=NYG2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in NYG2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,1].set_title("NYG Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[6,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,2].pie(NYG2020Values, labels=NYG2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in NYG2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,2].set_title("NYG Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[6,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[7,0].pie(NYJ2018Values, labels=NYJ2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in NYJ2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,0].set_title("NYJ Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[7,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[7,1].pie(NYJ2019Values, labels=NYJ2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in NYJ2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,1].set_title("NYJ Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[7,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[7,2].pie(NYJ2020Values, labels=NYJ2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in NYJ2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,2].set_title("NYJ Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[7,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110, va="center", ha="center")
fig.suptitle("NFL Special Teams Play Analysis (2018-20) Part-III", y=1, fontweight="bold", fontsize=200)
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
sns.set_style("dark")
plt.figure(figsize=(20, 12))
p1 = plt.bar(allLAData['LA Special Play'],allLAData['2020'], color='#b3995d',edgecolor='black',linewidth=2)
p2 = plt.bar(allLAData['LA Special Play'],allLAData['2019'], bottom = allLAData['2020'], color='#002244',edgecolor='black',linewidth=2)
p3 = plt.bar(allLAData['LA Special Play'],allLAData['2018'], bottom = allLAData['2020'] + allLAData['2019'] , color='white',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("LA Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allLACData['LAC Special Play'],allLACData['2020'], color='#0073cf',edgecolor='black',linewidth=2)
p2 = plt.bar(allLACData['LAC Special Play'],allLACData['2019'], bottom = allLACData['2020'], color='#ffb612',edgecolor='black',linewidth=2)
p3 = plt.bar(allLACData['LAC Special Play'],allLACData['2018'], bottom = allLACData['2020'] + allLACData['2019'] , color='#002244',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("LAC Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allMIAData['MIA Special Play'],allMIAData['2020'], color='#008e97',edgecolor='black',linewidth=2)
p2 = plt.bar(allMIAData['MIA Special Play'],allMIAData['2019'], bottom = allMIAData['2020'], color='#f26a24',edgecolor='black',linewidth=2)
p3 = plt.bar(allMIAData['MIA Special Play'],allMIAData['2018'], bottom = allMIAData['2020'] + allMIAData['2019'] , color='#005778',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("MIA Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allMINData['MIN Special Play'],allMINData['2020'], color='#4f2683',edgecolor='black',linewidth=2)
p2 = plt.bar(allMINData['MIN Special Play'],allMINData['2019'], bottom = allMINData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allMINData['MIN Special Play'],allMINData['2018'], bottom = allMINData['2020'] + allMINData['2019'] , color='#ffc62f',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("MIN Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allNEData['NE Special Play'],allNEData['2020'], color='#002244',edgecolor='black',linewidth=2)
p2 = plt.bar(allNEData['NE Special Play'],allNEData['2019'], bottom = allNEData['2020'], color='#c60c30',edgecolor='black',linewidth=2)
p3 = plt.bar(allNEData['NE Special Play'],allNEData['2018'], bottom = allNEData['2020'] + allNEData['2019'] , color='#b0b7bc',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("NE Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allNOData['NO Special Play'],allNOData['2020'], color='#000000',edgecolor='black',linewidth=2)
p2 = plt.bar(allNOData['NO Special Play'],allNOData['2019'], bottom = allNOData['2020'], color='#d3bc8d',edgecolor='black',linewidth=2)
p3 = plt.bar(allNOData['NO Special Play'],allNOData['2018'], bottom = allNOData['2020'] + allNOData['2019'] , color='white',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("NO Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allNYGData['NYG Special Play'],allNYGData['2020'], color='#a5acaf',edgecolor='black',linewidth=2)
p2 = plt.bar(allNYGData['NYG Special Play'],allNYGData['2019'], bottom = allNYGData['2020'], color='#a71930',edgecolor='black',linewidth=2)
p3 = plt.bar(allNYGData['NYG Special Play'],allNYGData['2018'], bottom = allNYGData['2020'] + allNYGData['2019'] , color='#0b2265',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("NYG Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allNYJData['NYJ Special Play'],allNYJData['2020'], color='white',edgecolor='black',linewidth=2)
p2 = plt.bar(allNYJData['NYJ Special Play'],allNYJData['2019'], bottom = allNYJData['2020'], color='#003f2d',edgecolor='black',linewidth=2)
p3 = plt.bar(allNYJData['NYJ Special Play'],allNYJData['2018'], bottom = allNYJData['2020'] + allNYJData['2019'] , color='green',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("NYJ Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
x = 0
y = 0
sns.set_style('dark')
colors2018 = sns.color_palette('pastel')
colors2019 = sns.color_palette('Set2')
colors2020 = sns.color_palette('Set3')
fig, axes = plt.subplots(8, 3, figsize=(180, 380))
axes[0,0].pie(OAK2018Values, labels=OAK2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in OAK2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,0].set_title("OAK Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[0,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")
axes[0,1].pie(OAK2019Values, labels=OAK2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in OAK2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,1].set_title("OAK Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[0,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[0,2].pie(OAK2020Values, labels=OAK2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in OAK2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[0,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[0,2].set_title("OAK/LV: Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[0,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[1,0].pie(PHI2018Values, labels=PHI2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in PHI2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,0].set_title("PHI Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[1,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,1].pie(PHI2019Values, labels=PHI2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in PHI2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,1].set_title("PHI Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[1,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[1,2].pie(PHI2020Values, labels=PHI2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in PHI2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[1,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[1,2].set_title("PHI Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[1,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[2,0].pie(PIT2018Values, labels=PIT2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in PIT2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,0].set_title("PIT Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[2,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,1].pie(PIT2019Values, labels=PIT2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in PIT2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,1].set_title("PIT Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[2,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[2,2].pie(PIT2020Values, labels=PIT2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in PIT2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[2,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[2,2].set_title("PIT Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[2,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[3,0].pie(SEA2018Values, labels=SEA2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in SEA2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,0].set_title("SEA Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[3,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,1].pie(SEA2019Values, labels=SEA2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in SEA2019Labels], shadow=True, startangle=110,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,1].set_title("SEA Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[3,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[3,2].pie(SEA2020Values, labels=SEA2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in SEA2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[3,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[3,2].set_title("SEA Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[3,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[4,0].pie(SF2018Values, labels=SF2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in SF2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,0].set_title("SF Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[4,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,1].pie(SF2019Values, labels=SF2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in SF2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,1].set_title("SF Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[4,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[4,2].pie(SF2020Values, labels=SF2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in SF2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[4,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[4,2].set_title("SF Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[4,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center", ha="center")

axes[5,0].pie(TB2018Values, labels=TB2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in TB2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,0].set_title("TB Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[5,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,1].pie(TB2019Values, labels=TB2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in TB2019Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,1].set_title("TB Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[5,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[5,2].pie(TB2020Values, labels=TB2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in TB2020Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[5,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[5,2].set_title("TB Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[5,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[6,0].pie(TEN2018Values, labels=TEN2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in TEN2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,0].set_title("TEN Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[6,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,1].pie(TEN2019Values, labels=TEN2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in TEN2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,1].set_title("TEN Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[6,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[6,2].pie(TEN2020Values, labels=TEN2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in TEN2020Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[6,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[6,2].set_title("TEN Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[6,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")

axes[7,0].pie(WAS2018Values, labels=WAS2018Labels, colors=colors2018, autopct='%.0f%%',
            explode=[0.05 for i in WAS2018Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,0].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,0].set_title("WAS Special Team Plays 2018", fontweight="bold", fontsize=110, pad=21)
axes[7,0].annotate("Season\n2018", xy=(x, y), fontweight="bold", fontsize=110,va="center",  ha="center")
axes[7,1].pie(WAS2019Values, labels=WAS2019Labels, colors=colors2019, autopct='%.0f%%',
            explode=[0.05 for i in WAS2019Labels], shadow=True, startangle=120,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,1].set_title("WAS Special Team Plays 2019", fontweight="bold", fontsize=110, pad=21)
axes[7,1].annotate("Season\n2019", xy=(x, y), fontweight="bold", fontsize=120,va="center",  ha="center")
axes[7,2].pie(WAS2020Values, labels=WAS2020Labels, colors=colors2020, autopct='%.0f%%',
            explode=[0.05 for i in WAS2020Labels], shadow=True, startangle=130,
            textprops={'fontweight': 'semibold', 'fontsize': 90}, wedgeprops={'linewidth': 12, 'edgecolor': 'k'},
            labeldistance=1.1)
axes[7,2].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=12))
axes[7,2].set_title("WAS Special Team Plays 2020", fontweight="bold", fontsize=110, pad=21)
axes[7,2].annotate("Season\n2020", xy=(x, y), fontweight="bold", fontsize=110, va="center", ha="center")
fig.suptitle("NFL Special Teams Play Analysis (2018-20) Part-IV", y=1, fontweight="bold", fontsize=200)
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
sns.set_style("dark")
plt.figure(figsize=(20, 12))
p1 = plt.bar(allOAKData['OAK Special Play'],allOAKData['2020'], color='#a5acaf',edgecolor='black',linewidth=2)
p2 = plt.bar(allOAKData['OAK Special Play'],allOAKData['2019'], bottom = allOAKData['2020'], color='black',edgecolor='black',linewidth=2)
p3 = plt.bar(allOAKData['OAK Special Play'],allOAKData['2018'], bottom = allOAKData['2020'] + allOAKData['2019'] , color='white',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("OAK / LV Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allPHIData['PHI Special Play'],allPHIData['2020'], color='#a5acaf',edgecolor='black',linewidth=2)
p2 = plt.bar(allPHIData['PHI Special Play'],allPHIData['2019'], bottom = allPHIData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allPHIData['PHI Special Play'],allPHIData['2018'], bottom = allPHIData['2020'] + allPHIData['2019'] , color='#004c54',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("PHI Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allPITData['PIT Special Play'],allPITData['2020'], color='#c60c30',edgecolor='black',linewidth=2)
p2 = plt.bar(allPITData['PIT Special Play'],allPITData['2019'], bottom = allPITData['2020'], color='#ffb612',edgecolor='black',linewidth=2)
p3 = plt.bar(allPITData['PIT Special Play'],allPITData['2018'], bottom = allPITData['2020'] + allPITData['2019'] , color='#00539b',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("PIT Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allSEAData['SEA Special Play'],allSEAData['2020'], color='#69be28',edgecolor='black',linewidth=2)
p2 = plt.bar(allSEAData['SEA Special Play'],allSEAData['2019'], bottom = allSEAData['2020'], color='#a5acaf',edgecolor='black',linewidth=2)
p3 = plt.bar(allSEAData['SEA Special Play'],allSEAData['2018'], bottom = allSEAData['2020'] + allSEAData['2019'] , color='#002244',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("SEA Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allSFData['SF Special Play'],allSFData['2020'], color='#b3995d',edgecolor='black',linewidth=2)
p2 = plt.bar(allSFData['SF Special Play'],allSFData['2019'], bottom = allSFData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allSFData['SF Special Play'],allSFData['2018'], bottom = allSFData['2020'] + allSFData['2019'] , color='#aa0000',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("SF Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allTBData['TB Special Play'],allTBData['2020'], color='#ff7900',edgecolor='black',linewidth=2)
p2 = plt.bar(allTBData['TB Special Play'],allTBData['2019'], bottom = allTBData['2020'], color='#34302b',edgecolor='black',linewidth=2)
p3 = plt.bar(allTBData['TB Special Play'],allTBData['2018'], bottom = allTBData['2020'] + allTBData['2019'] , color='#d50a0a',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("TB Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allTENData['TEN Special Play'],allTENData['2020'], color='#c60c30',edgecolor='black',linewidth=2)
p2 = plt.bar(allTENData['TEN Special Play'],allTENData['2019'], bottom = allTENData['2020'], color='#4b92db',edgecolor='black',linewidth=2)
p3 = plt.bar(allTENData['TEN Special Play'],allTENData['2018'], bottom = allTENData['2020'] + allTENData['2019'] , color='#a5acaf',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("TEN Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

plt.figure(figsize=(20, 12))
p1 = plt.bar(allWASData['WAS Special Play'],allWASData['2020'], color='#773141',edgecolor='black',linewidth=2)
p2 = plt.bar(allWASData['WAS Special Play'],allWASData['2019'], bottom = allWASData['2020'], color='white',edgecolor='black',linewidth=2)
p3 = plt.bar(allWASData['WAS Special Play'],allWASData['2018'], bottom = allWASData['2020'] + allWASData['2019'] , color='#ffb612',edgecolor='black',linewidth=2)

for r1,r2,r3 in zip(p1,p2,p3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    plt.text(r1.get_x()+r1.get_width()/2., h1+h2+h3, '%s'% (h1+h2+h3), ha = 'center', va='bottom',color='black', size=15)
plt.legend(["2020", "2019", "2018"],prop={'size': 15})
plt.title("WAS Special Team Plays", fontweight="bold", fontsize=25, pad=21)
plt.xticks(fontsize=14,fontweight="bold",rotation=90)
plt.yticks(fontsize=14,fontweight="bold")
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# %%
games_ids = {}
games = mergedGamePlaysAndTrackingFullData.groupby(by=["gameId"])
for game, data in games:
    games_ids[game] = list(set(data.playId.tolist()))

# %%
plt.rcParams['figure.figsize'] = [20, 16]
def drawPitch(width, height, color="w"):
    fig = plt.figure()
    ax = plt.axes(xlim=(-10, width + 30), ylim=(-15, height + 5))
    plt.axis('off')

    rect = patches.Rectangle((-10, -5), width + 40, height + 10, linewidth=1, facecolor='#00994c', capstyle='round')
    ax.add_patch(rect)

    rect = plt.Rectangle((0, 0), width + 20, height, ec=color, fc="None", lw=2)
    ax.add_patch(rect)

    for i in range(21):
        plt.plot([10 + 5 * i, 10 + 5 * i], [0, height], c="w", lw=2)

    for yards in range(10, width, 10):
        yards_text = yards if yards <= width / 2 else width - yards
        # top markers
        plt.text(10 + yards - 2, height - 7.5, yards_text, size=20, c="w", weight="bold")
        # botoom markers
        plt.text(10 + yards - 2, 7.5, yards_text, size=20, c="w", weight="bold", rotation=180)

    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [1, 3], color="w", lw=3)

    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [height - 1, height - 3], color="w", lw=3)

    y = (height - 18.5) / 2
    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [y, y + 2], color="w", lw=3)

    for x in range(20):
        for j in range(1, 5):
            plt.plot([10 + x * 5 + j, 10 + x * 5 + j], [height - y, height - y - 2], color="w", lw=3)

    plt.text(2.5, (height - 10) / 3.5, "Carolina Panthers", size=40, c="w", weight="bold", rotation=90)
    rect = plt.Rectangle((0, 0), 10, height, ec=color, fc="#0085ca", lw=2)
    ax.add_patch(rect)
  
    plt.text(112.5, (height - 10) / 5, "Tampa Bay Buccaneers", size=40, c="w", weight="bold", rotation=-90)
    rect = plt.Rectangle((width + 10, 0), 10, height, ec=color, fc="#d50a0a", lw=2)
    ax.add_patch(rect)
    
    y = (height - 3) / 2
    plt.plot([10 + 2, 10 + 2], [y, y + 3], c="w", lw=2)

    plt.plot([width + 10 - 2, width + 10 - 2], [y, y + 3], c="w", lw=2)

    goal_width = 6 # yards
    y = (height - goal_width) / 2
    plt.plot([0, 0], [y, y + goal_width], "-", c="#F4C430", lw=10, ms=20)
    plt.plot([width + 20, width + 20], [y, y + goal_width], "-", c="#F4C430", lw=10, ms=20)
    
    return fig, ax

fig, ax = drawPitch(100, 53.3)

# %%
def extract_one_game(game_id, play_id):
    game = mergedGamePlaysAndTrackingFullData[
        (mergedGamePlaysAndTrackingFullData.gameId == game_id) & (mergedGamePlaysAndTrackingFullData.playId == play_id)]
    home = {}
    away = {}
    balls = []

    players = game.sort_values(['frameId'], ascending=True).groupby('nflId')

    for id, dx in players:
        jerseyNumber = int(dx.jerseyNumber.iloc[0])
        if dx.team.iloc[0] == "home":
            home[jerseyNumber] = list(zip(dx.x.tolist(), dx.y.tolist()))
        elif dx.team.iloc[0] == "away":
            away[jerseyNumber] = list(zip(dx.x.tolist(), dx.y.tolist()))

    ball_df = game.sort_values(['frameId'], ascending=True)
    ball_df = ball_df[ball_df.team == "football"]
    balls = list(zip(ball_df.x.tolist(), ball_df.y.tolist()))
    return home, away, balls


def animate_one_play(game_id, play_id):
    fig, ax = drawPitch(100, 53.3)

    home, away, balls = extract_one_game(game_id, play_id)

    team_left, = ax.plot([], [], 'o', markersize=18, markerfacecolor="#0085ca", markeredgewidth=2,
                         markeredgecolor="black", zorder=7)
    team_right, = ax.plot([], [], 'o', markersize=18, markerfacecolor="#d50a0a", markeredgewidth=2,
                          markeredgecolor="black", zorder=7)
    ball, = ax.plot([], [], 'o', markersize=10, markerfacecolor="#654321", markeredgewidth=2, markeredgecolor="white",
                    zorder=7)
    drawings = [team_left, team_right, ball]

    def init():
        team_left.set_data([], [])
        team_right.set_data([], [])
        ball.set_data([], [])
        return drawings

    def draw_teams(i):
        X = []
        Y = []
        for k, v in home.items():
            x, y = v[i]
            X.append(x)
            Y.append(y)
        team_left.set_data(X, Y)

        X = []
        Y = []
        for k, v in away.items():
            x, y = v[i]
            X.append(x)
            Y.append(y)
        team_right.set_data(X, Y)

    def animate(i):
        draw_teams(i)

        x, y = balls[i]
        ball.set_data([x, y])
        return drawings

    anim = animation.FuncAnimation(fig, animate, init_func=init,
                                   frames=len(balls), interval=150, blit=True)
#     ax.text(.5, 1.05,
#             "TB's Kickoff Return Yards lossed by possession Team in 2020\n\nTampa Bay Buccaneers vs Carolina Panthers\n\n GameId:- 2020111500, PlayId:- 3154, Week: 10\nDescription:- B.Pinion kicks 67 yards from TB 35 to CAR -2. T.Cannon to TB 4 for 98 yards (S.Murphy-Bunting).\n", 
#             transform=ax.transAxes, ha='center', va='center', fontsize='xx-large', fontweight='extra bold')

#     anim.save('/Users/kushtrivedi/Desktop/NFL/TampaBay/Video/TB-Kickoff-Return-Yards-Loss-2020.mp4')

    return HTML(anim.to_html5_video())

# %%
animate_one_play(2018122302	, 1858)

# %%
# Kickoff Types:- Data Preparation

# Data Preparation for Kickoff by all aspects

# Kickoff Return
allKickoffReturn = task1DataFrameKickoffs[(task1DataFrameKickoffs.Result == 'Kickoff - Return') 
                                          & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                          & (task1DataFrameKickoffs.event != 'None') & (task1DataFrameKickoffs.kickReturnYardage > 25)]
# Kickoff Touchback
allKickoffTouchback = task1DataFrameKickoffs[(task1DataFrameKickoffs.Result == 'Kickoff - Touchback') 
                                          & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                          & (task1DataFrameKickoffs.event != 'None')]

# Kickoff - Muffed
allKickoffMuffed = task1DataFrameKickoffs[(task1DataFrameKickoffs.Result == 'Kickoff - Muffed') 
                                          & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                          & (task1DataFrameKickoffs.event != 'None')]

# Kickoff - Kickoff Team Recovery
allKickoffTeamRecovery = task1DataFrameKickoffs[(task1DataFrameKickoffs.Result == 'Kickoff - Kickoff Team Recovery') 
                                          & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                          & (task1DataFrameKickoffs.event != 'None')]

# Kickoff - Out of Bounds
allKickoffOutOfBounds = task1DataFrameKickoffs[(task1DataFrameKickoffs.Result == 'Kickoff - Out of Bounds') 
                                          & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                          & (task1DataFrameKickoffs.event != 'None')]

# Kickoff - Fair Catch
allKickoffFairCatch = task1DataFrameKickoffs[(task1DataFrameKickoffs.Result == 'Kickoff - Fair Catch') 
                                          & (task1DataFrameKickoffs.penaltyCodes == 0) 
                                          & (task1DataFrameKickoffs.event != 'None')]

# Kickoff - Downed
allKickoffDowned = task1DataFrameKickoffs[(task1DataFrameKickoffs.Result == 'Kickoff - Downed') & (task1DataFrameKickoffs.event != 'None')]

# %%
# Punt Types:- Data Preparation

# Data Preparation for Punt by all aspects

# Punt Return
allPuntReturn = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Return') 
                                          & (task1DataFramePunts.penaltyCodes == 0) 
                                          & (task1DataFramePunts.event != 'None')]
# Punt Touchback
allPuntTouchback = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Touchback') 
                                          & (task1DataFramePunts.penaltyCodes == 0) 
                                          & (task1DataFramePunts.event != 'None')]

# Punt - Fair Catch
allPuntFairCatch = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Fair Catch') 
                                          & (task1DataFramePunts.penaltyCodes == 0) 
                                          & (task1DataFramePunts.event != 'None')]

# Punt - Out of Bounds
allPuntOutOfBounds = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Out of Bounds') 
                                          & (task1DataFramePunts.penaltyCodes == 0) 
                                          & (task1DataFramePunts.event != 'None')]

# Punt - Muffed
allPuntMuffed = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Muffed') 
                                          & (task1DataFramePunts.penaltyCodes == 0) 
                                          & (task1DataFramePunts.event != 'None')]

# Punt - Downed
allPuntDowned = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Downed') & (task1DataFramePunts.event != 'None')]

# Punt - Non-Special Teams Result
allPuntNonSpecialTeamsResult = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Non-Special Teams Result') 
                                          & (task1DataFramePunts.penaltyCodes == 0) 
                                          & (task1DataFramePunts.event != 'None')]

# Punt - Blocked Punt
allPuntBlockedPunt = task1DataFramePunts[(task1DataFramePunts.Result == 'Punt - Blocked Punt') 
                                          & (task1DataFramePunts.penaltyCodes == 0) 
                                          & (task1DataFramePunts.event != 'None')]

# %%
# Kickoff Types:- DataFrames

# Kickoff Return
allKickoffReturnSeries = allKickoffReturn.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','kickReturnYardage','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allKickoffReturnFrame = pd.DataFrame(allKickoffReturnSeries)

# Kickoff Touchback
allKickoffTouchbackSeries = allKickoffTouchback.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allKickoffTouchbackFrame = pd.DataFrame(allKickoffTouchbackSeries)

# Kickoff - Muffed
allKickoffMuffedSeries = allKickoffMuffed.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allKickoffMuffedFrame = pd.DataFrame(allKickoffMuffedSeries)

# Kickoff - Kickoff Team Recovery
allKickoffTeamRecoverySeries = allKickoffTeamRecovery.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allKickoffTeamRecoveryFrame = pd.DataFrame(allKickoffTeamRecoverySeries)

# Kickoff - Out of Bounds
allKickoffOutOfBoundsSeries = allKickoffOutOfBounds.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allKickoffOutOfBoundsFrame = pd.DataFrame(allKickoffOutOfBoundsSeries)

# Kickoff - Fair Catch
allKickoffFairCatchSeries = allKickoffFairCatch.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allKickoffFairCatchFrame = pd.DataFrame(allKickoffFairCatchSeries)

# Kickoff - Downed
allKickoffDownedSeries = allKickoffDowned.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allKickoffDownedFrame = pd.DataFrame(allKickoffDownedSeries)

# %%
allPuntReturnSeries = allPuntReturn.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','kickReturnYardage','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allPuntReturnFrame = pd.DataFrame(allPuntReturnSeries)


allPuntTouchbackSeries = allPuntTouchback.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allPuntTouchbackFrame = pd.DataFrame(allPuntTouchbackSeries)



allPuntFairCatchSeries = allPuntFairCatch.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allPuntFairCatchFrame = pd.DataFrame(allPuntFairCatchSeries)



allPuntOutOfBoundsSeries = allPuntOutOfBounds.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allPuntOutOfBoundsFrame = pd.DataFrame(allPuntOutOfBoundsSeries)



allPuntMuffedSeries = allPuntMuffed.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allPuntMuffedFrame = pd.DataFrame(allPuntMuffedSeries)



allPuntDownedSeries = allPuntDowned.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allPuntDownedFrame = pd.DataFrame(allPuntDownedSeries)



allPuntNonSpecialTeamsResultSeries = allPuntNonSpecialTeamsResult.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=True).size()
allPuntNonSpecialTeamsResultFrame = pd.DataFrame(allPuntNonSpecialTeamsResultSeries)



allPuntBlockedPuntSeries = allPuntBlockedPunt.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo','yardlineSide','Result','gameClock',
                                   'yardlineNumber','playResult','preSnapHomeScore','preSnapVisitorScore','homeTeamAbbr','visitorTeamAbbr',
                                   'week'],as_index=False).size()
allPuntBlockedPuntFrame = pd.DataFrame(allPuntBlockedPuntSeries)

# %%
allKickoffReturnFrame.head()

# %%
# task2DataFrameARI = task2DataFrame[(task2DataFrame.possessionTeam == 'ARI') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameATL = task2DataFrame[(task2DataFrame.possessionTeam == 'ATL') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameBAL = task2DataFrame[(task2DataFrame.possessionTeam == 'BAL') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameBUF = task2DataFrame[(task2DataFrame.possessionTeam == 'BUF') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]

# task2DataFrameCAR = task2DataFrame[(task2DataFrame.possessionTeam == 'CAR') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameCHI = task2DataFrame[(task2DataFrame.possessionTeam == 'CHI') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameCIN = task2DataFrame[(task2DataFrame.possessionTeam == 'CIN') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameCLE = task2DataFrame[(task2DataFrame.possessionTeam == 'CLE') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]

# task2DataFrameDAL = task2DataFrame[(task2DataFrame.possessionTeam == 'DAL') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameDEN = task2DataFrame[(task2DataFrame.possessionTeam == 'DEN') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameDET = task2DataFrame[(task2DataFrame.possessionTeam == 'DET') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameGB = task2DataFrame[(task2DataFrame.possessionTeam == 'GB') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]

# task2DataFrameHOU = task2DataFrame[(task2DataFrame.possessionTeam == 'HOU') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameIND = task2DataFrame[(task2DataFrame.possessionTeam == 'IND') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameJAX = task2DataFrame[(task2DataFrame.possessionTeam == 'JAX') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameKC = task2DataFrame[(task2DataFrame.possessionTeam == 'KC') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0)]

# task2DataFrameLA = task2DataFrame[(task2DataFrame.possessionTeam == 'LA') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameLAC = task2DataFrame[(task2DataFrame.possessionTeam == 'LAC') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameMIA = task2DataFrame[(task2DataFrame.possessionTeam == 'MIA') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameMIN = task2DataFrame[(task2DataFrame.possessionTeam == 'MIN') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]

# task2DataFrameNE = task2DataFrame[(task2DataFrame.possessionTeam == 'NE') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameNO = task2DataFrame[(task2DataFrame.possessionTeam == 'NO') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameNYG = task2DataFrame[(task2DataFrame.possessionTeam == 'NYG') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameNYJ = task2DataFrame[(task2DataFrame.possessionTeam == 'NYJ') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]

# task2DataFrameOAK = task2DataFrame[(task2DataFrame.possessionTeam == 'OAK') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFramePHI = task2DataFrame[(task2DataFrame.possessionTeam == 'PHI') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFramePIT = task2DataFrame[(task2DataFrame.possessionTeam == 'PIT') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameSEA = task2DataFrame[(task2DataFrame.possessionTeam == 'SEA') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]

# task2DataFrameSF = task2DataFrame[(task2DataFrame.possessionTeam == 'SF') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameTB = task2DataFrame[(task2DataFrame.possessionTeam == 'TB') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameTEN = task2DataFrame[(task2DataFrame.possessionTeam == 'TEN') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]
# task2DataFrameWAS = task2DataFrame[(task2DataFrame.possessionTeam == 'WAS') & (task2DataFrame.down != 0) & (task2DataFrame.penaltyCodes == 0) & (task2DataFrame.event != 'None')]

# %%
# task2DataFrameARISeries = task2DataFrameARI.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameARIFinal = pd.DataFrame(task2DataFrameARISeries)

# task2DataFrameATLSeries = task2DataFrameATL.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameATLFinal = pd.DataFrame(task2DataFrameATLSeries)

# task2DataFrameBALSeries = task2DataFrameBAL.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameBALFinal = pd.DataFrame(task2DataFrameBALSeries)

# task2DataFrameBUFSeries = task2DataFrameBUF.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameBUFFinal = pd.DataFrame(task2DataFrameBUFSeries)


# task2DataFrameCARSeries = task2DataFrameCAR.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameCARFinal = pd.DataFrame(task2DataFrameCARSeries)

# task2DataFrameCHISeries = task2DataFrameCHI.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameCHIFinal = pd.DataFrame(task2DataFrameCHISeries)

# task2DataFrameCINSeries = task2DataFrameCIN.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameCINFinal = pd.DataFrame(task2DataFrameCINSeries)

# task2DataFrameCLESeries = task2DataFrameCLE.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameCLEFinal = pd.DataFrame(task2DataFrameCLESeries)


# task2DataFrameDALSeries = task2DataFrameDAL.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameDALFinal = pd.DataFrame(task2DataFrameDALSeries)

# task2DataFrameDENSeries = task2DataFrameDEN.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameDENFinal = pd.DataFrame(task2DataFrameDENSeries)

# task2DataFrameDETSeries = task2DataFrameDET.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameDETFinal = pd.DataFrame(task2DataFrameDETSeries)

# task2DataFrameGBSeries = task2DataFrameGB.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameGBFinal = pd.DataFrame(task2DataFrameGBSeries)

# task2DataFrameHOUSeries = task2DataFrameHOU.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameHOUFinal = pd.DataFrame(task2DataFrameHOUSeries)

# task2DataFrameINDSeries = task2DataFrameIND.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameINDFinal = pd.DataFrame(task2DataFrameINDSeries)

# task2DataFrameJAXSeries = task2DataFrameJAX.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameJAXFinal = pd.DataFrame(task2DataFrameJAXSeries)

# task2DataFrameKCSeries = task2DataFrameKC.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameKCFinal = pd.DataFrame(task2DataFrameKCSeries)


# task2DataFrameLASeries = task2DataFrameLA.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameLAFinal = pd.DataFrame(task2DataFrameLASeries)

# task2DataFrameLACSeries = task2DataFrameLAC.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameLACFinal = pd.DataFrame(task2DataFrameLACSeries)

# task2DataFrameMIASeries = task2DataFrameMIA.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameMIAFinal = pd.DataFrame(task2DataFrameMIASeries)

# task2DataFrameMINSeries = task2DataFrameMIN.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameMINFinal = pd.DataFrame(task2DataFrameMINSeries)



# task2DataFrameNESeries = task2DataFrameNE.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameNEFinal = pd.DataFrame(task2DataFrameNESeries)

# task2DataFrameNOSeries = task2DataFrameNO.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameNOFinal = pd.DataFrame(task2DataFrameNOSeries)

# task2DataFrameNYGSeries = task2DataFrameNYG.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameNYGFinal = pd.DataFrame(task2DataFrameNYGSeries)

# task2DataFrameNYJSeries = task2DataFrameNYJ.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameNYJFinal = pd.DataFrame(task2DataFrameNYJSeries)



# task2DataFrameOAKSeries = task2DataFrameOAK.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameOAKFinal = pd.DataFrame(task2DataFrameOAKSeries)

# task2DataFramePHISeries = task2DataFramePHI.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFramePHIFinal = pd.DataFrame(task2DataFramePHISeries)

# task2DataFramePITSeries = task2DataFramePIT.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFramePITFinal = pd.DataFrame(task2DataFramePITSeries)

# task2DataFrameSEASeries = task2DataFrameSEA.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameSEAFinal = pd.DataFrame(task2DataFrameSEASeries)



# task2DataFrameSFSeries = task2DataFrameSF.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameSFFinal = pd.DataFrame(task2DataFrameSFSeries)

# task2DataFrameTBSeries = task2DataFrameTB.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameTBFinal = pd.DataFrame(task2DataFrameTBSeries)

# task2DataFrameTENSeries = task2DataFrameTEN.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameTENFinal = pd.DataFrame(task2DataFrameTENSeries)

# task2DataFrameWASSeries = task2DataFrameWAS.groupby(['season','possessionTeam','gameId','playId','quarter','down','yardsToGo',
#                                                'yardlineSide','Result','gameClock','yardlineNumber','playResult',
#                                                'preSnapHomeScore','preSnapVisitorScore','event','homeTeamAbbr','visitorTeamAbbr','week']
#                                               ,as_index=False).size()
# task2DataFrameWASFinal = pd.DataFrame(task2DataFrameWASSeries)
